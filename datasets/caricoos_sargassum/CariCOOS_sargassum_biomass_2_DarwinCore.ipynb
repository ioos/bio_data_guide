# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewBiddle/bio_data_guide/blob/main/datasets/caricoos_sargassum/CariCOOS_sargassum_biomass_2_DarwinCore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CariCOOS Sargassum Biomass to Darwin Core
#
# This notebook walks through the process of standardizing the CariCOOS Sargassum biomass data to the Darwin Core standard.
#
# Source data:
# * <http://dm3.caricoos.org/thredds/catalog/content/Parguera_Sargassum/Sargassum_Biomass/catalog.html>

# %%
import pandas as pd
import xarray as xr

# %% [markdown]
# ## First, lets take a look at one of the datasets
#
# We know the data are hosted on a THREDDS server, so we can use some tools like xarray to investigate the data.

# %%
urls = [
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Varadero.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_San_Cristobal.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Monsio_Jose_Entrada.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Monsio_Jose_Centro.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Monsio_Jose.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Media_Luna_4.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Media_Luna_2.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Media_Luna.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Laurel.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Godo.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Enrique.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Corral_Oeste.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Corral_Este.nc',
    'http://dm3.caricoos.org/thredds/fileServer/content/Parguera_Sargassum/Sargassum_Biomass/sargassum_biomass_Corral_Centro.nc'
]

# %%
ds = xr.open_mfdataset(urls, combine='nested', concat_dim='time', data_vars='all')

ds
# Out:
# <xarray.Dataset> Size: 285kB
# Dimensions:                 (time: 2741)
# Coordinates:
#   * time                    (time) datetime64[ns] 22kB 2021-01-13 ... 2025-04-18
# Data variables:
#     station_id              (time) <U19 208kB 'Varadero' ... 'Corral Centro'
#     latitude                (time) float32 11kB 17.97 17.97 ... 17.94 17.94
#     longitude               (time) float32 11kB -67.07 -67.07 ... -67.01 -67.01
#     Sargassum_biomass       (time) float32 11kB dask.array<chunksize=(225,), meta=np.ndarray>
#     Sargassum_biomass_Flag  (time) float64 22kB dask.array<chunksize=(225,), meta=np.ndarray>
# Attributes: (12/50)
#     title:                        Sargassum monitoring program for Varadero s...
#     acknowledgement:              This dataset is part of the Sargassum Monit...
#     Conventions:                  CF-1.6, ACDD-1.3
#     keywords:                     oceanography, sargassum, Caribbean Sea, tim...
#     summary:                      Weekly measurements of Sargassum biomass fr...
#     abstract:                     This time series dataset includes weekly es...
#     ...                           ...
#     time_coverage_resolution:     P1W
#     time_coverage_interval:       P1W
#     time_coverage_units:          days since 1970-01-01T00:00:00Z
#     time_coverage_standard_name:  time
#     cdm_data_type:                TimeSeries
#     cdm_timeseries_variables:     station_id, latitude, longitude

# %% [markdown]
# Let's make this a DataFrame that we can work with.

# %%
df = ds.to_dataframe()

df.sample(n=5)
# Out:
#                      station_id   latitude  longitude  Sargassum_biomass  \
# time
# 2020-12-01         Media Luna 2  17.939409 -67.040291                NaN
# 2023-08-18  Monsio Jose Entrada  17.967649 -67.076546           0.031250
# 2024-08-23        Corral Centro  17.943399 -67.005127           0.000000
# 2021-04-21          Corral Este  17.944214 -67.002602          50.757812
# 2023-03-31              Enrique  17.954504 -67.050285           0.000000
#
#             Sargassum_biomass_Flag
# time
# 2020-12-01                     9.0
# 2023-08-18                     2.0
# 2024-08-23                     2.0
# 2021-04-21                     2.0
# 2023-03-31                     2.0

# %% [markdown]
# Okay, so we have a location and time and some information about biomass and a flag qualifier.
#
# Let's see what the flags mean.

# %%
ds.Sargassum_biomass_Flag.attrs
# Out:
# {'Dimensions': 'time',
#  'standard_name': 'quality_flag',
#  'flag_values': array([0, 1, 2, 3, 4, 9], dtype=int32),
#  'flag_meanings': 'calculated_data, not_analyzed, good_data, questtionable_data, bad_data, missing_data',
#  'long_name': 'Quality flag for Sargassum_biomass',
#  'coverage_content_type': 'qualityInformation'}

# %% [markdown]
# Cool! So, a flag value of 9 == "missing_data". In my opinion, we should only work with data that has `Sargassum_biomass_Flag` == 2 (or "good_data").

# %%
df_occur = df.loc[df['Sargassum_biomass_Flag'] == 2]

# %% [markdown]
# So, what do we need for Darwin Core alignment?
#
# Columns: 'occurrenceID','countryCode', 'kingdom', 'geodeticDatum','eventDate', 'decimalLongitude', 'decimalLatitude', 'scientificName', 'scientificNameID', 'occurrenceStatus', 'basisOfRecord'.

# %%
req_cols = ['occurrenceID','countryCode', 'kingdom', 'geodeticDatum','eventDate', 'decimalLongitude', 'decimalLatitude', 'scientificName', 'scientificNameID', 'occurrenceStatus', 'basisOfRecord']

missing_cols = []
for col in req_cols:
    if col not in df_occur.columns:
        print('Column {} is missing.'.format(col))
# Out:
# Column occurrenceID is missing.
# Column countryCode is missing.
# Column kingdom is missing.
# Column geodeticDatum is missing.
# Column eventDate is missing.
# Column decimalLongitude is missing.
# Column decimalLatitude is missing.
# Column scientificName is missing.
# Column scientificNameID is missing.
# Column occurrenceStatus is missing.
# Column basisOfRecord is missing.

# %% [markdown]
# Whoa, we're missing a bunch. Let's do some renaming and mapping.

# %%
df_occur = df_occur.reset_index()

df_occur.rename(
    columns={'latitude':'decimalLatitude',
             'longitude':'decimalLongitude',
             'time':'eventDate',
             },
    inplace=True,
)

df_occur
# Out:
#       eventDate     station_id  decimalLatitude  decimalLongitude  \
# 0    2021-01-13       Varadero        17.972265        -67.065926
# 1    2021-02-04       Varadero        17.972265        -67.065926
# 2    2021-02-17       Varadero        17.972265        -67.065926
# 3    2021-03-04       Varadero        17.972265        -67.065926
# 4    2021-03-19       Varadero        17.972265        -67.065926
# ...         ...            ...              ...               ...
# 2163 2025-03-14  Corral Centro        17.943399        -67.005127
# 2164 2025-03-21  Corral Centro        17.943399        -67.005127
# 2165 2025-03-28  Corral Centro        17.943399        -67.005127
# 2166 2025-04-04  Corral Centro        17.943399        -67.005127
# 2167 2025-04-11  Corral Centro        17.943399        -67.005127
#
#       Sargassum_biomass  Sargassum_biomass_Flag
# 0              0.000000                     2.0
# 1              0.000000                     2.0
# 2              0.000000                     2.0
# 3              0.000000                     2.0
# 4              0.000000                     2.0
# ...                 ...                     ...
# 2163           0.078125                     2.0
# 2164           0.000000                     2.0
# 2165           0.132812                     2.0
# 2166           0.062500                     2.0
# 2167           7.210938                     2.0
#
# [2168 rows x 6 columns]

# %% [markdown]
# Let's check again to see what we are missing.

# %%
missing_cols = []
for col in req_cols:
    if col not in df_occur.columns:
        print('Column {} is missing.'.format(col))
# Out:
# Column occurrenceID is missing.
# Column countryCode is missing.
# Column kingdom is missing.
# Column geodeticDatum is missing.
# Column scientificName is missing.
# Column scientificNameID is missing.
# Column occurrenceStatus is missing.
# Column basisOfRecord is missing.

# %% [markdown]
# Okay, we're missing mainly the taxonomic information. Let's see how we can gather that a make a mapping table. Luckily, we are only working with Sargassum, so we can search WoRMS for sargassum and see what we find.

# %%
# !pip install pyworms
# Out:
# Requirement already satisfied: pyworms in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: backports.functools-lru-cache in /usr/local/lib/python3.11/dist-packages (from pyworms) (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pyworms) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (2025.4.26)

# %%
import pyworms
worms_info = pyworms.aphiaRecordsByMatchNames('sargassum', marine_only=True)

worms_info
# Out:
# [[{'AphiaID': 144132,
#    'url': 'https://www.marinespecies.org/aphia.php?p=taxdetails&id=144132',
#    'scientificname': 'Sargassum',
#    'authority': 'C.Agardh, 1820',
#    'status': 'accepted',
#    'unacceptreason': None,
#    'taxonRankID': 180,
#    'rank': 'Genus',
#    'valid_AphiaID': 144132,
#    'valid_name': 'Sargassum',
#    'valid_authority': 'C.Agardh, 1820',
#    'parentNameUsageID': 143725,
#    'kingdom': 'Chromista',
#    'phylum': 'Ochrophyta',
#    'class': 'Phaeophyceae',
#    'order': 'Fucales',
#    'family': 'Sargassaceae',
#    'genus': 'Sargassum',
#    'citation': 'Guiry, M.D. & Guiry, G.M. (2025). AlgaeBase. World-wide electronic publication, National University of Ireland, Galway (taxonomic information republished from AlgaeBase with permission of M.D. Guiry). Sargassum C.Agardh, 1820. Accessed through: World Register of Marine Species at: https://www.marinespecies.org/aphia.php?p=taxdetails&id=144132 on 2025-05-14',
#    'lsid': 'urn:lsid:marinespecies.org:taxname:144132',
#    'isMarine': 1,
#    'isBrackish': 1,
#    'isFreshwater': None,
#    'isTerrestrial': None,
#    'isExtinct': None,
#    'match_type': 'exact',
#    'modified': '2012-07-04T13:40:04.623Z'}]]

# %% [markdown]
# Awesome! Now we have our taxonomic information!! Let's add it to the data frame.

# %%
df_occur['kingdom'] = worms_info[0][0]['kingdom']
df_occur['scientificName'] = worms_info[0][0]['scientificname']
df_occur['scientificNameID'] = worms_info[0][0]['lsid']
df_occur.sample(n=5)
# Out:
#       eventDate           station_id  decimalLatitude  decimalLongitude  \
# 1747 2024-05-17         Corral Oeste        17.943796        -67.009186
# 2051 2022-06-24        Corral Centro        17.943399        -67.005127
# 1506 2023-02-17              Enrique        17.954504        -67.050285
# 354  2025-04-04        San Cristobal        17.942074        -67.076714
# 427  2024-02-16  Monsio Jose Entrada        17.967649        -67.076546
#
#       Sargassum_biomass  Sargassum_biomass_Flag    kingdom scientificName  \
# 1747           0.000000                     2.0  Chromista      Sargassum
# 2051           1.789062                     2.0  Chromista      Sargassum
# 1506           0.000000                     2.0  Chromista      Sargassum
# 354            0.000000                     2.0  Chromista      Sargassum
# 427            0.000000                     2.0  Chromista      Sargassum
#
#                                scientificNameID
# 1747  urn:lsid:marinespecies.org:taxname:144132
# 2051  urn:lsid:marinespecies.org:taxname:144132
# 1506  urn:lsid:marinespecies.org:taxname:144132
# 354   urn:lsid:marinespecies.org:taxname:144132
# 427   urn:lsid:marinespecies.org:taxname:144132

# %% [markdown]
# Let's check again to see if we are missing anything.

# %%
missing_cols = []
for col in req_cols:
    if col not in df_occur.columns:
        print('Column {} is missing.'.format(col))
# Out:
# Column occurrenceID is missing.
# Column countryCode is missing.
# Column geodeticDatum is missing.
# Column occurrenceStatus is missing.
# Column basisOfRecord is missing.

# %% [markdown]
# Let's build an eventID and occurrenceID.

# %%
df_occur['eventID'] = df_occur['station_id'].replace(" ","_")+"_"+df_occur['eventDate'].dt.strftime('%Y-%m-%d')


df_occur['occurrenceID'] = 'CARICOOS'+"_"+ds.project.replace(" ","_")+"_"+df_occur["scientificName"]+"_"+df_occur['eventID']

df_occur[['occurrenceID','eventID']].sample(n=5)
# Out:
#                                            occurrenceID  \
# 2008  CARICOOS_Sargassum_monitoring_program_Sargassu...
# 1564  CARICOOS_Sargassum_monitoring_program_Sargassu...
# 1325  CARICOOS_Sargassum_monitoring_program_Sargassu...
# 1837  CARICOOS_Sargassum_monitoring_program_Sargassu...
# 1425  CARICOOS_Sargassum_monitoring_program_Sargassu...
#
#                        eventID
# 2008  Corral Centro_2021-07-23
# 1564        Enrique_2024-07-26
# 1325           Godo_2023-03-17
# 1837    Corral Este_2021-11-23
# 1425        Enrique_2021-04-08

# %% [markdown]
# Now what are we missing?

# %%
missing_cols = []
for col in req_cols:
    if col not in df_occur.columns:
        print('Column {} is missing.'.format(col))
# Out:
# Column countryCode is missing.
# Column geodeticDatum is missing.
# Column occurrenceStatus is missing.
# Column basisOfRecord is missing.

# %% [markdown]
# Lets add the rest of them.

# %%
df_occur['countryCode'] = "US"
df_occur['geodeticDatum'] = "WGS84"
df_occur['occurrenceStatus'] = "present"
df_occur['basisOfRecord'] = "HumanObservation"

df_occur.sample(n=5)
# Out:
#       eventDate           station_id  decimalLatitude  decimalLongitude  \
# 266  2023-03-24        San Cristobal        17.942074        -67.076714
# 2064 2022-10-20        Corral Centro        17.943399        -67.005127
# 1232 2025-02-14               Laurel        17.943192        -67.056442
# 965  2022-11-23           Media Luna        17.939505        -67.042870
# 406  2023-07-21  Monsio Jose Entrada        17.967649        -67.076546
#
#       Sargassum_biomass  Sargassum_biomass_Flag    kingdom scientificName  \
# 266            41.03125                     2.0  Chromista      Sargassum
# 2064            0.00000                     2.0  Chromista      Sargassum
# 1232            0.00000                     2.0  Chromista      Sargassum
# 965             0.00000                     2.0  Chromista      Sargassum
# 406             2.81250                     2.0  Chromista      Sargassum
#
#                                scientificNameID  \
# 266   urn:lsid:marinespecies.org:taxname:144132
# 2064  urn:lsid:marinespecies.org:taxname:144132
# 1232  urn:lsid:marinespecies.org:taxname:144132
# 965   urn:lsid:marinespecies.org:taxname:144132
# 406   urn:lsid:marinespecies.org:taxname:144132
#
#                              eventID  \
# 266         San Cristobal_2023-03-24
# 2064        Corral Centro_2022-10-20
# 1232               Laurel_2025-02-14
# 965            Media Luna_2022-11-23
# 406   Monsio Jose Entrada_2023-07-21
#
#                                            occurrenceID countryCode  \
# 266   CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 2064  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 1232  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 965   CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 406   CARICOOS_Sargassum_monitoring_program_Sargassu...          US
#
#      geodeticDatum occurrenceStatus     basisOfRecord
# 266          WGS84          present  HumanObservation
# 2064         WGS84          present  HumanObservation
# 1232         WGS84          present  HumanObservation
# 965          WGS84          present  HumanObservation
# 406          WGS84          present  HumanObservation

# %% [markdown]
# One last check for all the right columns

# %%
missing_cols = []
for col in req_cols:
    if col not in df_occur.columns:
        print('Column {} is missing.'.format(col))

# %% [markdown]
# Awesome! We've got them all. Good work!
#
# So, we now have an Occurrence Core table. But, what about the biomass data? That's useful information! Let's map it to the extended measurement or fact extension. But first, let's make an event table.

# %%
df_event = df_occur[['eventDate','decimalLatitude','decimalLongitude','eventID','geodeticDatum']]

df_event.sample(n=5)
# Out:
#       eventDate  decimalLatitude  decimalLongitude  \
# 1069 2021-04-27        17.943192        -67.056442
# 1433 2021-06-04        17.954504        -67.050285
# 529  2022-03-04        17.971815        -67.072350
# 1303 2022-07-22        17.970369        -67.047806
# 1532 2023-09-01        17.954504        -67.050285
#
#                             eventID geodeticDatum
# 1069              Laurel_2021-04-27         WGS84
# 1433             Enrique_2021-06-04         WGS84
# 529   Monsio Jose Centro_2022-03-04         WGS84
# 1303                Godo_2022-07-22         WGS84
# 1532             Enrique_2023-09-01         WGS84

# %% [markdown]
# Let's add a few additional details to the event.
#
# * 'coordinateUncertaintyInMeters'
# * 'minimumDepthInMeters'
# * 'maximumDepthInMeters'

# %%
pd.options.mode.copy_on_write = True

df_event['coordinateUncertaintyInMeters'] = 'unknown'
df_event['minimumDepthInMeters'] = 0
df_event['maximumDepthInMeters'] = 0
df_event['samplingProtocol'] = ds.Sargassum_biomass.comment

df_event.sample(n=5)
# Out:
#       eventDate  decimalLatitude  decimalLongitude                   eventID  \
# 311  2024-04-26        17.942074        -67.076714  San Cristobal_2024-04-26
# 112  2023-09-01        17.972265        -67.065926       Varadero_2023-09-01
# 93   2023-04-20        17.972265        -67.065926       Varadero_2023-04-20
# 2078 2023-03-24        17.943399        -67.005127  Corral Centro_2023-03-24
# 893  2021-04-21        17.939505        -67.042870     Media Luna_2021-04-21
#
#      geodeticDatum coordinateUncertaintyInMeters  minimumDepthInMeters  \
# 311          WGS84                       unknown                     0
# 112          WGS84                       unknown                     0
# 93           WGS84                       unknown                     0
# 2078         WGS84                       unknown                     0
# 893          WGS84                       unknown                     0
#
#       maximumDepthInMeters                                   samplingProtocol
# 311                      0  The weekly Sargassum biomass influx (kg∙m-1∙Wk...
# 112                      0  The weekly Sargassum biomass influx (kg∙m-1∙Wk...
# 93                       0  The weekly Sargassum biomass influx (kg∙m-1∙Wk...
# 2078                     0  The weekly Sargassum biomass influx (kg∙m-1∙Wk...
# 893                      0  The weekly Sargassum biomass influx (kg∙m-1∙Wk...

# %% [markdown]
# Okay, we have an event table and an occurrence table. The last step is to create an extended measurement or fact extension table.
#
# What do we need?
#
# * eventID
# * measurementDeterminedDate
# * measurementType
# * measurementValue
# * measurementTypeID
# * measurementUnit
# * measurementUnitID
# * measurementAccuracy
# * measruementMethod

# %%
df_emof = df_occur[['eventID','eventDate','Sargassum_biomass','Sargassum_biomass_Flag']]

df_emof.rename(columns={
    'Sargassum_biomass':'measurementValue',
    'eventDate':'measurementDeterminedDate',
},
    inplace=True,
)

df_emof['measurementType'] = ds.Sargassum_biomass.long_name
df_emof['measurementUnit'] = ds.Sargassum_biomass.units
df_emof['measurementMethod'] = ds.Sargassum_biomass.method

df_emof.drop(columns='Sargassum_biomass_Flag', inplace=True)

df_emof.sample(n=5)
# Out:
#                      eventID measurementDeterminedDate  measurementValue  \
# 712   Monsio Jose_2022-03-25                2022-03-25           0.00000
# 1212       Laurel_2024-09-20                2024-09-20           0.00000
# 1037   Media Luna_2024-09-27                2024-09-27           0.00000
# 1424      Enrique_2021-03-19                2021-03-19           0.00000
# 1526      Enrique_2023-07-21                2023-07-21           6.78125
#
#                       measurementType measurementUnit      measurementMethod
# 712   Sargassum biomass concentration          kg m-1  Measured in the field
# 1212  Sargassum biomass concentration          kg m-1  Measured in the field
# 1037  Sargassum biomass concentration          kg m-1  Measured in the field
# 1424  Sargassum biomass concentration          kg m-1  Measured in the field
# 1526  Sargassum biomass concentration          kg m-1  Measured in the field

# %% [markdown]
# Now, let's hop over to NERC to get our identifiers.
#
# https://vocab.nerc.ac.uk/

# %%
df_emof['measurementTypeID'] = 'http://vocab.nerc.ac.uk/collection/P01/current/SDBIOL05/'
df_emof['measurementUnitID'] = 'http://vocab.nerc.ac.uk/collection/S02/current/S040/'

df_emof.sample(n=5)
# Out:
#                        eventID measurementDeterminedDate  measurementValue  \
# 189   San Cristobal_2021-06-04                2021-06-04          8.687500
# 1269           Godo_2021-10-22                2021-10-22          0.000000
# 1493        Enrique_2022-09-09                2022-09-09          1.343750
# 1020     Media Luna_2024-04-26                2024-04-26          0.000000
# 1802    Corral Este_2021-03-04                2021-03-04          5.242188
#
#                       measurementType measurementUnit      measurementMethod  \
# 189   Sargassum biomass concentration          kg m-1  Measured in the field
# 1269  Sargassum biomass concentration          kg m-1  Measured in the field
# 1493  Sargassum biomass concentration          kg m-1  Measured in the field
# 1020  Sargassum biomass concentration          kg m-1  Measured in the field
# 1802  Sargassum biomass concentration          kg m-1  Measured in the field
#
#                                       measurementTypeID  \
# 189   http://vocab.nerc.ac.uk/collection/P01/current...
# 1269  http://vocab.nerc.ac.uk/collection/P01/current...
# 1493  http://vocab.nerc.ac.uk/collection/P01/current...
# 1020  http://vocab.nerc.ac.uk/collection/P01/current...
# 1802  http://vocab.nerc.ac.uk/collection/P01/current...
#
#                                       measurementUnitID
# 189   http://vocab.nerc.ac.uk/collection/S02/current...
# 1269  http://vocab.nerc.ac.uk/collection/S02/current...
# 1493  http://vocab.nerc.ac.uk/collection/S02/current...
# 1020  http://vocab.nerc.ac.uk/collection/S02/current...
# 1802  http://vocab.nerc.ac.uk/collection/S02/current...

# %% [markdown]
# We can clean up the occurence records now.

# %%
df_occur.drop(columns=['Sargassum_biomass','Sargassum_biomass_Flag','station_id'],inplace=True)

df_occur.sample(n=5)
# Out:
#       eventDate  decimalLatitude  decimalLongitude    kingdom scientificName  \
# 765  2023-07-14        17.968765        -67.076874  Chromista      Sargassum
# 1574 2024-10-11        17.954504        -67.050285  Chromista      Sargassum
# 1226 2024-12-26        17.943192        -67.056442  Chromista      Sargassum
# 1661 2022-03-25        17.943796        -67.009186  Chromista      Sargassum
# 2015 2021-09-01        17.943399        -67.005127  Chromista      Sargassum
#
#                                scientificNameID                   eventID  \
# 765   urn:lsid:marinespecies.org:taxname:144132    Monsio Jose_2023-07-14
# 1574  urn:lsid:marinespecies.org:taxname:144132        Enrique_2024-10-11
# 1226  urn:lsid:marinespecies.org:taxname:144132         Laurel_2024-12-26
# 1661  urn:lsid:marinespecies.org:taxname:144132   Corral Oeste_2022-03-25
# 2015  urn:lsid:marinespecies.org:taxname:144132  Corral Centro_2021-09-01
#
#                                            occurrenceID countryCode  \
# 765   CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 1574  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 1226  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 1661  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
# 2015  CARICOOS_Sargassum_monitoring_program_Sargassu...          US
#
#      geodeticDatum occurrenceStatus     basisOfRecord
# 765          WGS84          present  HumanObservation
# 1574         WGS84          present  HumanObservation
# 1226         WGS84          present  HumanObservation
# 1661         WGS84          present  HumanObservation
# 2015         WGS84          present  HumanObservation

# %% [markdown]
# Now let's write them to CSV files to upload to the OBIS-USA IPT.

# %%
df_occur.to_csv('occur.csv', index=False)
df_event.to_csv('event.csv', index=False)
df_emof.to_csv('emof.csv',index=False)
