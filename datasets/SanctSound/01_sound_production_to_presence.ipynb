# %% [markdown]
# # Sound production to presence
#
# This notebook uses the coastwatch erddap to collect species presence information from SanctSound sound production datasets.
#
# It creates a `sanctsound_presence.zip` file that contains when animals were acoustically present at a specific time and location.
#
# The notebook `presence_to_occurrence.ipynb` reads the results of this notebook and converts them to an occurrence table.
# The notebook `sound_propagation_processing.ipynb` reads the occurrence table and adds information about the coordinateUncertainty from sound propagation modeling data.
#
#
# Let's search the [Coastwatch ERDDAP](https://coastwatch.pfeg.noaa.gov/erddap/index.html) for datasets that contain the following information:
#
# ```
# sanctsound "Sound Production"
# ```

# %%
import erddapy

erddapy.__version__
# Out:
# '2.2.0'

# %%
from erddapy import ERDDAP
import pandas as pd

server = "https://coastwatch.pfeg.noaa.gov/erddap/"

protocol = "griddap"

search_for = 'sanctsound "Sound Production"'

e = ERDDAP(server=server, protocol=protocol)

url = e.get_search_url(search_for=search_for, response="csv")

datasets = pd.read_csv(url)[["Dataset ID","Title"]]

datasets
# Out:
#                              Dataset ID  \
# 0    noaaSanctSound_GR01_01_dolphins_1h
# 1    noaaSanctSound_GR01_02_dolphins_1h
# 2    noaaSanctSound_GR01_03_dolphins_1h
# 3    noaaSanctSound_GR01_04_dolphins_1h
# 4    noaaSanctSound_GR01_05_dolphins_1h
# ..                                  ...
# 690  noaaSanctSound_SB03_08_finwhale_1d
# 691  noaaSanctSound_SB03_09_finwhale_1d
# 692  noaaSanctSound_SB03_10_finwhale_1d
# 693  noaaSanctSound_SB03_11_finwhale_1d
# 694  noaaSanctSound_SB03_12_finwhale_1d
#
#                                                  Title
# 0    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 1    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 2    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 3    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 4    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# ..                                                 ...
# 690  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 691  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 692  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 693  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 694  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
#
# [695 rows x 2 columns]

# %% [markdown]
# # Next let's start building our presence table from each dataset

# %% [markdown]
# Now lets find the `start_time` and `end_time` when animals were present (e.g. `dolphin_presence == 1`).
#
# To do this we look through the variables in the dataset to find the data variable which ends with the phrase `presence` or `detection_count`. This will return the string of the variable name (e.g. `dolphin_presence`). Then, we want to filter the dataset for when that variable only has values equal to 1.0 (or present). Then, we drop any entrys not equal to 1.0.
#
# This returns a filtered xarray dataset of only presence values along with `start_time`, `end_time`, and all the associated metadata.

# %%
# %%time

df_final = pd.DataFrame()

df_broken = pd.DataFrame()

for index, row in datasets.iterrows():
    
    e.dataset_id = row['Dataset ID']
    
    ds = e.to_xarray()
    
    time_var = list(ds.coords)[0]
    
    # set up try/except to test for presence vars, skip datasets without them.
    try:
        da = [da for varname, da in ds.data_vars.items() if (varname.endswith("presence") | varname.endswith("detection_count"))][0]
    except:
        
        string = 'Skipping {} - no presence vars'.format(row['Dataset ID'])
        
        df_broke = pd.DataFrame({'Dataset ID': [row['Dataset ID']], 
                                'reason': [string]})
        df_broken = pd.concat([df_broken, df_broke])
        
        continue

    
    # subset to only presences (presence var == 1)
    ds_subset = da[da.values != 0]
    
    # kick out if ds_subset is empty
    if len(ds_subset[time_var]) == 0:
        
        string = '{} obs - moving to next dataset'.format(len(ds_subset[time_var]))
        
        df_broke = pd.DataFrame({'Dataset ID': [row['Dataset ID']], 
                                'reason': [string]})
        
        df_broken = pd.concat([df_broken, df_broke])
        
        continue
        
    df = ds_subset.to_dataframe().reset_index()
    
    # print some details about what is happening.
    if index==1:
        print('\n{}/{} datasets\n'.format(index+1,datasets.shape[0]))
        print('querying {}'.format(row['Dataset ID']))
        print('{} ({} rows): {}'.format(row['Dataset ID'],ds.coords.dims[time_var],ds.geospatial_bounds))
        print('Subsetted to ({} rows)'.format(len(ds_subset[time_var])))
    
    # Store global attributes as data.
    df['dataset_id'] = row['Dataset ID']
    df['WKT'] = ds.geospatial_bounds
    df['decimalLatitude'] = ds.geospatial_bounds.split(" ")[1].replace("(","")
    df['decimalLongitude'] = ds.geospatial_bounds.split(" ")[2].replace(")","")
    df['vernacularName'] = ds.title.split(",")[1].replace(" Sound Production","").replace(" Sound Producion","").lower().lstrip()
    
    # Create the BIG dataframe
    df_final = pd.concat([df_final, df])

print(f'Found {df_final.shape[0]} datasets. There were {df_broken.shape[0]} datasets that either didn\'t have a presence variable or didn\'t contain presence data')
# Out:
# 2/695 datasets
#
# querying noaaSanctSound_GR01_02_dolphins_1h
# noaaSanctSound_GR01_02_dolphins_1h (3029 rows): POINT (31.396417 -80.8904)
# Subsetted to (56 rows)
# Found 713676 datasets. There were 186 datasets that either didn't have a presence variable or didn't contain presence data
# CPU times: total: 40.7 s
# Wall time: 5min 20s

# %%
df_final.sample(n=5)
# Out:
#       start_time  dolphin_presence                        dataset_id  \
# 40112        NaT               NaN  noaaSanctSound_MB01_03_bluewhale
# 40783        NaT               NaN  noaaSanctSound_MB01_06_bluewhale
# 22773        NaT               NaN  noaaSanctSound_CI02_05_bluewhale
# 26017        NaT               NaN  noaaSanctSound_CI04_02_bluewhale
# 17670        NaT               NaN  noaaSanctSound_MB01_06_bluewhale
#
#                              WKT decimalLatitude decimalLongitude  \
# 40112    POINT (36.798 -121.976)          36.798         -121.976
# 40783  POINT (36.7977 -121.9757)         36.7977        -121.9757
# 22773  POINT (34.0853 -120.5223)         34.0853        -120.5223
# 26017  POINT (33.8489 -120.1175)         33.8489        -120.1175
# 17670  POINT (36.7977 -121.9757)         36.7977        -121.9757
#
#       vernacularName                    time  bluewhale_presence  \
# 40112     blue whale 2019-12-08 15:22:29.368                 1.0
# 40783     blue whale 2020-12-06 23:15:11.864                 1.0
# 22773     blue whale 2020-09-12 14:51:11.608                 1.0
# 26017     blue whale 2019-08-03 03:32:30.504                 1.0
# 17670     blue whale 2020-10-19 03:01:40.848                 1.0
#
#        bluewhale_manual_presence  ...  pinniped_presence  \
# 40112                        NaN  ...                NaN
# 40783                        NaN  ...                NaN
# 22773                        NaN  ...                NaN
# 26017                        NaN  ...                NaN
# 17670                        NaN  ...                NaN
#
#        redgrouper_detection_count  seiwhale_presence  atlanticcod_presence  \
# 40112                         NaN                NaN                   NaN
# 40783                         NaN                NaN                   NaN
# 22773                         NaN                NaN                   NaN
# 26017                         NaN                NaN                   NaN
# 17670                         NaN                NaN                   NaN
#
#        blackgrouper_detection_count  humpbackwhale_presence  \
# 40112                           NaN                     NaN
# 40783                           NaN                     NaN
# 22773                           NaN                     NaN
# 26017                           NaN                     NaN
# 17670                           NaN                     NaN
#
#        killerwhale_presence  minkewhale_presence  plainfinmidshipman_presence  \
# 40112                   NaN                  NaN                          NaN
# 40783                   NaN                  NaN                          NaN
# 22773                   NaN                  NaN                          NaN
# 26017                   NaN                  NaN                          NaN
# 17670                   NaN                  NaN                          NaN
#
#        northatlanticrightwhale_presence
# 40112                               NaN
# 40783                               NaN
# 22773                               NaN
# 26017                               NaN
# 17670                               NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## WoRMS Mapping
# WoRMS lookup. Abby Benson created a mapping table which we will use below to insert the appropriate WoRMS idenfitiers.

# %%
df_mapping = pd.read_csv('SanctSound_SpeciesLookupTable.csv')

df_mapping
# Out:
#                 vernacularName              scientificName  \
# 0                      dolphin                     Cetacea
# 1                   blue whale       Balaenoptera musculus
# 2                     bocaccio        Sebastes paucispinis
# 3                    fin whale       Balaenoptera physalus
# 4                     pinniped                  Pinnipedia
# 5                  red grouper           Epinephelus morio
# 6                    sei whale       Balaenoptera borealis
# 7                black grouper         Mycteroperca bonaci
# 8               humpback whale      Megaptera novaeangliae
# 9                 killer whale                Orcinus orca
# 10                 minke whale  Balaenoptera acutorostrata
# 11         plainfin midshipman          Porichthys notatus
# 12  north atlantic right whale         Eubalaena glacialis
# 13                atlantic cod                Gadus morhua
#
#                              scientificNameID   taxonRank   kingdom  \
# 0     urn:lsid:marinespecies.org:taxname:2688  Infraorder  Animalia
# 1   urn:lsid:marinespecies.org:taxname:137090     Species  Animalia
# 2   urn:lsid:marinespecies.org:taxname:274833     Species  Animalia
# 3   urn:lsid:marinespecies.org:taxname:137091     Species  Animalia
# 4   urn:lsid:marinespecies.org:taxname:148736  Infraorder  Animalia
# 5   urn:lsid:marinespecies.org:taxname:159354     Species  Animalia
# 6   urn:lsid:marinespecies.org:taxname:137088     Species  Animalia
# 7   urn:lsid:marinespecies.org:taxname:159231     Species  Animalia
# 8   urn:lsid:marinespecies.org:taxname:137092     Species  Animalia
# 9   urn:lsid:marinespecies.org:taxname:137102     Species  Animalia
# 10  urn:lsid:marinespecies.org:taxname:137087     Species  Animalia
# 11  urn:lsid:marinespecies.org:taxname:275658     Species  Animalia
# 12  urn:lsid:marinespecies.org:taxname:159023     Species  Animalia
# 13  urn:lsid:marinespecies.org:taxname:126436     Species  Animalia
#
#     propagationFrequency
# 0                   5000
# 1                     63
# 2                    300
# 3                     20
# 4                   1000
# 5                    125
# 6                     63
# 7                    125
# 8                    300
# 9                   1000
# 10                    20
# 11                   300
# 12                    63
# 13                    63

# %% [markdown]
# Now lets add in the WoRMS mapping for species information.

# %%
# merge in the WoRMS species information
df_presence = df_final.merge(df_mapping, how='left', on='vernacularName')  

df_presence.sample(5)
# Out:
#        start_time  dolphin_presence                        dataset_id  \
# 324893        NaT               NaN  noaaSanctSound_CI04_08_bluewhale
# 388404        NaT               NaN  noaaSanctSound_MB01_03_bluewhale
# 206128        NaT               NaN  noaaSanctSound_CI04_05_bluewhale
# 400416        NaT               NaN  noaaSanctSound_MB01_03_bluewhale
# 167845        NaT               NaN  noaaSanctSound_CI04_03_bluewhale
#
#                               WKT decimalLatitude decimalLongitude  \
# 324893  POINT (33.8485 -120.1159)         33.8485        -120.1159
# 388404    POINT (36.798 -121.976)          36.798         -121.976
# 206128  POINT (33.8489 -120.1171)         33.8489        -120.1171
# 400416    POINT (36.798 -121.976)          36.798         -121.976
# 167845  POINT (33.84888 -120.117)        33.84888         -120.117
#
#        vernacularName                    time  bluewhale_presence  \
# 324893     blue whale 2021-10-08 08:24:51.480                 1.0
# 388404     blue whale 2019-11-16 17:29:12.576                 1.0
# 206128     blue whale 2020-08-06 06:44:04.040                 1.0
# 400416     blue whale 2019-12-19 16:32:50.072                 1.0
# 167845     blue whale 2019-09-27 11:43:21.720                 1.0
#
#         bluewhale_manual_presence  ...  humpbackwhale_presence  \
# 324893                        NaN  ...                     NaN
# 388404                        NaN  ...                     NaN
# 206128                        NaN  ...                     NaN
# 400416                        NaN  ...                     NaN
# 167845                        NaN  ...                     NaN
#
#         killerwhale_presence  minkewhale_presence  \
# 324893                   NaN                  NaN
# 388404                   NaN                  NaN
# 206128                   NaN                  NaN
# 400416                   NaN                  NaN
# 167845                   NaN                  NaN
#
#         plainfinmidshipman_presence  northatlanticrightwhale_presence  \
# 324893                          NaN                               NaN
# 388404                          NaN                               NaN
# 206128                          NaN                               NaN
# 400416                          NaN                               NaN
# 167845                          NaN                               NaN
#
#                scientificName                           scientificNameID  \
# 324893  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 388404  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 206128  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 400416  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 167845  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
#
#         taxonRank   kingdom  propagationFrequency
# 324893    Species  Animalia                    63
# 388404    Species  Animalia                    63
# 206128    Species  Animalia                    63
# 400416    Species  Animalia                    63
# 167845    Species  Animalia                    63
#
# [5 rows x 27 columns]

# %%
df_presence.columns
# Out:
# Index(['start_time', 'dolphin_presence', 'dataset_id', 'WKT',
#        'decimalLatitude', 'decimalLongitude', 'vernacularName', 'time',
#        'bluewhale_presence', 'bluewhale_manual_presence', 'bocaccio_presence',
#        'finwhale_presence', 'pinniped_presence', 'redgrouper_detection_count',
#        'seiwhale_presence', 'atlanticcod_presence',
#        'blackgrouper_detection_count', 'humpbackwhale_presence',
#        'killerwhale_presence', 'minkewhale_presence',
#        'plainfinmidshipman_presence', 'northatlanticrightwhale_presence',
#        'scientificName', 'scientificNameID', 'taxonRank', 'kingdom',
#        'propagationFrequency'],
#       dtype='object')

# %% [markdown]
# ## Determining `time`
#
# Okay, we have two time variables:
# `start_time`, and `time`
#
# We need to make one `eventDate`!
#
# Let's first check to see if we can mash things together.
#
# First, lets print out all the times when `time` has an entry:

# %%
df_presence.loc[df_presence['time'].notna(),['start_time','time']].sample(20)
# Out:
#        start_time                          time
# 336825        NaT 2019-07-25 19:24:07.336000000
# 284062        NaT 2021-07-09 20:22:54.752000000
# 380509        NaT 2019-11-05 13:28:09.000000000
# 274011        NaT 2020-12-15 11:07:25.736000000
# 357635        NaT 2019-09-07 19:34:46.648000000
# 60865         NaT 2020-11-01 04:01:27.480000000
# 561094        NaT 2020-08-02 07:13:59.648000000
# 597312        NaT 2021-01-16 13:41:41.600000256
# 126411        NaT 2019-07-21 11:27:18.424000000
# 355014        NaT 2018-12-04 15:20:52.496000000
# 601865        NaT 2019-12-04 21:24:40.016000000
# 251633        NaT 2020-10-22 08:00:23.232000000
# 292879        NaT 2021-07-29 11:51:11.168000000
# 557598        NaT 2019-12-20 20:45:11.312000000
# 89091         NaT 2021-08-23 22:43:00.272000000
# 83863         NaT 2021-08-07 00:25:15.880000000
# 184994        NaT 2019-11-08 06:23:41.688000000
# 342157        NaT 2021-07-18 14:58:42.000000000
# 227949        NaT 2020-09-11 02:25:37.776000000
# 48193         NaT 2020-10-07 19:16:28.760000000

# %% [markdown]
# Okay, so let's see if `start_time` is only NaN for all those rows:

# %%
df_presence.loc[df_presence['time'].notna(),'start_time'].unique()
# Out:
# array(['NaT'], dtype='datetime64[ns]')

# %% [markdown]
# Looking good! We have only NaN's returned so we don't have conflicting dates between `start_time` and `time`.

# %% [markdown]
# Fantastic! So, this means we can make a new column for `eventDate` which merges `time` into `start_time`.

# %%
#df_presence_copy = df_presence.copy()

# start eventDate column with values where `time` exists.
df_presence['eventDate'] = df_presence.loc[df_presence['time'].notna(),['time']]

# fillna with values from start_time
df_presence['eventDate'].fillna(df_presence['start_time'], inplace=True)

df_presence[['eventDate','time','start_time']].sample(n=5)
# Out:
#                      eventDate                    time start_time
# 534055 2018-11-28 01:29:19.000 2018-11-28 01:29:19.000        NaT
# 3738   2018-11-01 05:20:32.368 2018-11-01 05:20:32.368        NaT
# 248818 2020-10-13 14:25:34.496 2020-10-13 14:25:34.496        NaT
# 423838 2020-10-09 16:56:23.392 2020-10-09 16:56:23.392        NaT
# 570024 2020-09-12 09:38:16.800 2020-09-12 09:38:16.800        NaT

# %%
df_presence.loc[df_presence['eventDate'].isna()]
# Out:
# Empty DataFrame
# Columns: [start_time, dolphin_presence, dataset_id, WKT, decimalLatitude, decimalLongitude, vernacularName, time, bluewhale_presence, bluewhale_manual_presence, bocaccio_presence, finwhale_presence, pinniped_presence, redgrouper_detection_count, seiwhale_presence, atlanticcod_presence, blackgrouper_detection_count, humpbackwhale_presence, killerwhale_presence, minkewhale_presence, plainfinmidshipman_presence, northatlanticrightwhale_presence, scientificName, scientificNameID, taxonRank, kingdom, propagationFrequency, eventDate]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ## Double check we moved the right values
#
# Show me where `time` is NaN and we used `start_time`.

# %%
df_presence.loc[df_presence['time'].isna(),['start_time','eventDate','time']].sample(5)
# Out:
#                     start_time               eventDate time
# 669263 2019-12-26 10:00:00.000 2019-12-26 10:00:00.000  NaT
# 676601 2019-08-09 19:00:00.000 2019-08-09 19:00:00.000  NaT
# 501325 2021-11-01 07:42:52.864 2021-11-01 07:42:52.864  NaT
# 686945 2020-10-24 13:00:00.000 2020-10-24 13:00:00.000  NaT
# 628795 2020-04-21 09:23:47.588 2020-04-21 09:23:47.588  NaT

# %% [markdown]
# Show me where `start_time` is NaN and we used `time`.

# %%
df_presence.loc[df_presence['start_time'].isna(),['start_time','eventDate','time']].sample(5)
# Out:
#        start_time               eventDate                    time
# 179513        NaT 2019-10-27 09:29:26.232 2019-10-27 09:29:26.232
# 274753        NaT 2020-12-19 01:59:50.824 2020-12-19 01:59:50.824
# 7047          NaT 2019-07-10 04:23:29.624 2019-07-10 04:23:29.624
# 525758        NaT 2020-01-11 21:59:55.176 2020-01-11 21:59:55.176
# 157595        NaT 2019-08-26 14:57:15.632 2019-08-26 14:57:15.632

# %% [markdown]
# Now, lets make `eventDate` the index for our DataFrame so we can make a nice plot and output the dates in a format we like.

# %%
df_presence['eventDate'] = pd.to_datetime(df_presence['eventDate'], format='%Y-%m-%d %H:%M:%S.%f')

df_presence
# Out:
#                 start_time  dolphin_presence  \
# 0      2018-12-15 04:00:00               1.0
# 1      2018-12-15 05:00:00               1.0
# 2      2018-12-15 06:00:00               1.0
# 3      2018-12-15 07:00:00               1.0
# 4      2018-12-15 18:00:00               1.0
# ...                    ...               ...
# 713671 2020-11-18 00:00:00               NaN
# 713672 2020-11-19 00:00:00               NaN
# 713673 2020-11-20 00:00:00               NaN
# 713674 2020-11-21 00:00:00               NaN
# 713675 2020-11-22 00:00:00               NaN
#
#                                 dataset_id                          WKT  \
# 0       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 1       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 2       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 3       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 4       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# ...                                    ...                          ...
# 713671  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713672  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713673  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713674  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713675  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
#
#        decimalLatitude decimalLongitude vernacularName time  \
# 0            31.396417         -80.8904        dolphin  NaT
# 1            31.396417         -80.8904        dolphin  NaT
# 2            31.396417         -80.8904        dolphin  NaT
# 3            31.396417         -80.8904        dolphin  NaT
# 4            31.396417         -80.8904        dolphin  NaT
# ...                ...              ...            ...  ...
# 713671        42.25508       -70.179047      fin whale  NaT
# 713672        42.25508       -70.179047      fin whale  NaT
# 713673        42.25508       -70.179047      fin whale  NaT
# 713674        42.25508       -70.179047      fin whale  NaT
# 713675        42.25508       -70.179047      fin whale  NaT
#
#         bluewhale_presence  bluewhale_manual_presence  ...  \
# 0                      NaN                        NaN  ...
# 1                      NaN                        NaN  ...
# 2                      NaN                        NaN  ...
# 3                      NaN                        NaN  ...
# 4                      NaN                        NaN  ...
# ...                    ...                        ...  ...
# 713671                 NaN                        NaN  ...
# 713672                 NaN                        NaN  ...
# 713673                 NaN                        NaN  ...
# 713674                 NaN                        NaN  ...
# 713675                 NaN                        NaN  ...
#
#         killerwhale_presence  minkewhale_presence  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
# ...                      ...                  ...
# 713671                   NaN                  NaN
# 713672                   NaN                  NaN
# 713673                   NaN                  NaN
# 713674                   NaN                  NaN
# 713675                   NaN                  NaN
#
#         plainfinmidshipman_presence  northatlanticrightwhale_presence  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 713671                          NaN                               NaN
# 713672                          NaN                               NaN
# 713673                          NaN                               NaN
# 713674                          NaN                               NaN
# 713675                          NaN                               NaN
#
#                scientificName                           scientificNameID  \
# 0                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 1                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 2                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 3                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 4                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# ...                       ...                                        ...
# 713671  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713672  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713673  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713674  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713675  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
#
#          taxonRank   kingdom  propagationFrequency           eventDate
# 0       Infraorder  Animalia                  5000 2018-12-15 04:00:00
# 1       Infraorder  Animalia                  5000 2018-12-15 05:00:00
# 2       Infraorder  Animalia                  5000 2018-12-15 06:00:00
# 3       Infraorder  Animalia                  5000 2018-12-15 07:00:00
# 4       Infraorder  Animalia                  5000 2018-12-15 18:00:00
# ...            ...       ...                   ...                 ...
# 713671     Species  Animalia                    20 2020-11-18 00:00:00
# 713672     Species  Animalia                    20 2020-11-19 00:00:00
# 713673     Species  Animalia                    20 2020-11-20 00:00:00
# 713674     Species  Animalia                    20 2020-11-21 00:00:00
# 713675     Species  Animalia                    20 2020-11-22 00:00:00
#
# [713676 rows x 28 columns]

# %% [markdown]
# ## Write presence file

# %%
# overwrite to csv file
fname = 'data/sanctsound_presence.zip'
df_presence.to_csv(fname, index=False, compression='zip')

df_presence.sample(n=5)
# Out:
#                 start_time  dolphin_presence  \
# 521618                 NaT               NaN
# 333844                 NaT               NaN
# 420311                 NaT               NaN
# 590136                 NaT               NaN
# 2110   2021-01-29 02:00:00               1.0
#
#                                 dataset_id                           WKT  \
# 521618    noaaSanctSound_MB02_04_bluewhale     POINT (36.6495 -121.9084)
# 333844    noaaSanctSound_CI04_08_bluewhale     POINT (33.8485 -120.1159)
# 420311    noaaSanctSound_MB01_06_bluewhale     POINT (36.7977 -121.9757)
# 590136    noaaSanctSound_MB03_04_bluewhale  POINT (36.37021 -122.314903)
# 2110    noaaSanctSound_GR02_05_dolphins_1h  POINT (31.376133 -80.839133)
#
#        decimalLatitude decimalLongitude vernacularName  \
# 521618         36.6495        -121.9084     blue whale
# 333844         33.8485        -120.1159     blue whale
# 420311         36.7977        -121.9757     blue whale
# 590136        36.37021      -122.314903     blue whale
# 2110         31.376133       -80.839133        dolphin
#
#                           time  bluewhale_presence  bluewhale_manual_presence  \
# 521618 2019-12-21 21:21:31.000                 1.0                        NaN
# 333844 2021-11-02 11:02:30.296                 1.0                        NaN
# 420311 2020-10-02 07:30:31.784                 1.0                        NaN
# 590136 2020-11-27 04:18:51.488                 1.0                        NaN
# 2110                       NaT                 NaN                        NaN
#
#         ...  killerwhale_presence  minkewhale_presence  \
# 521618  ...                   NaN                  NaN
# 333844  ...                   NaN                  NaN
# 420311  ...                   NaN                  NaN
# 590136  ...                   NaN                  NaN
# 2110    ...                   NaN                  NaN
#
#         plainfinmidshipman_presence  northatlanticrightwhale_presence  \
# 521618                          NaN                               NaN
# 333844                          NaN                               NaN
# 420311                          NaN                               NaN
# 590136                          NaN                               NaN
# 2110                            NaN                               NaN
#
#                scientificName                           scientificNameID  \
# 521618  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 333844  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 420311  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 590136  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 2110                  Cetacea    urn:lsid:marinespecies.org:taxname:2688
#
#          taxonRank   kingdom  propagationFrequency               eventDate
# 521618     Species  Animalia                    63 2019-12-21 21:21:31.000
# 333844     Species  Animalia                    63 2021-11-02 11:02:30.296
# 420311     Species  Animalia                    63 2020-10-02 07:30:31.784
# 590136     Species  Animalia                    63 2020-11-27 04:18:51.488
# 2110    Infraorder  Animalia                  5000 2021-01-29 02:00:00.000
#
# [5 rows x 28 columns]
