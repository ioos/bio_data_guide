# %% [markdown]
# # Sound production to presence
#
# This notebook uses the coastwatch erddap to collect species presence information from SanctSound sound production datasets.
#
# It creates a `sanctsound_presence.zip` file that contains when animals were acoustically present at a specific time and location.
#
# The notebook `presence_to_occurrence.ipynb` reads the results of this notebook and converts them to an occurrence table.
# The notebook `sound_propagation_processing.ipynb` reads the occurrence table and adds information about the coordinateUncertainty from sound propagation modeling data.
#
#
# Let's search the [Coastwatch ERDDAP](https://coastwatch.pfeg.noaa.gov/erddap/index.html) for datasets that contain the following information:
#
# ```
# sanctsound "Sound Production"
# ```

# %%
import erddapy

erddapy.__version__
# Out:
# '2.0.1'

# %%
from erddapy import ERDDAP
import pandas as pd

server = "https://coastwatch.pfeg.noaa.gov/erddap/"

protocol = "griddap"

search_for = 'sanctsound "Sound Production"'

e = ERDDAP(server=server, protocol=protocol)

url = e.get_search_url(search_for=search_for, response="csv")

datasets = pd.read_csv(url)[["Dataset ID","Title"]]

datasets
# Out:
#                              Dataset ID  \
# 0    noaaSanctSound_GR01_01_dolphins_1h
# 1    noaaSanctSound_GR01_02_dolphins_1h
# 2    noaaSanctSound_GR01_03_dolphins_1h
# 3    noaaSanctSound_GR01_04_dolphins_1h
# 4    noaaSanctSound_GR01_05_dolphins_1h
# ..                                  ...
# 690  noaaSanctSound_SB03_08_finwhale_1d
# 691  noaaSanctSound_SB03_09_finwhale_1d
# 692  noaaSanctSound_SB03_10_finwhale_1d
# 693  noaaSanctSound_SB03_11_finwhale_1d
# 694  noaaSanctSound_SB03_12_finwhale_1d
#
#                                                  Title
# 0    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 1    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 2    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 3    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 4    NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# ..                                                 ...
# 690  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 691  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 692  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 693  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
# 694  NOAA-Navy Sanctuary Soundscape Monitoring Proj...
#
# [695 rows x 2 columns]

# %% [markdown]
# # Next let's start building our presence table from each dataset

# %% [markdown]
# Now lets find the `start_time` and `end_time` when animals were present (e.g. `dolphin_presence == 1`).
#
# To do this we look through the variables in the dataset to find the data variable which ends with the phrase `presence` or `detection_count`. This will return the string of the variable name (e.g. `dolphin_presence`). Then, we want to filter the dataset for when that variable only has values equal to 1.0 (or present). Then, we drop any entrys not equal to 1.0.
#
# This returns a filtered xarray dataset of only presence values along with `start_time`, `end_time`, and all the associated metadata.

# %%
# %%time

df_final = pd.DataFrame()

df_broken = pd.DataFrame()

for index, row in datasets.iterrows():
    
    print('\n{}/{} datasets\n'.format(index+1,datasets.shape[0]))
    print('querying {}'.format(row['Dataset ID']))
    
    e.dataset_id = row['Dataset ID']
    
    ds = e.to_xarray()
    
    time_var = list(ds.coords)[0]
    
    print('{} ({} rows): {}'.format(row['Dataset ID'],ds.coords.dims[time_var],ds.geospatial_bounds))
    
    # set up try/except to test for presence vars, skip datasets without them.
    try:
        da = [da for varname, da in ds.data_vars.items() if (varname.endswith("presence") | varname.endswith("detection_count"))][0]
    except:
        
        string = 'Skipping {} - no presence vars'.format(row['Dataset ID'])
        
        df_broke = pd.DataFrame({'Dataset ID': [row['Dataset ID']], 
                                'reason': [string]})
        df_broken = pd.concat([df_broken, df_broke])
        
        continue

    
    # subset to only presences (presence var == 1)
    ds_subset = da[da.values != 0]
    
    # kick out if ds_subset is empty
    if len(ds_subset[time_var]) == 0:
        
        string = '{} obs - moving to next dataset'.format(len(ds_subset[time_var]))
        
        df_broke = pd.DataFrame({'Dataset ID': [row['Dataset ID']], 
                                'reason': [string]})
        
        df_broken = pd.concat([df_broken, df_broke])
        
        continue
        
    df = ds_subset.to_dataframe().reset_index()
    
    print('Subsetted to ({} rows)'.format(len(ds_subset[time_var])))
    
    # Store global attributes as data.
    df['dataset_id'] = row['Dataset ID']
    df['WKT'] = ds.geospatial_bounds
    df['decimalLatitude'] = ds.geospatial_bounds.split(" ")[1].replace("(","")
    df['decimalLongitude'] = ds.geospatial_bounds.split(" ")[2].replace(")","")
    df['vernacularName'] = ds.title.split(",")[1].replace(" Sound Production","").replace(" Sound Producion","").lower().lstrip()
    
    df_final = pd.concat([df_final, df])

print(f'There were {df_broken.shape[0]} datasets that either didn\'t have a presence variable or didn\'t contain presence data')
# Out:
# 1/695 datasets
#
# querying noaaSanctSound_GR01_01_dolphins_1h
# noaaSanctSound_GR01_01_dolphins_1h (3185 rows): POINT (31.396417 -80.8904)
# Subsetted to (191 rows)
#
# 2/695 datasets
#
# querying noaaSanctSound_GR01_02_dolphins_1h
# noaaSanctSound_GR01_02_dolphins_1h (3029 rows): POINT (31.396417 -80.8904)
# Subsetted to (56 rows)
#
# 3/695 datasets
#
# querying noaaSanctSound_GR01_03_dolphins_1h
# noaaSanctSound_GR01_03_dolphins_1h (2532 rows): POINT (31.396417 -80.8904)
# Subsetted to (146 rows)
#
# 4/695 datasets
#
# querying noaaSanctSound_GR01_04_dolphins_1h
# noaaSanctSound_GR01_04_dolphins_1h (2693 rows): POINT (31.396417 -80.8904)
# Subsetted to (110 rows)
#
# 5/695 datasets
#
# querying noaaSanctSound_GR01_05_dolphins_1h
# noaaSanctSound_GR01_05_dolphins_1h (3344 rows): POINT (31.396417 -80.8904)
# Subsetted to (341 rows)
#
# 6/695 datasets
#
# querying noaaSanctSound_GR02_02_dolphins_1h
# noaaSanctSound_GR02_02_dolphins_1h (2741 rows): POINT (31.376133 -80.839133)
# Subsetted to (291 rows)
#
# 7/695 datasets
#
# querying noaaSanctSound_GR02_03_dolphins_1h
# noaaSanctSound_GR02_03_dolphins_1h (2990 rows): POINT (31.376133 -80.839133)
# Subsetted to (339 rows)
#
# 8/695 datasets
#
# querying noaaSanctSound_GR02_05_dolphins_1h
# noaaSanctSound_GR02_05_dolphins_1h (3326 rows): POINT (31.376133 -80.839133)
# Subsetted to (752 rows)
#
# 9/695 datasets
#
# querying noaaSanctSound_GR03_02_dolphins_1h
# noaaSanctSound_GR03_02_dolphins_1h (3022 rows): POINT (31.36749 -80.895)
# Subsetted to (172 rows)
#
# 10/695 datasets
#
# querying noaaSanctSound_GR03_03_dolphins_1h
# noaaSanctSound_GR03_03_dolphins_1h (1108 rows): POINT (31.367517 -80.8949)
# Subsetted to (101 rows)
#
# 11/695 datasets
#
# querying noaaSanctSound_GR03_04_dolphins_1h
# noaaSanctSound_GR03_04_dolphins_1h (3364 rows): POINT (31.367517 -80.8949)
# Subsetted to (499 rows)
#
# 12/695 datasets
#
# querying noaaSanctSound_GR03_05_dolphins_1h
# noaaSanctSound_GR03_05_dolphins_1h (2785 rows): POINT (31.367517 -80.8949)
# Subsetted to (449 rows)
#
# 13/695 datasets
#
# querying noaaSanctSound_CI01_01_bluewhale
# noaaSanctSound_CI01_01_bluewhale (49 rows): POINT (34.0438 -120.0811)
# Subsetted to (49 rows)
#
# 14/695 datasets
#
# querying noaaSanctSound_CI01_02_bluewhale
# noaaSanctSound_CI01_02_bluewhale (24 rows): POINT (34.0438 -120.08105)
# Subsetted to (24 rows)
#
# 15/695 datasets
#
# querying noaaSanctSound_CI01_03_bluewhale
# noaaSanctSound_CI01_03_bluewhale (1 rows): POINT (34.04383 -120.081)
#
# 16/695 datasets
#
# querying noaaSanctSound_CI01_04_bluewhale_manual
# noaaSanctSound_CI01_04_bluewhale_manual (1 rows): POINT (34.04363 -120.08073)
#
# 17/695 datasets
#
# querying noaaSanctSound_CI01_05_bluewhale_manual
# noaaSanctSound_CI01_05_bluewhale_manual (123 rows): POINT (34.0463 -120.08073)
# Subsetted to (123 rows)
#
# 18/695 datasets
#
# querying noaaSanctSound_CI01_06_bluewhale_manual
# noaaSanctSound_CI01_06_bluewhale_manual (48 rows): POINT (34.0438 -120.081)
# Subsetted to (48 rows)
#
# 19/695 datasets
#
# querying noaaSanctSound_CI01_07_bluewhale_manual
# noaaSanctSound_CI01_07_bluewhale_manual (1 rows): POINT (34.04358 -120.06702)
#
# 20/695 datasets
#
# querying noaaSanctSound_CI01_08_bluewhale_manual
# noaaSanctSound_CI01_08_bluewhale_manual (1 rows): POINT (34.0436 -120.0803)
#
# 21/695 datasets
#
# querying noaaSanctSound_CI02_01_bluewhale
# noaaSanctSound_CI02_01_bluewhale (2572 rows): POINT (34.0856 -120.5232)
# Subsetted to (2572 rows)
#
# 22/695 datasets
#
# querying noaaSanctSound_CI02_02_bluewhale
# noaaSanctSound_CI02_02_bluewhale (1333 rows): POINT (34.0854 -120.5233)
# Subsetted to (1333 rows)
#
# 23/695 datasets
#
# querying noaaSanctSound_CI02_04_bluewhale_manual
# noaaSanctSound_CI02_04_bluewhale_manual (1 rows): POINT (34.08532 -120.523)
#
# 24/695 datasets
#
# querying noaaSanctSound_CI02_05_bluewhale
# noaaSanctSound_CI02_05_bluewhale (49322 rows): POINT (34.0853 -120.5223)
# Subsetted to (49322 rows)
#
# 25/695 datasets
#
# querying noaaSanctSound_CI02_06_bluewhale
# noaaSanctSound_CI02_06_bluewhale (7946 rows): POINT (34.08523 -120.0957)
# Subsetted to (7946 rows)
#
# 26/695 datasets
#
# querying noaaSanctSound_CI02_07_bluewhale
# noaaSanctSound_CI02_07_bluewhale (42237 rows): POINT (34.0855 -120.5224)
# Subsetted to (42237 rows)
#
# 27/695 datasets
#
# querying noaaSanctSound_CI03_02_bluewhale_manual
# noaaSanctSound_CI03_02_bluewhale_manual (1 rows): POINT (33.48687 -119.01609)
#
# 28/695 datasets
#
# querying noaaSanctSound_CI03_03_bluewhale_manual
# noaaSanctSound_CI03_03_bluewhale_manual (1 rows): POINT (33.48687 -119.01609)
#
# 29/695 datasets
#
# querying noaaSanctSound_CI03_04_bluewhale_manual
# noaaSanctSound_CI03_04_bluewhale_manual (512 rows): POINT (33.48675 -119.01607)
# Subsetted to (512 rows)
#
# 30/695 datasets
#
# querying noaaSanctSound_CI03_05_bluewhale_manual
# noaaSanctSound_CI03_05_bluewhale_manual (2 rows): POINT (33.48675 -119.01607)
# Subsetted to (2 rows)
#
# 31/695 datasets
#
# querying noaaSanctSound_CI03_06_bluewhale_manual
# noaaSanctSound_CI03_06_bluewhale_manual (3 rows): POINT (33.4868 -119.016)
# Subsetted to (3 rows)
#
# 32/695 datasets
#
# querying noaaSanctSound_CI03_07_bluewhale_manual
# noaaSanctSound_CI03_07_bluewhale_manual (24 rows): POINT (33.4868 -119.0159)
# Subsetted to (24 rows)
#
# 33/695 datasets
#
# querying noaaSanctSound_CI04_01_bluewhale
# noaaSanctSound_CI04_01_bluewhale (7509 rows): POINT (33.849 -120.118)
# Subsetted to (7509 rows)
#
# 34/695 datasets
#
# querying noaaSanctSound_CI04_02_bluewhale
# noaaSanctSound_CI04_02_bluewhale (32790 rows): POINT (33.8489 -120.1175)
# Subsetted to (32790 rows)
#
# 35/695 datasets
#
# querying noaaSanctSound_CI04_03_bluewhale
# noaaSanctSound_CI04_03_bluewhale (46848 rows): POINT (33.84888 -120.117)
# Subsetted to (46848 rows)
#
# 36/695 datasets
#
# querying noaaSanctSound_CI04_04_bluewhale_manual
# noaaSanctSound_CI04_04_bluewhale_manual (1 rows): POINT (33.84888 -120.117)
#
# 37/695 datasets
#
# querying noaaSanctSound_CI04_05_bluewhale
# noaaSanctSound_CI04_05_bluewhale (56884 rows): POINT (33.8489 -120.1171)
# Subsetted to (56884 rows)
#
# 38/695 datasets
#
# querying noaaSanctSound_CI04_06_bluewhale
# noaaSanctSound_CI04_06_bluewhale (27060 rows): POINT (33.8489 -120.1174)
# Subsetted to (27060 rows)
#
# 39/695 datasets
#
# querying noaaSanctSound_CI04_07_bluewhale
# noaaSanctSound_CI04_07_bluewhale (15008 rows): POINT (33.84853 -120.1161)
# Subsetted to (15008 rows)
#
# 40/695 datasets
#
# querying noaaSanctSound_CI04_08_bluewhale
# noaaSanctSound_CI04_08_bluewhale (42778 rows): POINT (33.8485 -120.1159)
# Subsetted to (42778 rows)
#
# 41/695 datasets
#
# querying noaaSanctSound_CI05_01_bluewhale
# noaaSanctSound_CI05_01_bluewhale (212 rows): POINT (34.0178 -119.3172)
# Subsetted to (212 rows)
#
# 42/695 datasets
#
# querying noaaSanctSound_CI05_02_bluewhale
# noaaSanctSound_CI05_02_bluewhale (147 rows): POINT (34.0178 -119.3172)
# Subsetted to (147 rows)
#
# 43/695 datasets
#
# querying noaaSanctSound_CI05_03_bluewhale
# noaaSanctSound_CI05_03_bluewhale (846 rows): POINT (34.0178 -119.317)
# Subsetted to (846 rows)
#
# 44/695 datasets
#
# querying noaaSanctSound_CI05_04_bluewhale_manual
# noaaSanctSound_CI05_04_bluewhale_manual (1 rows): POINT (34.0178 -119.317)
#
# 45/695 datasets
#
# querying noaaSanctSound_CI05_05_bluewhale_manual
# noaaSanctSound_CI05_05_bluewhale_manual (1 rows): POINT (34.01785 -119.3171)
#
# 46/695 datasets
#
# querying noaaSanctSound_CI05_06_bluewhale
# noaaSanctSound_CI05_06_bluewhale (3693 rows): POINT (34.0178 -119.3171)
# Subsetted to (3693 rows)
#
# 47/695 datasets
#
# querying noaaSanctSound_CI05_07_bluewhale_manual
# noaaSanctSound_CI05_07_bluewhale_manual (1 rows): POINT (34.01778 -119.31707)
#
# 48/695 datasets
#
# querying noaaSanctSound_CI05_08_bluewhale
# noaaSanctSound_CI05_08_bluewhale (11180 rows): POINT (34.018 -119.3168)
# Subsetted to (11180 rows)
#
# 49/695 datasets
#
# querying noaaSanctSound_FK01_01_bluewhale_1d
# noaaSanctSound_FK01_01_bluewhale_1d (123 rows): POINT (24.43313 -81.93068)
#
# 50/695 datasets
#
# querying noaaSanctSound_FK02_01_bluewhale_1d
# noaaSanctSound_FK02_01_bluewhale_1d (125 rows): POINT (24.4888 -81.666316)
#
# 51/695 datasets
#
# querying noaaSanctSound_FK03_01_bluewhale_1d
# noaaSanctSound_FK03_01_bluewhale_1d (128 rows): POINT (24.45895 -81.774133)
#
# 52/695 datasets
#
# querying noaaSanctSound_GR01_01_bluewhale_1d
# noaaSanctSound_GR01_01_bluewhale_1d (140 rows): POINT (31.396417 -80.8904)
#
# 53/695 datasets
#
# querying noaaSanctSound_GR01_02_bluewhale_1d
# noaaSanctSound_GR01_02_bluewhale_1d (143 rows): POINT (31.396417 -80.8904)
#
# 54/695 datasets
#
# querying noaaSanctSound_GR02_02_bluewhale_1d
# noaaSanctSound_GR02_02_bluewhale_1d (134 rows): POINT (31.376133 -80.839133)
#
# 55/695 datasets
#
# querying noaaSanctSound_GR03_02_bluewhale_1d
# noaaSanctSound_GR03_02_bluewhale_1d (131 rows): POINT (31.36749 -80.895)
#
# 56/695 datasets
#
# querying noaaSanctSound_MB01_01_bluewhale
# noaaSanctSound_MB01_01_bluewhale (4260 rows): POINT (36.798 -121.976)
# Subsetted to (4260 rows)
#
# 57/695 datasets
#
# querying noaaSanctSound_MB01_02_bluewhale_manual
# noaaSanctSound_MB01_02_bluewhale_manual (331 rows): POINT (36.798 -121.976)
# Subsetted to (331 rows)
#
# 58/695 datasets
#
# querying noaaSanctSound_MB01_03_bluewhale
# noaaSanctSound_MB01_03_bluewhale (43418 rows): POINT (36.798 -121.976)
# Subsetted to (43418 rows)
#
# 59/695 datasets
#
# querying noaaSanctSound_MB01_04_bluewhale
# noaaSanctSound_MB01_04_bluewhale (3587 rows): POINT (36.798 -121.976)
# Subsetted to (3587 rows)
#
# 60/695 datasets
#
# querying noaaSanctSound_MB01_05_bluewhale
# noaaSanctSound_MB01_05_bluewhale (6034 rows): POINT (36.7977 -121.9757)
# Subsetted to (6034 rows)
#
# 61/695 datasets
#
# querying noaaSanctSound_MB01_06_bluewhale
# noaaSanctSound_MB01_06_bluewhale (44236 rows): POINT (36.7977 -121.9757)
# Subsetted to (44236 rows)
#
# 62/695 datasets
#
# querying noaaSanctSound_MB01_07_bluewhale
# noaaSanctSound_MB01_07_bluewhale (17338 rows): POINT (36.81467 -121.97593)
# Subsetted to (17338 rows)
#
# 63/695 datasets
#
# querying noaaSanctSound_MB01_08_bluewhale_manual
# noaaSanctSound_MB01_08_bluewhale_manual (12 rows): POINT (36.798 -121.97607)
# Subsetted to (12 rows)
#
# 64/695 datasets
#
# querying noaaSanctSound_MB01_09_bluewhale
# noaaSanctSound_MB01_09_bluewhale (33737 rows): POINT (36.798 -122.9758)
# Subsetted to (33737 rows)
#
# 65/695 datasets
#
# querying noaaSanctSound_MB02_01_bluewhale
# noaaSanctSound_MB02_01_bluewhale (2037 rows): POINT (36.648 -121.9084)
# Subsetted to (2037 rows)
#
# 66/695 datasets
#
# querying noaaSanctSound_MB02_02_bluewhale
# noaaSanctSound_MB02_02_bluewhale (1 rows): POINT (36.6495 -121.9084)
#
# 67/695 datasets
#
# querying noaaSanctSound_MB02_03_bluewhale
# noaaSanctSound_MB02_03_bluewhale (13929 rows): POINT (36.6495 -121.9084)
# Subsetted to (13929 rows)
#
# 68/695 datasets
#
# querying noaaSanctSound_MB02_04_bluewhale
# noaaSanctSound_MB02_04_bluewhale (5780 rows): POINT (36.6495 -121.9084)
# Subsetted to (5780 rows)
#
# 69/695 datasets
#
# querying noaaSanctSound_MB02_05_bluewhale
# noaaSanctSound_MB02_05_bluewhale (2509 rows): POINT (36.6484 -121.9075)
# Subsetted to (2509 rows)
#
# 70/695 datasets
#
# querying noaaSanctSound_MB02_07_bluewhale
# noaaSanctSound_MB02_07_bluewhale (3441 rows): POINT (36.64798 -121.90792)
# Subsetted to (3441 rows)
#
# 71/695 datasets
#
# querying noaaSanctSound_MB03_01_disk01_bluewhale
# noaaSanctSound_MB03_01_disk01_bluewhale (2609 rows): POINT (36.3703 -122.3148)
# Subsetted to (2609 rows)
#
# 72/695 datasets
#
# querying noaaSanctSound_MB03_01_disk02_bluewhale
# noaaSanctSound_MB03_01_disk02_bluewhale (3 rows): POINT (36.3703 -122.3148)
# Subsetted to (3 rows)
#
# 73/695 datasets
#
# querying noaaSanctSound_MB03_01_disk1_bluewhale
# noaaSanctSound_MB03_01_disk1_bluewhale (2609 rows): POINT (36.3703 -122.3148)
# Subsetted to (2609 rows)
#
# 74/695 datasets
#
# querying noaaSanctSound_MB03_01_disk2_bluewhale
# noaaSanctSound_MB03_01_disk2_bluewhale (3 rows): POINT (36.3703 -122.3148)
# Subsetted to (3 rows)
#
# 75/695 datasets
#
# querying noaaSanctSound_MB03_01_disk3_bluewhale
# noaaSanctSound_MB03_01_disk3_bluewhale (1 rows): POINT (36.3703 -122.3148)
#
# 76/695 datasets
#
# querying noaaSanctSound_MB03_01_disk4_bluewhale
# noaaSanctSound_MB03_01_disk4_bluewhale (1 rows): POINT (36.3703 -122.3148)
#
# 77/695 datasets
#
# querying noaaSanctSound_MB03_02_bluewhale
# noaaSanctSound_MB03_02_bluewhale (20394 rows): POINT (36.37021 -122.314903)
# Subsetted to (20394 rows)
#
# 78/695 datasets
#
# querying noaaSanctSound_MB03_03_bluewhale
# noaaSanctSound_MB03_03_bluewhale (18245 rows): POINT (36.37021 -122.314903)
# Subsetted to (18245 rows)
#
# 79/695 datasets
#
# querying noaaSanctSound_MB03_04_bluewhale
# noaaSanctSound_MB03_04_bluewhale (22061 rows): POINT (36.37021 -122.314903)
# Subsetted to (22061 rows)
#
# 80/695 datasets
#
# querying noaaSanctSound_OC01_01_bluewhale
# noaaSanctSound_OC01_01_bluewhale (1 rows): POINT (48.3938 -124.654)
#
# 81/695 datasets
#
# querying noaaSanctSound_OC01_03_bluewhale_manual
# noaaSanctSound_OC01_03_bluewhale_manual (1 rows): POINT (48.3938 -124.62067)
#
# 82/695 datasets
#
# querying noaaSanctSound_OC02_01_bluewhale
# noaaSanctSound_OC02_01_bluewhale (1 rows): POINT (48.4904 -125.0038)
#
# 83/695 datasets
#
# querying noaaSanctSound_OC02_02_bluewhale_manual
# noaaSanctSound_OC02_02_bluewhale_manual (101 rows): POINT (48.4905 -125.0039)
# Subsetted to (101 rows)
#
# 84/695 datasets
#
# querying noaaSanctSound_OC02_04_bluewhale_manual
# noaaSanctSound_OC02_04_bluewhale_manual (1 rows): POINT (48.4903 -125.0037)
#
# 85/695 datasets
#
# querying noaaSanctSound_OC02_05_bluewhale_manual
# noaaSanctSound_OC02_05_bluewhale_manual (1 rows): POINT (48.49045 -124.0035)
#
# 86/695 datasets
#
# querying noaaSanctSound_OC03_02_bluewhale
# noaaSanctSound_OC03_02_bluewhale (3363 rows): POINT (47.3179 -124.4166)
# Subsetted to (3363 rows)
#
# 87/695 datasets
#
# querying noaaSanctSound_OC03_03_bluewhale
# noaaSanctSound_OC03_03_bluewhale (81 rows): POINT (47.3179 -124.4166)
# Subsetted to (81 rows)
#
# 88/695 datasets
#
# querying noaaSanctSound_OC03_04_bluewhale
# noaaSanctSound_OC03_04_bluewhale (1 rows): POINT (47.3175 -124.4146)
#
# 89/695 datasets
#
# querying noaaSanctSound_OC04_02_bluewhale
# noaaSanctSound_OC04_02_bluewhale (1 rows): POINT (48.0378 -124.7285)
#
# 90/695 datasets
#
# querying noaaSanctSound_OC04_04_bluewhale
# noaaSanctSound_OC04_04_bluewhale (131 rows): POINT (48.0378 -124.72845)
# Subsetted to (131 rows)
#
# 91/695 datasets
#
# querying noaaSanctSound_SB01_01_bluewhale_1d
# noaaSanctSound_SB01_01_bluewhale_1d (78 rows): POINT (42.436838 -70.546958)
#
# 92/695 datasets
#
# querying noaaSanctSound_SB01_02_bluewhale_1d
# noaaSanctSound_SB01_02_bluewhale_1d (65 rows): POINT (42.43668 -70.546655)
#
# 93/695 datasets
#
# querying noaaSanctSound_SB01_03_bluewhale_1d
# noaaSanctSound_SB01_03_bluewhale_1d (61 rows): POINT (42.4371 -70.5467833)
#
# 94/695 datasets
#
# querying noaaSanctSound_SB01_04_bluewhale_1d
# noaaSanctSound_SB01_04_bluewhale_1d (63 rows): POINT (42.436795 -70.5464317)
#
# 95/695 datasets
#
# querying noaaSanctSound_SB01_05_bluewhale_1d
# noaaSanctSound_SB01_05_bluewhale_1d (65 rows): POINT (42.436785 -70.546435)
#
# 96/695 datasets
#
# querying noaaSanctSound_SB01_06_bluewhale_1d
# noaaSanctSound_SB01_06_bluewhale_1d (63 rows): POINT (42.4369067 -70.5460133)
#
# 97/695 datasets
#
# querying noaaSanctSound_SB01_07_bluewhale_1d
# noaaSanctSound_SB01_07_bluewhale_1d (57 rows): POINT (42.4369383 -70.54587)
#
# 98/695 datasets
#
# querying noaaSanctSound_SB01_08_bluewhale_1d
# noaaSanctSound_SB01_08_bluewhale_1d (68 rows): POINT (42.4369267 -70.5458567)
#
# 99/695 datasets
#
# querying noaaSanctSound_SB01_09_bluewhale_1d
# noaaSanctSound_SB01_09_bluewhale_1d (67 rows): POINT (42.437243 -70.54595)
#
# 100/695 datasets
#
# querying noaaSanctSound_SB01_10_bluewhale_1d
# noaaSanctSound_SB01_10_bluewhale_1d (64 rows): POINT (42.437455 -70.545987)
#
# 101/695 datasets
#
# querying noaaSanctSound_SB01_11_bluewhale_1d
# noaaSanctSound_SB01_11_bluewhale_1d (35 rows): POINT (42.437835 -70.54602)
#
# 102/695 datasets
#
# querying noaaSanctSound_SB01_12_bluewhale_1d
# noaaSanctSound_SB01_12_bluewhale_1d (67 rows): POINT (42.437805 -70.546112)
#
# 103/695 datasets
#
# querying noaaSanctSound_SB02_01_bluewhale_1d
# noaaSanctSound_SB02_01_bluewhale_1d (78 rows): POINT (42.470793 -70.24294)
#
# 104/695 datasets
#
# querying noaaSanctSound_SB02_02_bluewhale_1d
# noaaSanctSound_SB02_02_bluewhale_1d (65 rows): POINT (42.4708417 -70.24281)
#
# 105/695 datasets
#
# querying noaaSanctSound_SB02_03_bluewhale_1d
# noaaSanctSound_SB02_03_bluewhale_1d (61 rows): POINT (42.4713583 -70.2427633)
#
# 106/695 datasets
#
# querying noaaSanctSound_SB02_04_bluewhale_1d
# noaaSanctSound_SB02_04_bluewhale_1d (63 rows): POINT (42.4708617 -70.2424117)
#
# 107/695 datasets
#
# querying noaaSanctSound_SB02_05_bluewhale_1d
# noaaSanctSound_SB02_05_bluewhale_1d (65 rows): POINT (42.4708733 -70.2423833)
#
# 108/695 datasets
#
# querying noaaSanctSound_SB02_06_bluewhale_1d
# noaaSanctSound_SB02_06_bluewhale_1d (63 rows): POINT (42.47096 -70.242305)
# Subsetted to (7 rows)
#
# 109/695 datasets
#
# querying noaaSanctSound_SB02_07_bluewhale_1d
# noaaSanctSound_SB02_07_bluewhale_1d (57 rows): POINT (42.4709883 -70.2423467)
#
# 110/695 datasets
#
# querying noaaSanctSound_SB02_08_bluewhale_1d
# noaaSanctSound_SB02_08_bluewhale_1d (68 rows): POINT (42.470965 -70.2426433)
#
# 111/695 datasets
#
# querying noaaSanctSound_SB02_09_bluewhale_1d
# noaaSanctSound_SB02_09_bluewhale_1d (67 rows): POINT (42.470708 -70.242457)
#
# 112/695 datasets
#
# querying noaaSanctSound_SB02_10_bluewhale_1d
# noaaSanctSound_SB02_10_bluewhale_1d (64 rows): POINT (42.470772 -70.242258)
#
# 113/695 datasets
#
# querying noaaSanctSound_SB02_11_bluewhale_1d
# noaaSanctSound_SB02_11_bluewhale_1d (35 rows): POINT (42.47099 -70.24229)
#
# 114/695 datasets
#
# querying noaaSanctSound_SB02_12_bluewhale_1d
# noaaSanctSound_SB02_12_bluewhale_1d (67 rows): POINT (42.47083 -70.242287)
#
# 115/695 datasets
#
# querying noaaSanctSound_SB03_01_bluewhale_1d
# noaaSanctSound_SB03_01_bluewhale_1d (78 rows): POINT (42.25541 -70.178607)
#
# 116/695 datasets
#
# querying noaaSanctSound_SB03_02_bluewhale_1d
# noaaSanctSound_SB03_02_bluewhale_1d (65 rows): POINT (42.25539 -70.178843)
#
# 117/695 datasets
#
# querying noaaSanctSound_SB03_03_bluewhale_1d
# noaaSanctSound_SB03_03_bluewhale_1d (61 rows): POINT (42.2554067 -70.17901)
#
# 118/695 datasets
#
# querying noaaSanctSound_SB03_04_bluewhale_1d
# noaaSanctSound_SB03_04_bluewhale_1d (63 rows): POINT (42.2554283 -70.179015)
#
# 119/695 datasets
#
# querying noaaSanctSound_SB03_05_bluewhale_1d
# noaaSanctSound_SB03_05_bluewhale_1d (65 rows): POINT (42.2555167 -70.179065)
#
# 120/695 datasets
#
# querying noaaSanctSound_SB03_06_bluewhale_1d
# noaaSanctSound_SB03_06_bluewhale_1d (63 rows): POINT (42.25553 -70.1789733)
# Subsetted to (4 rows)
#
# 121/695 datasets
#
# querying noaaSanctSound_SB03_07_bluewhale_1d
# noaaSanctSound_SB03_07_bluewhale_1d (29 rows): POINT (42.2553933 -70.1794483)
#
# 122/695 datasets
#
# querying noaaSanctSound_SB03_08_bluewhale_1d
# noaaSanctSound_SB03_08_bluewhale_1d (68 rows): POINT (42.255235 -70.1796283)
#
# 123/695 datasets
#
# querying noaaSanctSound_SB03_09_bluewhale_1d
# noaaSanctSound_SB03_09_bluewhale_1d (67 rows): POINT (42.254995 -70.17908)
#
# 124/695 datasets
#
# querying noaaSanctSound_SB03_10_bluewhale_1d
# noaaSanctSound_SB03_10_bluewhale_1d (64 rows): POINT (42.254985 -70.179125)
#
# 125/695 datasets
#
# querying noaaSanctSound_SB03_11_bluewhale_1d
# noaaSanctSound_SB03_11_bluewhale_1d (35 rows): POINT (42.25512 -70.178928)
#
# 126/695 datasets
#
# querying noaaSanctSound_SB03_12_bluewhale_1d
# noaaSanctSound_SB03_12_bluewhale_1d (67 rows): POINT (42.25508 -70.179047)
#
# 127/695 datasets
#
# querying noaaSanctSound_CI01_01_bocaccio
# noaaSanctSound_CI01_01_bocaccio (1755 rows): POINT (34.0438 -120.0811)
# Subsetted to (1755 rows)
#
# 128/695 datasets
#
# querying noaaSanctSound_CI01_02_bocaccio
# noaaSanctSound_CI01_02_bocaccio (1167 rows): POINT (34.0438 -120.08105)
# Subsetted to (1167 rows)
#
# 129/695 datasets
#
# querying noaaSanctSound_CI01_03_bocaccio
# noaaSanctSound_CI01_03_bocaccio (180 rows): POINT (34.04383 -120.081)
# Subsetted to (180 rows)
#
# 130/695 datasets
#
# querying noaaSanctSound_CI02_01_bocaccio
# noaaSanctSound_CI02_01_bocaccio (401 rows): POINT (34.0856 -120.5232)
# Subsetted to (401 rows)
#
# 131/695 datasets
#
# querying noaaSanctSound_CI02_02_bocaccio
# noaaSanctSound_CI02_02_bocaccio (1730 rows): POINT (34.0854 -120.5233)
# Subsetted to (1730 rows)
#
# 132/695 datasets
#
# querying noaaSanctSound_CI03_02_bocaccio
# noaaSanctSound_CI03_02_bocaccio (8397 rows): POINT (33.48687 -119.01609)
# Subsetted to (8397 rows)
#
# 133/695 datasets
#
# querying noaaSanctSound_CI03_03_bocaccio
# noaaSanctSound_CI03_03_bocaccio (23497 rows): POINT (33.48687 -119.01609)
# Subsetted to (23497 rows)
#
# 134/695 datasets
#
# querying noaaSanctSound_CI04_01_bocaccio
# noaaSanctSound_CI04_01_bocaccio (166 rows): POINT (33.849 -120.118)
# Subsetted to (166 rows)
#
# 135/695 datasets
#
# querying noaaSanctSound_CI04_02_bocaccio
# noaaSanctSound_CI04_02_bocaccio (1314 rows): POINT (33.8489 -120.1175)
# Subsetted to (1314 rows)
#
# 136/695 datasets
#
# querying noaaSanctSound_CI04_03_bocaccio
# noaaSanctSound_CI04_03_bocaccio (669 rows): POINT (33.84888 -120.117)
# Subsetted to (669 rows)
#
# 137/695 datasets
#
# querying noaaSanctSound_CI05_01_bocaccio
# noaaSanctSound_CI05_01_bocaccio (507 rows): POINT (34.0178 -119.3172)
# Subsetted to (507 rows)
#
# 138/695 datasets
#
# querying noaaSanctSound_CI05_02_bocaccio
# noaaSanctSound_CI05_02_bocaccio (952 rows): POINT (34.0178 -119.3172)
# Subsetted to (952 rows)
#
# 139/695 datasets
#
# querying noaaSanctSound_CI05_03_bocaccio
# noaaSanctSound_CI05_03_bocaccio (54 rows): POINT (34.0178 -119.317)
# Subsetted to (54 rows)
#
# 140/695 datasets
#
# querying noaaSanctSound_MB01_01_bocaccio
# noaaSanctSound_MB01_01_bocaccio (582 rows): POINT (36.798 -121.976)
# Subsetted to (582 rows)
#
# 141/695 datasets
#
# querying noaaSanctSound_MB01_02_bocaccio
# noaaSanctSound_MB01_02_bocaccio (2974 rows): POINT (36.798 -121.976)
# Subsetted to (2974 rows)
#
# 142/695 datasets
#
# querying noaaSanctSound_MB01_03_bocaccio
# noaaSanctSound_MB01_03_bocaccio (8298 rows): POINT (36.798 -121.976)
# Subsetted to (8298 rows)
#
# 143/695 datasets
#
# querying noaaSanctSound_MB02_01_bocaccio
# noaaSanctSound_MB02_01_bocaccio (272 rows): POINT (36.648 -121.9084)
# Subsetted to (272 rows)
#
# 144/695 datasets
#
# querying noaaSanctSound_MB02_02_bocaccio
# noaaSanctSound_MB02_02_bocaccio (588 rows): POINT (36.6495 -121.9084)
# Subsetted to (588 rows)
#
# 145/695 datasets
#
# querying noaaSanctSound_MB02_03_bocaccio
# noaaSanctSound_MB02_03_bocaccio (1653 rows): POINT (36.6495 -121.9084)
# Subsetted to (1653 rows)
#
# 146/695 datasets
#
# querying noaaSanctSound_CI01_02_dolphins_1h
# noaaSanctSound_CI01_02_dolphins_1h (1538 rows): POINT (34.0438 -120.08105)
# Subsetted to (60 rows)
#
# 147/695 datasets
#
# querying noaaSanctSound_CI01_03_dolphins_1h
# noaaSanctSound_CI01_03_dolphins_1h (1353 rows): POINT (34.04383 -120.081)
# Subsetted to (62 rows)
#
# 148/695 datasets
#
# querying noaaSanctSound_CI01_04_dolphins_1h
# noaaSanctSound_CI01_04_dolphins_1h (3089 rows): POINT (34.04363 -120.08073)
# Subsetted to (11 rows)
#
# 149/695 datasets
#
# querying noaaSanctSound_CI02_02_dolphins_1h
# noaaSanctSound_CI02_02_dolphins_1h (1251 rows): POINT (34.0854 -120.5233)
# Subsetted to (88 rows)
#
# 150/695 datasets
#
# querying noaaSanctSound_CI02_04_dolphins_1h
# noaaSanctSound_CI02_04_dolphins_1h (2787 rows): POINT (34.08532 -120.523)
# Subsetted to (34 rows)
#
# 151/695 datasets
#
# querying noaaSanctSound_CI03_02_dolphins_1h
# noaaSanctSound_CI03_02_dolphins_1h (3043 rows): POINT (33.48687 -119.01609)
# Subsetted to (965 rows)
#
# 152/695 datasets
#
# querying noaaSanctSound_CI03_03_dolphins_1h
# noaaSanctSound_CI03_03_dolphins_1h (1799 rows): POINT (33.48687 -119.01609)
# Subsetted to (81 rows)
#
# 153/695 datasets
#
# querying noaaSanctSound_CI04_02_dolphins_1h
# noaaSanctSound_CI04_02_dolphins_1h (1651 rows): POINT (33.8489 -120.1175)
# Subsetted to (872 rows)
#
# 154/695 datasets
#
# querying noaaSanctSound_CI04_03_dolphins_1h
# noaaSanctSound_CI04_03_dolphins_1h (2398 rows): POINT (33.84888 -120.117)
# Subsetted to (1378 rows)
#
# 155/695 datasets
#
# querying noaaSanctSound_CI04_04_dolphins_1h
# noaaSanctSound_CI04_04_dolphins_1h (2688 rows): POINT (33.84888 -120.117)
# Subsetted to (799 rows)
#
# 156/695 datasets
#
# querying noaaSanctSound_CI05_02_dolphins_1h
# noaaSanctSound_CI05_02_dolphins_1h (1377 rows): POINT (34.0178 -119.3172)
# Subsetted to (1317 rows)
#
# 157/695 datasets
#
# querying noaaSanctSound_CI05_03_dolphins_1h
# noaaSanctSound_CI05_03_dolphins_1h (1386 rows): POINT (34.0178 -119.317)
# Subsetted to (1308 rows)
#
# 158/695 datasets
#
# querying noaaSanctSound_CI05_04_dolphins_1h
# noaaSanctSound_CI05_04_dolphins_1h (3325 rows): POINT (34.0178 -119.317)
# Subsetted to (2763 rows)
#
# 159/695 datasets
#
# querying noaaSanctSound_CI05_05_dolphins_1h
# noaaSanctSound_CI05_05_dolphins_1h (194 rows): POINT (34.01785 -119.3171)
# Subsetted to (158 rows)
#
# 160/695 datasets
#
# querying noaaSanctSound_FK01_01_dolphins_1h
# noaaSanctSound_FK01_01_dolphins_1h (632 rows): POINT (24.43313 -81.93068)
# Subsetted to (93 rows)
#
# 161/695 datasets
#
# querying noaaSanctSound_FK01_04_dolphins_1h
# noaaSanctSound_FK01_04_dolphins_1h (2710 rows): POINT (24.43313 -81.93068)
# Subsetted to (219 rows)
#
# 162/695 datasets
#
# querying noaaSanctSound_FK01_06_dolphins_1h
# noaaSanctSound_FK01_06_dolphins_1h (1730 rows): POINT (24.43313 -81.93068)
# Subsetted to (218 rows)
#
# 163/695 datasets
#
# querying noaaSanctSound_FK02_01_dolphins_1h
# noaaSanctSound_FK02_01_dolphins_1h (2970 rows): POINT (24.4888 -81.666316)
# Subsetted to (77 rows)
#
# 164/695 datasets
#
# querying noaaSanctSound_FK02_03_dolphins_1h
# noaaSanctSound_FK02_03_dolphins_1h (2731 rows): POINT (24.4888 -81.666316)
# Subsetted to (56 rows)
#
# 165/695 datasets
#
# querying noaaSanctSound_FK02_04_dolphins_1h
# noaaSanctSound_FK02_04_dolphins_1h (1795 rows): POINT (24.4888 -81.666316)
# Subsetted to (20 rows)
#
# 166/695 datasets
#
# querying noaaSanctSound_FK02_05_dolphins_1h
# noaaSanctSound_FK02_05_dolphins_1h (986 rows): POINT (24.48896 -81.6664)
# Subsetted to (28 rows)
#
# 167/695 datasets
#
# querying noaaSanctSound_FK02_06_dolphins_1h
# noaaSanctSound_FK02_06_dolphins_1h (2868 rows): POINT (24.48896 -81.6664)
# Subsetted to (64 rows)
#
# 168/695 datasets
#
# querying noaaSanctSound_FK03_01_dolphins_1h
# noaaSanctSound_FK03_01_dolphins_1h (3037 rows): POINT (24.45895 -81.774133)
# Subsetted to (222 rows)
#
# 169/695 datasets
#
# querying noaaSanctSound_FK03_03_dolphins_1h
# noaaSanctSound_FK03_03_dolphins_1h (63 rows): POINT (24.45895 -81.774133)
# Subsetted to (2 rows)
#
# 170/695 datasets
#
# querying noaaSanctSound_FK03_04_dolphins_1h
# noaaSanctSound_FK03_04_dolphins_1h (660 rows): POINT (24.45895 -81.774133)
# Subsetted to (18 rows)
#
# 171/695 datasets
#
# querying noaaSanctSound_FK03_05_dolphins_1h
# noaaSanctSound_FK03_05_dolphins_1h (795 rows): POINT (24.45895 -81.774133)
# Subsetted to (52 rows)
#
# 172/695 datasets
#
# querying noaaSanctSound_HI03_02_dolphins_1hr
# noaaSanctSound_HI03_02_dolphins_1hr (4438 rows): POINT (21.28542 -157.60012)
# Subsetted to (2710 rows)
#
# 173/695 datasets
#
# querying noaaSanctSound_HI04_02_dolphins_1hr
# noaaSanctSound_HI04_02_dolphins_1hr (3912 rows): POINT (22.263472 -159.586389)
# Subsetted to (1849 rows)
#
# 174/695 datasets
#
# querying noaaSanctSound_MB01_02_dolphins_1h
# noaaSanctSound_MB01_02_dolphins_1h (1793 rows): POINT (36.798 -121.976)
# Subsetted to (182 rows)
#
# 175/695 datasets
#
# querying noaaSanctSound_MB01_03_dolphins_1h
# noaaSanctSound_MB01_03_dolphins_1h (2878 rows): POINT (36.798 -121.976)
# Subsetted to (845 rows)
#
# 176/695 datasets
#
# querying noaaSanctSound_MB01_04_dolphins_1h
# noaaSanctSound_MB01_04_dolphins_1h (2656 rows): POINT (36.798 -121.976)
# Subsetted to (708 rows)
#
# 177/695 datasets
#
# querying noaaSanctSound_MB01_05_dolphins_1h
# noaaSanctSound_MB01_05_dolphins_1h (1063 rows): POINT (36.7977 -121.9757)
# Subsetted to (166 rows)
#
# 178/695 datasets
#
# querying noaaSanctSound_MB02_02_dolphins_1h
# noaaSanctSound_MB02_02_dolphins_1h (1698 rows): POINT (36.6495 -121.9084)
# Subsetted to (71 rows)
#
# 179/695 datasets
#
# querying noaaSanctSound_MB02_03_dolphins_1h
# noaaSanctSound_MB02_03_dolphins_1h (2867 rows): POINT (36.6495 -121.9084)
# Subsetted to (238 rows)
#
# 180/695 datasets
#
# querying noaaSanctSound_MB02_04_dolphins_1h
# noaaSanctSound_MB02_04_dolphins_1h (2208 rows): POINT (36.6495 -121.9084)
# Subsetted to (261 rows)
#
# 181/695 datasets
#
# querying noaaSanctSound_MB03_01_dolphins_1h
# noaaSanctSound_MB03_01_dolphins_1h (233 rows): POINT (36.3703 -122.3148)
# Subsetted to (81 rows)
#
# 182/695 datasets
#
# querying noaaSanctSound_MB03_02_dolphins_1h
# noaaSanctSound_MB03_02_dolphins_1h (5493 rows): POINT (36.37021 -122.314903)
# Subsetted to (1526 rows)
#
# 183/695 datasets
#
# querying noaaSanctSound_MB03_03_dolphins_1h
# noaaSanctSound_MB03_03_dolphins_1h (1224 rows): POINT (36.37021 -122.314903)
# Subsetted to (225 rows)
#
# 184/695 datasets
#
# querying noaaSanctSound_OC02_02_dolphins_1h
# noaaSanctSound_OC02_02_dolphins_1h (2661 rows): POINT (48.4905 -125.0039)
# Subsetted to (256 rows)
#
# 185/695 datasets
#
# querying noaaSanctSound_PM05_01_dolphins_1h
# noaaSanctSound_PM05_01_dolphins_1h (5578 rows): POINT (24.81682 -168.13411)
# Subsetted to (277 rows)
#
# 186/695 datasets
#
# querying noaaSanctSound_SB01_01_dolphins_1h
# noaaSanctSound_SB01_01_dolphins_1h (1846 rows): POINT (42.436838 -70.546958)
# Subsetted to (262 rows)
#
# 187/695 datasets
#
# querying noaaSanctSound_SB01_02_dolphins_1h
# noaaSanctSound_SB01_02_dolphins_1h (1536 rows): POINT (42.436838 -70.546958)
# Subsetted to (124 rows)
#
# 188/695 datasets
#
# querying noaaSanctSound_SB01_03_dolphins_1h
# noaaSanctSound_SB01_03_dolphins_1h (1451 rows): POINT (42.4371 -70.5467833)
# Subsetted to (594 rows)
#
# 189/695 datasets
#
# querying noaaSanctSound_SB01_04_dolphins_1h
# noaaSanctSound_SB01_04_dolphins_1h (1487 rows): POINT (42.436795 -70.5464317)
# Subsetted to (48 rows)
#
# 190/695 datasets
#
# querying noaaSanctSound_SB01_05_dolphins_1h
# noaaSanctSound_SB01_05_dolphins_1h (1532 rows): POINT (42.436785 -70.546435)
# Subsetted to (205 rows)
#
# 191/695 datasets
#
# querying noaaSanctSound_SB01_06_dolphins_1h
# noaaSanctSound_SB01_06_dolphins_1h (1486 rows): POINT (42.4369067 -70.5460133)
# Subsetted to (161 rows)
#
# 192/695 datasets
#
# querying noaaSanctSound_SB01_07_dolphins_1h
# noaaSanctSound_SB01_07_dolphins_1h (1342 rows): POINT (42.4369383 -70.54587)
# Subsetted to (86 rows)
#
# 193/695 datasets
#
# querying noaaSanctSound_SB01_08_dolphins_1h
# noaaSanctSound_SB01_08_dolphins_1h (1611 rows): POINT (42.4369267 -70.5458567)
# Subsetted to (249 rows)
#
# 194/695 datasets
#
# querying noaaSanctSound_SB01_09_dolphins_1h
# noaaSanctSound_SB01_09_dolphins_1h (1581 rows): POINT (42.437243 -70.54595)
# Subsetted to (860 rows)
#
# 195/695 datasets
#
# querying noaaSanctSound_SB01_10_dolphins_1h
# noaaSanctSound_SB01_10_dolphins_1h (1509 rows): POINT (42.437455 -70.545987)
# Subsetted to (100 rows)
#
# 196/695 datasets
#
# querying noaaSanctSound_SB01_11_dolphins_1h
# noaaSanctSound_SB01_11_dolphins_1h (815 rows): POINT (42.437835 -70.54602)
# Subsetted to (216 rows)
#
# 197/695 datasets
#
# querying noaaSanctSound_SB01_12_dolphins_1h
# noaaSanctSound_SB01_12_dolphins_1h (1583 rows): POINT (42.437805 -70.546112)
# Subsetted to (344 rows)
#
# 198/695 datasets
#
# querying noaaSanctSound_SB01_13_dolphins_1h
# noaaSanctSound_SB01_13_dolphins_1h (1559 rows): POINT (42.438228 -70.54546)
# Subsetted to (204 rows)
#
# 199/695 datasets
#
# querying noaaSanctSound_SB01_14_dolphins_1h
# noaaSanctSound_SB01_14_dolphins_1h (1270 rows): POINT (42.438323 -70.54551)
# Subsetted to (87 rows)
#
# 200/695 datasets
#
# querying noaaSanctSound_SB01_15_dolphins_1h
# noaaSanctSound_SB01_15_dolphins_1h (1601 rows): POINT (42.438427 -70.54542)
# Subsetted to (988 rows)
#
# 201/695 datasets
#
# querying noaaSanctSound_SB01_16_dolphins_1h
# noaaSanctSound_SB01_16_dolphins_1h (1466 rows): POINT (42.43835 -70.54556)
# Subsetted to (30 rows)
#
# 202/695 datasets
#
# querying noaaSanctSound_SB01_17_dolphins_1h
# noaaSanctSound_SB01_17_dolphins_1h (1439 rows): POINT (42.4383 -70.545683)
# Subsetted to (292 rows)
#
# 203/695 datasets
#
# querying noaaSanctSound_SB01_18_dolphins_1h
# noaaSanctSound_SB01_18_dolphins_1h (1941 rows): POINT (42.43843 -70.54583)
# Subsetted to (235 rows)
#
# 204/695 datasets
#
# querying noaaSanctSound_SB02_01_dolphins_1h
# noaaSanctSound_SB02_01_dolphins_1h (1848 rows): POINT (42.470793 -70.24294)
# Subsetted to (341 rows)
#
# 205/695 datasets
#
# querying noaaSanctSound_SB02_02_dolphins_1h
# noaaSanctSound_SB02_02_dolphins_1h (1531 rows): POINT (42.4708417 -70.24281)
# Subsetted to (238 rows)
#
# 206/695 datasets
#
# querying noaaSanctSound_SB02_03_dolphins_1h
# noaaSanctSound_SB02_03_dolphins_1h (1435 rows): POINT (42.4713583 -70.2427633)
# Subsetted to (547 rows)
#
# 207/695 datasets
#
# querying noaaSanctSound_SB02_04_dolphins_1h
# noaaSanctSound_SB02_04_dolphins_1h (1487 rows): POINT (42.4708617 -70.2424117)
# Subsetted to (401 rows)
#
# 208/695 datasets
#
# querying noaaSanctSound_SB02_05_dolphins_1h
# noaaSanctSound_SB02_05_dolphins_1h (1534 rows): POINT (42.4708733 -70.2423833)
# Subsetted to (238 rows)
#
# 209/695 datasets
#
# querying noaaSanctSound_SB02_06_dolphins_1h
# noaaSanctSound_SB02_06_dolphins_1h (1486 rows): POINT (42.47096 -70.242305)
# Subsetted to (223 rows)
#
# 210/695 datasets
#
# querying noaaSanctSound_SB02_07_dolphins_1h
# noaaSanctSound_SB02_07_dolphins_1h (1343 rows): POINT (42.4709883 -70.2423467)
# Subsetted to (202 rows)
#
# 211/695 datasets
#
# querying noaaSanctSound_SB02_08_dolphins_1h
# noaaSanctSound_SB02_08_dolphins_1h (1607 rows): POINT (42.470965 -70.2426433)
# Subsetted to (225 rows)
#
# 212/695 datasets
#
# querying noaaSanctSound_SB02_09_dolphins_1h
# noaaSanctSound_SB02_09_dolphins_1h (1581 rows): POINT (42.470708 -70.242457)
# Subsetted to (655 rows)
#
# 213/695 datasets
#
# querying noaaSanctSound_SB02_10_dolphins_1h
# noaaSanctSound_SB02_10_dolphins_1h (1509 rows): POINT (42.470772 -70.242258)
# Subsetted to (73 rows)
#
# 214/695 datasets
#
# querying noaaSanctSound_SB02_11_dolphins_1h
# noaaSanctSound_SB02_11_dolphins_1h (814 rows): POINT (42.47099 -70.24229)
# Subsetted to (166 rows)
#
# 215/695 datasets
#
# querying noaaSanctSound_SB02_12_dolphins_1h
# noaaSanctSound_SB02_12_dolphins_1h (1583 rows): POINT (42.47083 -70.242287)
# Subsetted to (329 rows)
#
# 216/695 datasets
#
# querying noaaSanctSound_SB02_13_dolphins_1h
# noaaSanctSound_SB02_13_dolphins_1h (1559 rows): POINT (42.471128 -70.241957)
# Subsetted to (359 rows)
#
# 217/695 datasets
#
# querying noaaSanctSound_SB02_14_dolphins_1h
# noaaSanctSound_SB02_14_dolphins_1h (1294 rows): POINT (42.471233 -70.24206)
# Subsetted to (163 rows)
#
# 218/695 datasets
#
# querying noaaSanctSound_SB02_15_dolphins_1h
# noaaSanctSound_SB02_15_dolphins_1h (1604 rows): POINT (42.471452 -70.241883)
# Subsetted to (894 rows)
#
# 219/695 datasets
#
# querying noaaSanctSound_SB02_16_dolphins_1h
# noaaSanctSound_SB02_16_dolphins_1h (1463 rows): POINT (42.47147 -70.24188)
# Subsetted to (74 rows)
#
# 220/695 datasets
#
# querying noaaSanctSound_SB02_17_dolphins_1h
# noaaSanctSound_SB02_17_dolphins_1h (1439 rows): POINT (42.471435 -70.241828)
# Subsetted to (284 rows)
#
# 221/695 datasets
#
# querying noaaSanctSound_SB02_18_dolphins_1h
# noaaSanctSound_SB02_18_dolphins_1h (1942 rows): POINT (42.47146 -70.2418)
# Subsetted to (482 rows)
#
# 222/695 datasets
#
# querying noaaSanctSound_SB03_01_dolphins_1h
# noaaSanctSound_SB03_01_dolphins_1h (1703 rows): POINT (42.25541 -70.178607)
# Subsetted to (632 rows)
#
# 223/695 datasets
#
# querying noaaSanctSound_SB03_02_dolphins_1h
# noaaSanctSound_SB03_02_dolphins_1h (1528 rows): POINT (42.25539 -70.178843)
# Subsetted to (391 rows)
#
# 224/695 datasets
#
# querying noaaSanctSound_SB03_03_dolphins_1h
# noaaSanctSound_SB03_03_dolphins_1h (1437 rows): POINT (42.2554067 -70.17901)
# Subsetted to (846 rows)
#
# 225/695 datasets
#
# querying noaaSanctSound_SB03_04_dolphins_1h
# noaaSanctSound_SB03_04_dolphins_1h (1488 rows): POINT (42.2554283 -70.179015)
# Subsetted to (157 rows)
#
# 226/695 datasets
#
# querying noaaSanctSound_SB03_05_dolphins_1h
# noaaSanctSound_SB03_05_dolphins_1h (1538 rows): POINT (42.2555167 -70.179065)
# Subsetted to (718 rows)
#
# 227/695 datasets
#
# querying noaaSanctSound_SB03_06_dolphins_1h
# noaaSanctSound_SB03_06_dolphins_1h (1486 rows): POINT (42.25553 -70.1789733)
# Subsetted to (512 rows)
#
# 228/695 datasets
#
# querying noaaSanctSound_SB03_07_dolphins_1h
# noaaSanctSound_SB03_07_dolphins_1h (667 rows): POINT (42.2553933 -70.1794483)
# Subsetted to (136 rows)
#
# 229/695 datasets
#
# querying noaaSanctSound_SB03_08_dolphins_1h
# noaaSanctSound_SB03_08_dolphins_1h (1603 rows): POINT (42.255235 -70.1796283)
# Subsetted to (327 rows)
#
# 230/695 datasets
#
# querying noaaSanctSound_SB03_09_dolphins_1h
# noaaSanctSound_SB03_09_dolphins_1h (1582 rows): POINT (42.254995 -70.17908)
# Subsetted to (888 rows)
#
# 231/695 datasets
#
# querying noaaSanctSound_SB03_10_dolphins_1h
# noaaSanctSound_SB03_10_dolphins_1h (1510 rows): POINT (42.254985 -70.179125)
# Subsetted to (193 rows)
#
# 232/695 datasets
#
# querying noaaSanctSound_SB03_11_dolphins_1h
# noaaSanctSound_SB03_11_dolphins_1h (814 rows): POINT (42.25512 -70.178928)
# Subsetted to (255 rows)
#
# 233/695 datasets
#
# querying noaaSanctSound_SB03_12_dolphins_1h
# noaaSanctSound_SB03_12_dolphins_1h (1583 rows): POINT (42.25508 -70.179047)
# Subsetted to (664 rows)
#
# 234/695 datasets
#
# querying noaaSanctSound_SB03_13_dolphins_1h
# noaaSanctSound_SB03_13_dolphins_1h (1427 rows): POINT (42.25532 -70.178937)
# Subsetted to (603 rows)
#
# 235/695 datasets
#
# querying noaaSanctSound_SB03_14_dolphins_1h
# noaaSanctSound_SB03_14_dolphins_1h (796 rows): POINT (42.255683 -70.178618)
# Subsetted to (60 rows)
#
# 236/695 datasets
#
# querying noaaSanctSound_SB03_15_dolphins_1h
# noaaSanctSound_SB03_15_dolphins_1h (1608 rows): POINT (42.25571 -70.178603)
# Subsetted to (1133 rows)
#
# 237/695 datasets
#
# querying noaaSanctSound_SB03_16_dolphins_1h
# noaaSanctSound_SB03_16_dolphins_1h (1460 rows): POINT (42.25571 -70.1787)
# Subsetted to (69 rows)
#
# 238/695 datasets
#
# querying noaaSanctSound_SB03_17_dolphins_1h
# noaaSanctSound_SB03_17_dolphins_1h (1438 rows): POINT (42.255657 -70.178618)
# Subsetted to (315 rows)
#
# 239/695 datasets
#
# querying noaaSanctSound_SB03_18_dolphins_1h
# noaaSanctSound_SB03_18_dolphins_1h (1705 rows): POINT (42.25564 -70.1789)
# Subsetted to (687 rows)
#
# 240/695 datasets
#
# querying noaaSanctSound_CI01_01_finwhale_1d
# noaaSanctSound_CI01_01_finwhale_1d (46 rows): POINT (34.0438 -120.0811)
#
# 241/695 datasets
#
# querying noaaSanctSound_CI01_02_finwhale_1d
# noaaSanctSound_CI01_02_finwhale_1d (133 rows): POINT (34.0438 -120.08105)
#
# 242/695 datasets
#
# querying noaaSanctSound_CI01_03_finwhale_1d
# noaaSanctSound_CI01_03_finwhale_1d (14 rows): POINT (34.04383 -120.081)
#
# 243/695 datasets
#
# querying noaaSanctSound_CI01_04_finwhale_1d
# noaaSanctSound_CI01_04_finwhale_1d (133 rows): POINT (34.04363 -120.08073)
#
# 244/695 datasets
#
# querying noaaSanctSound_CI01_05_finwhale_1d
# noaaSanctSound_CI01_05_finwhale_1d (129 rows): POINT (34.0463 -120.08073)
#
# 245/695 datasets
#
# querying noaaSanctSound_CI01_06_finwhale_1d
# noaaSanctSound_CI01_06_finwhale_1d (125 rows): POINT (34.0438 -120.081)
#
# 246/695 datasets
#
# querying noaaSanctSound_CI01_07_finwhale_1d
# noaaSanctSound_CI01_07_finwhale_1d (118 rows): POINT (34.04358 -120.06702)
#
# 247/695 datasets
#
# querying noaaSanctSound_CI01_08_finwhale_1d
# noaaSanctSound_CI01_08_finwhale_1d (65 rows): POINT (34.0436 -120.0803)
#
# 248/695 datasets
#
# querying noaaSanctSound_CI02_01_finwhale_1d
# noaaSanctSound_CI02_01_finwhale_1d (31 rows): POINT (34.0856 -120.5232)
# Subsetted to (19 rows)
#
# 249/695 datasets
#
# querying noaaSanctSound_CI02_02_finwhale_1d
# noaaSanctSound_CI02_02_finwhale_1d (121 rows): POINT (34.0854 -120.5233)
#
# 250/695 datasets
#
# querying noaaSanctSound_CI02_04_finwhale_1d
# noaaSanctSound_CI02_04_finwhale_1d (121 rows): POINT (34.08532 -120.523)
# Subsetted to (5 rows)
#
# 251/695 datasets
#
# querying noaaSanctSound_CI02_05_finwhale_1d
# noaaSanctSound_CI02_05_finwhale_1d (141 rows): POINT (34.0853 -120.5223)
# Subsetted to (62 rows)
#
# 252/695 datasets
#
# querying noaaSanctSound_CI02_06_finwhale_1d
# noaaSanctSound_CI02_06_finwhale_1d (132 rows): POINT (34.08523 -120.0957)
# Subsetted to (64 rows)
#
# 253/695 datasets
#
# querying noaaSanctSound_CI02_07_finwhale_1d
# noaaSanctSound_CI02_07_finwhale_1d (146 rows): POINT (34.0855 -120.5224)
# Subsetted to (56 rows)
#
# 254/695 datasets
#
# querying noaaSanctSound_CI03_02_finwhale_1d
# noaaSanctSound_CI03_02_finwhale_1d (128 rows): POINT (33.48687 -119.01609)
#
# 255/695 datasets
#
# querying noaaSanctSound_CI03_03_finwhale_1d
# noaaSanctSound_CI03_03_finwhale_1d (126 rows): POINT (33.48687 -119.01609)
#
# 256/695 datasets
#
# querying noaaSanctSound_CI03_04_finwhale_1d
# noaaSanctSound_CI03_04_finwhale_1d (93 rows): POINT (33.48675 -119.01607)
#
# 257/695 datasets
#
# querying noaaSanctSound_CI03_05_finwhale_1d
# noaaSanctSound_CI03_05_finwhale_1d (128 rows): POINT (33.48675 -119.01607)
#
# 258/695 datasets
#
# querying noaaSanctSound_CI03_06_finwhale_1d
# noaaSanctSound_CI03_06_finwhale_1d (99 rows): POINT (33.4868 -119.016)
#
# 259/695 datasets
#
# querying noaaSanctSound_CI03_07_finwhale_1d
# noaaSanctSound_CI03_07_finwhale_1d (126 rows): POINT (33.4868 -119.0159)
# Subsetted to (9 rows)
#
# 260/695 datasets
#
# querying noaaSanctSound_CI04_01_finwhale_1d
# noaaSanctSound_CI04_01_finwhale_1d (60 rows): POINT (33.849 -120.118)
# Subsetted to (57 rows)
#
# 261/695 datasets
#
# querying noaaSanctSound_CI04_02_finwhale_1d
# noaaSanctSound_CI04_02_finwhale_1d (137 rows): POINT (33.8489 -120.1175)
# Subsetted to (22 rows)
#
# 262/695 datasets
#
# querying noaaSanctSound_CI04_03_finwhale_1d
# noaaSanctSound_CI04_03_finwhale_1d (101 rows): POINT (33.84888 -120.117)
# Subsetted to (92 rows)
#
# 263/695 datasets
#
# querying noaaSanctSound_CI04_04_finwhale_1d
# noaaSanctSound_CI04_04_finwhale_1d (57 rows): POINT (33.84888 -120.117)
# Subsetted to (51 rows)
#
# 264/695 datasets
#
# querying noaaSanctSound_CI04_05_finwhale_1d
# noaaSanctSound_CI04_05_finwhale_1d (141 rows): POINT (33.8489 -120.1171)
# Subsetted to (117 rows)
#
# 265/695 datasets
#
# querying noaaSanctSound_CI04_06_finwhale_1d
# noaaSanctSound_CI04_06_finwhale_1d (131 rows): POINT (33.8489 -120.1174)
# Subsetted to (124 rows)
#
# 266/695 datasets
#
# querying noaaSanctSound_CI04_07_finwhale_1d
# noaaSanctSound_CI04_07_finwhale_1d (27 rows): POINT (33.84853 -120.1161)
# Subsetted to (20 rows)
#
# 267/695 datasets
#
# querying noaaSanctSound_CI04_08_finwhale_1d
# noaaSanctSound_CI04_08_finwhale_1d (108 rows): POINT (33.8485 -120.1159)
# Subsetted to (108 rows)
#
# 268/695 datasets
#
# querying noaaSanctSound_CI05_01_finwhale_1d
# noaaSanctSound_CI05_01_finwhale_1d (37 rows): POINT (34.0178 -119.3172)
# Subsetted to (36 rows)
#
# 269/695 datasets
#
# querying noaaSanctSound_CI05_02_finwhale_1d
# noaaSanctSound_CI05_02_finwhale_1d (125 rows): POINT (34.0178 -119.3172)
# Subsetted to (18 rows)
#
# 270/695 datasets
#
# querying noaaSanctSound_CI05_03_finwhale_1d
# noaaSanctSound_CI05_03_finwhale_1d (59 rows): POINT (34.0178 -119.317)
# Subsetted to (43 rows)
#
# 271/695 datasets
#
# querying noaaSanctSound_CI05_04_finwhale_1d
# noaaSanctSound_CI05_04_finwhale_1d (139 rows): POINT (34.0178 -119.317)
# Subsetted to (110 rows)
#
# 272/695 datasets
#
# querying noaaSanctSound_CI05_05_finwhale_1d
# noaaSanctSound_CI05_05_finwhale_1d (9 rows): POINT (34.01785 -119.3171)
#
# 273/695 datasets
#
# querying noaaSanctSound_CI05_06_finwhale_1d
# noaaSanctSound_CI05_06_finwhale_1d (120 rows): POINT (34.0178 -119.3171)
# Subsetted to (120 rows)
#
# 274/695 datasets
#
# querying noaaSanctSound_CI05_07_finwhale_1d
# noaaSanctSound_CI05_07_finwhale_1d (55 rows): POINT (34.01778 -119.31707)
# Subsetted to (31 rows)
#
# 275/695 datasets
#
# querying noaaSanctSound_CI05_08_finwhale_1d
# noaaSanctSound_CI05_08_finwhale_1d (129 rows): POINT (34.018 -119.3168)
# Subsetted to (121 rows)
#
# 276/695 datasets
#
# querying noaaSanctSound_MB01_01_finwhale_1d
# noaaSanctSound_MB01_01_finwhale_1d (134 rows): POINT (36.798 -121.976)
# Subsetted to (56 rows)
#
# 277/695 datasets
#
# querying noaaSanctSound_MB01_02_finwhale_1d
# noaaSanctSound_MB01_02_finwhale_1d (129 rows): POINT (36.798 -121.976)
#
# 278/695 datasets
#
# querying noaaSanctSound_MB01_03_finwhale_1d
# noaaSanctSound_MB01_03_finwhale_1d (121 rows): POINT (36.798 -121.976)
# Subsetted to (90 rows)
#
# 279/695 datasets
#
# querying noaaSanctSound_MB01_04_finwhale_1d
# noaaSanctSound_MB01_04_finwhale_1d (111 rows): POINT (36.798 -121.976)
# Subsetted to (56 rows)
#
# 280/695 datasets
#
# querying noaaSanctSound_MB01_05_finwhale_1d
# noaaSanctSound_MB01_05_finwhale_1d (127 rows): POINT (36.7977 -121.9757)
# Subsetted to (19 rows)
#
# 281/695 datasets
#
# querying noaaSanctSound_MB01_06_finwhale_1d
# noaaSanctSound_MB01_06_finwhale_1d (113 rows): POINT (36.7977 -121.9757)
# Subsetted to (110 rows)
#
# 282/695 datasets
#
# querying noaaSanctSound_MB01_07_finwhale_1d
# noaaSanctSound_MB01_07_finwhale_1d (134 rows): POINT (36.81467 -121.97593)
# Subsetted to (110 rows)
#
# 283/695 datasets
#
# querying noaaSanctSound_MB01_08_finwhale_1d
# noaaSanctSound_MB01_08_finwhale_1d (47 rows): POINT (36.798 -121.97607)
# Subsetted to (9 rows)
#
# 284/695 datasets
#
# querying noaaSanctSound_MB01_09_finwhale_1d
# noaaSanctSound_MB01_09_finwhale_1d (103 rows): POINT (36.798 -122.9758)
# Subsetted to (99 rows)
#
# 285/695 datasets
#
# querying noaaSanctSound_MB02_01_finwhale_1d
# noaaSanctSound_MB02_01_finwhale_1d (145 rows): POINT (36.648 -121.9084)
# Subsetted to (1 rows)
#
# 286/695 datasets
#
# querying noaaSanctSound_MB02_02_finwhale_1d
# noaaSanctSound_MB02_02_finwhale_1d (126 rows): POINT (36.6495 -121.9084)
#
# 287/695 datasets
#
# querying noaaSanctSound_MB02_03_finwhale_1d
# noaaSanctSound_MB02_03_finwhale_1d (120 rows): POINT (36.6495 -121.9084)
# Subsetted to (22 rows)
#
# 288/695 datasets
#
# querying noaaSanctSound_MB02_04_finwhale_1d
# noaaSanctSound_MB02_04_finwhale_1d (155 rows): POINT (36.6495 -121.9084)
# Subsetted to (16 rows)
#
# 289/695 datasets
#
# querying noaaSanctSound_MB02_05_finwhale_1d
# noaaSanctSound_MB02_05_finwhale_1d (127 rows): POINT (36.6484 -121.9075)
# Subsetted to (5 rows)
#
# 290/695 datasets
#
# querying noaaSanctSound_MB02_07_finwhale_1d
# noaaSanctSound_MB02_07_finwhale_1d (134 rows): POINT (36.64798 -121.90792)
# Subsetted to (10 rows)
#
# 291/695 datasets
#
# querying noaaSanctSound_MB02_08_finwhale_1d
# noaaSanctSound_MB02_08_finwhale_1d (111 rows): POINT (36.6482 -121.90682)
#
# 292/695 datasets
#
# querying noaaSanctSound_MB02_09_finwhale_1d
# noaaSanctSound_MB02_09_finwhale_1d (140 rows): POINT (36.6482 -122.90687)
#
# 293/695 datasets
#
# querying noaaSanctSound_MB03_01_finwhale_1d
# noaaSanctSound_MB03_01_finwhale_1d (132 rows): POINT (36.3703 -122.3148)
# Subsetted to (58 rows)
#
# 294/695 datasets
#
# querying noaaSanctSound_MB03_02_finwhale_1d
# noaaSanctSound_MB03_02_finwhale_1d (226 rows): POINT (36.37021 -122.314903)
# Subsetted to (114 rows)
#
# 295/695 datasets
#
# querying noaaSanctSound_MB03_03_finwhale_1d
# noaaSanctSound_MB03_03_finwhale_1d (214 rows): POINT (36.37021 -122.314903)
#
# 296/695 datasets
#
# querying noaaSanctSound_MB03_04_finwhale_1d
# noaaSanctSound_MB03_04_finwhale_1d (172 rows): POINT (36.37021 -122.314903)
# Subsetted to (137 rows)
#
# 297/695 datasets
#
# querying noaaSanctSound_OC01_01_finwhale_1d
# noaaSanctSound_OC01_01_finwhale_1d (123 rows): POINT (48.3938 -124.654)
#
# 298/695 datasets
#
# querying noaaSanctSound_OC01_03_finwhale_1d
# noaaSanctSound_OC01_03_finwhale_1d (161 rows): POINT (48.3938 -124.62067)
#
# 299/695 datasets
#
# querying noaaSanctSound_OC02_01_finwhale_1d
# noaaSanctSound_OC02_01_finwhale_1d (48 rows): POINT (48.4904 -125.0038)
#
# 300/695 datasets
#
# querying noaaSanctSound_OC02_02_finwhale_1d
# noaaSanctSound_OC02_02_finwhale_1d (112 rows): POINT (48.4905 -125.0039)
# Subsetted to (7 rows)
#
# 301/695 datasets
#
# querying noaaSanctSound_OC02_04_finwhale_1d
# noaaSanctSound_OC02_04_finwhale_1d (81 rows): POINT (48.4903 -125.0037)
#
# 302/695 datasets
#
# querying noaaSanctSound_OC02_05_finwhale_1d
# noaaSanctSound_OC02_05_finwhale_1d (141 rows): POINT (48.49045 -124.0035)
#
# 303/695 datasets
#
# querying noaaSanctSound_OC03_02_finwhale_1d
# noaaSanctSound_OC03_02_finwhale_1d (127 rows): POINT (47.3179 -124.4166)
#
# 304/695 datasets
#
# querying noaaSanctSound_OC03_03_finwhale_1d
# noaaSanctSound_OC03_03_finwhale_1d (91 rows): POINT (47.3179 -124.4166)
#
# 305/695 datasets
#
# querying noaaSanctSound_OC03_04_finwhale_1d
# noaaSanctSound_OC03_04_finwhale_1d (131 rows): POINT (47.3175 -124.4146)
#
# 306/695 datasets
#
# querying noaaSanctSound_OC04_02_finwhale_1d
# noaaSanctSound_OC04_02_finwhale_1d (17 rows): POINT (48.0378 -124.7285)
#
# 307/695 datasets
#
# querying noaaSanctSound_OC04_04_finwhale_1d
# noaaSanctSound_OC04_04_finwhale_1d (140 rows): POINT (48.0378 -124.72845)
#
# 308/695 datasets
#
# querying noaaSanctSound_SB01_04_finwhale_1d
# noaaSanctSound_SB01_04_finwhale_1d (63 rows): POINT (42.436795 -70.5464317)
#
# 309/695 datasets
#
# querying noaaSanctSound_CI02_01_pinnipeds
# noaaSanctSound_CI02_01_pinnipeds (1 rows): POINT (34.0856 -120.5232)
# Subsetted to (1 rows)
#
# 310/695 datasets
#
# querying noaaSanctSound_CI02_02_pinnipeds
# noaaSanctSound_CI02_02_pinnipeds (127 rows): POINT (34.0854 -120.5233)
# Subsetted to (127 rows)
#
# 311/695 datasets
#
# querying noaaSanctSound_CI02_04_pinnipeds
# noaaSanctSound_CI02_04_pinnipeds (53 rows): POINT (34.08532 -120.523)
# Subsetted to (53 rows)
#
# 312/695 datasets
#
# querying noaaSanctSound_CI02_05_pinnipeds
# noaaSanctSound_CI02_05_pinnipeds (134 rows): POINT (34.0853 -120.5223)
# ...
#
# 602/695 datasets
#
# querying noaaSanctSound_MB02_01_sonar
# noaaSanctSound_MB02_01_sonar (1 rows): POINT (36.648 -121.9084)
#
# 603/695 datasets
#
# querying noaaSanctSound_MB02_02_plainfinmidshipman
# noaaSanctSound_MB02_02_plainfinmidshipman (99 rows): POINT (36.6495 -121.9084)
# Subsetted to (99 rows)
#
# 604/695 datasets
#
# querying noaaSanctSound_MB02_03_plainfinmidshipman
# noaaSanctSound_MB02_03_plainfinmidshipman (44 rows): POINT (36.6495 -121.9084)
# Subsetted to (44 rows)
#
# 605/695 datasets
#
# querying noaaSanctSound_MB02_04_plainfinmidshipman
# noaaSanctSound_MB02_04_plainfinmidshipman (8 rows): POINT (36.6495 -121.9084)
# Subsetted to (8 rows)
#
# 606/695 datasets
#
# querying noaaSanctSound_MB02_05_plainfinmidshipman
# noaaSanctSound_MB02_05_plainfinmidshipman (102 rows): POINT (36.6484 -121.9075)
# Subsetted to (102 rows)
#
# 607/695 datasets
#
# querying noaaSanctSound_MB02_07_plainfinmidshipman
# noaaSanctSound_MB02_07_plainfinmidshipman (1 rows): POINT (36.64798 -121.90792)
#
# 608/695 datasets
#
# querying noaaSanctSound_FK01_01_northatlanticrightwhale_1d
# noaaSanctSound_FK01_01_northatlanticrightwhale_1d (123 rows): POINT (24.43313 -81.93068)
#
# 609/695 datasets
#
# querying noaaSanctSound_FK02_01_northatlanticrightwhale_1d
# noaaSanctSound_FK02_01_northatlanticrightwhale_1d (125 rows): POINT (24.4888 -81.666316)
#
# 610/695 datasets
#
# querying noaaSanctSound_FK03_01_northatlanticrightwhale_1d
# noaaSanctSound_FK03_01_northatlanticrightwhale_1d (128 rows): POINT (24.45895 -81.774133)
#
# 611/695 datasets
#
# querying noaaSanctSound_GR01_01_northatlanticrightwhale_1d
# noaaSanctSound_GR01_01_northatlanticrightwhale_1d (140 rows): POINT (31.396417 -80.8904)
# Subsetted to (3 rows)
#
# 612/695 datasets
#
# querying noaaSanctSound_GR01_02_northatlanticrightwhale_1d
# noaaSanctSound_GR01_02_northatlanticrightwhale_1d (143 rows): POINT (31.396417 -80.8904)
#
# 613/695 datasets
#
# querying noaaSanctSound_GR01_03_northatlanticrightwhale_1d
# noaaSanctSound_GR01_03_northatlanticrightwhale_1d (107 rows): POINT (31.396417 -80.8904)
# Subsetted to (2 rows)
#
# 614/695 datasets
#
# querying noaaSanctSound_GR01_04_northatlanticrightwhale_1d
# noaaSanctSound_GR01_04_northatlanticrightwhale_1d (113 rows): POINT (31.396417 -80.8904)
#
# 615/695 datasets
#
# querying noaaSanctSound_GR01_05_northatlanticrightwhale_1d
# noaaSanctSound_GR01_05_northatlanticrightwhale_1d (140 rows): POINT (31.396417 -80.8904)
# Subsetted to (9 rows)
#
# 616/695 datasets
#
# querying noaaSanctSound_GR02_02_northatlanticrightwhale_1d
# noaaSanctSound_GR02_02_northatlanticrightwhale_1d (134 rows): POINT (31.376133 -80.839133)
#
# 617/695 datasets
#
# querying noaaSanctSound_GR03_02_northatlanticrightwhale_1d
# noaaSanctSound_GR03_02_northatlanticrightwhale_1d (131 rows): POINT (31.36749 -80.895)
#
# 618/695 datasets
#
# querying noaaSanctSound_SB01_01_northatlanticrightwhale_1d
# noaaSanctSound_SB01_01_northatlanticrightwhale_1d (78 rows): POINT (42.436838 -70.546958)
#
# 619/695 datasets
#
# querying noaaSanctSound_SB01_02_northatlanticrightwhale_1d
# noaaSanctSound_SB01_02_northatlanticrightwhale_1d (65 rows): POINT (42.43668 -70.546655)
# Subsetted to (9 rows)
#
# 620/695 datasets
#
# querying noaaSanctSound_SB01_03_northatlanticrightwhale_1d
# noaaSanctSound_SB01_03_northatlanticrightwhale_1d (61 rows): POINT (42.4371 -70.5467833)
#
# 621/695 datasets
#
# querying noaaSanctSound_SB01_04_northatlanticrightwhale_1d
# noaaSanctSound_SB01_04_northatlanticrightwhale_1d (63 rows): POINT (42.436795 -70.5464317)
#
# 622/695 datasets
#
# querying noaaSanctSound_SB01_05_northatlanticrightwhale_1d
# noaaSanctSound_SB01_05_northatlanticrightwhale_1d (65 rows): POINT (42.436785 -70.546435)
#
# 623/695 datasets
#
# querying noaaSanctSound_SB01_06_northatlanticrightwhale_1d
# noaaSanctSound_SB01_06_northatlanticrightwhale_1d (63 rows): POINT (42.4369067 -70.5460133)
#
# 624/695 datasets
#
# querying noaaSanctSound_SB01_07_northatlanticrightwhale_1d
# noaaSanctSound_SB01_07_northatlanticrightwhale_1d (57 rows): POINT (42.4369383 -70.54587)
# Subsetted to (3 rows)
#
# 625/695 datasets
#
# querying noaaSanctSound_SB01_08_northatlanticrightwhale_1d
# noaaSanctSound_SB01_08_northatlanticrightwhale_1d (68 rows): POINT (42.4369267 -70.5458567)
# Subsetted to (27 rows)
#
# 626/695 datasets
#
# querying noaaSanctSound_SB01_09_northatlanticrightwhale_1d
# noaaSanctSound_SB01_09_northatlanticrightwhale_1d (67 rows): POINT (42.437243 -70.54595)
# Subsetted to (11 rows)
#
# 627/695 datasets
#
# querying noaaSanctSound_SB01_10_northatlanticrightwhale_1d
# noaaSanctSound_SB01_10_northatlanticrightwhale_1d (64 rows): POINT (42.437455 -70.545987)
# Subsetted to (1 rows)
#
# 628/695 datasets
#
# querying noaaSanctSound_SB01_11_northatlanticrightwhale_1d
# noaaSanctSound_SB01_11_northatlanticrightwhale_1d (35 rows): POINT (42.437835 -70.54602)
#
# 629/695 datasets
#
# querying noaaSanctSound_SB01_12_northatlanticrightwhale_1d
# noaaSanctSound_SB01_12_northatlanticrightwhale_1d (67 rows): POINT (42.437805 -70.546112)
#
# 630/695 datasets
#
# querying noaaSanctSound_SB02_01_northatlanticrightwhale_1d
# noaaSanctSound_SB02_01_northatlanticrightwhale_1d (78 rows): POINT (42.470793 -70.24294)
# Subsetted to (3 rows)
#
# 631/695 datasets
#
# querying noaaSanctSound_SB02_02_northatlanticrightwhale_1d
# noaaSanctSound_SB02_02_northatlanticrightwhale_1d (65 rows): POINT (42.4708417 -70.24281)
# Subsetted to (7 rows)
#
# 632/695 datasets
#
# querying noaaSanctSound_SB02_03_northatlanticrightwhale_1d
# noaaSanctSound_SB02_03_northatlanticrightwhale_1d (61 rows): POINT (42.4713583 -70.2427633)
# Subsetted to (11 rows)
#
# 633/695 datasets
#
# querying noaaSanctSound_SB02_04_northatlanticrightwhale_1d
# noaaSanctSound_SB02_04_northatlanticrightwhale_1d (63 rows): POINT (42.4708617 -70.2424117)
#
# 634/695 datasets
#
# querying noaaSanctSound_SB02_05_northatlanticrightwhale_1d
# noaaSanctSound_SB02_05_northatlanticrightwhale_1d (65 rows): POINT (42.4708733 -70.2423833)
# Subsetted to (3 rows)
#
# 635/695 datasets
#
# querying noaaSanctSound_SB02_06_northatlanticrightwhale_1d
# noaaSanctSound_SB02_06_northatlanticrightwhale_1d (63 rows): POINT (42.47096 -70.242305)
#
# 636/695 datasets
#
# querying noaaSanctSound_SB02_07_northatlanticrightwhale_1d
# noaaSanctSound_SB02_07_northatlanticrightwhale_1d (57 rows): POINT (42.4709883 -70.2423467)
# Subsetted to (21 rows)
#
# 637/695 datasets
#
# querying noaaSanctSound_SB02_08_northatlanticrightwhale_1d
# noaaSanctSound_SB02_08_northatlanticrightwhale_1d (68 rows): POINT (42.470965 -70.2426433)
# Subsetted to (20 rows)
#
# 638/695 datasets
#
# querying noaaSanctSound_SB02_09_northatlanticrightwhale_1d
# noaaSanctSound_SB02_09_northatlanticrightwhale_1d (67 rows): POINT (42.470708 -70.242457)
# Subsetted to (9 rows)
#
# 639/695 datasets
#
# querying noaaSanctSound_SB02_10_northatlanticrightwhale_1d
# noaaSanctSound_SB02_10_northatlanticrightwhale_1d (64 rows): POINT (42.470772 -70.242258)
#
# 640/695 datasets
#
# querying noaaSanctSound_SB02_11_northatlanticrightwhale_1d
# noaaSanctSound_SB02_11_northatlanticrightwhale_1d (35 rows): POINT (42.47099 -70.24229)
#
# 641/695 datasets
#
# querying noaaSanctSound_SB02_12_northatlanticrightwhale_1d
# noaaSanctSound_SB02_12_northatlanticrightwhale_1d (67 rows): POINT (42.47083 -70.242287)
# Subsetted to (1 rows)
#
# 642/695 datasets
#
# querying noaaSanctSound_SB03_01_northatlanticrightwhale_1d
# noaaSanctSound_SB03_01_northatlanticrightwhale_1d (78 rows): POINT (42.25541 -70.178607)
# Subsetted to (5 rows)
#
# 643/695 datasets
#
# querying noaaSanctSound_SB03_02_northatlanticrightwhale_1d
# noaaSanctSound_SB03_02_northatlanticrightwhale_1d (65 rows): POINT (42.25539 -70.178843)
# Subsetted to (21 rows)
#
# 644/695 datasets
#
# querying noaaSanctSound_SB03_03_northatlanticrightwhale_1d
# noaaSanctSound_SB03_03_northatlanticrightwhale_1d (61 rows): POINT (42.2554067 -70.17901)
# Subsetted to (26 rows)
#
# 645/695 datasets
#
# querying noaaSanctSound_SB03_04_northatlanticrightwhale_1d
# noaaSanctSound_SB03_04_northatlanticrightwhale_1d (63 rows): POINT (42.2554283 -70.179015)
# Subsetted to (1 rows)
#
# 646/695 datasets
#
# querying noaaSanctSound_SB03_05_northatlanticrightwhale_1d
# noaaSanctSound_SB03_05_northatlanticrightwhale_1d (65 rows): POINT (42.2555167 -70.179065)
# Subsetted to (1 rows)
#
# 647/695 datasets
#
# querying noaaSanctSound_SB03_06_northatlanticrightwhale_1d
# noaaSanctSound_SB03_06_northatlanticrightwhale_1d (63 rows): POINT (42.25553 -70.1789733)
# Subsetted to (2 rows)
#
# 648/695 datasets
#
# querying noaaSanctSound_SB03_07_northatlanticrightwhale_1d
# noaaSanctSound_SB03_07_northatlanticrightwhale_1d (29 rows): POINT (42.2553933 -70.1794483)
# Subsetted to (6 rows)
#
# 649/695 datasets
#
# querying noaaSanctSound_SB03_08_northatlanticrightwhale_1d
# noaaSanctSound_SB03_08_northatlanticrightwhale_1d (68 rows): POINT (42.255235 -70.1796283)
# Subsetted to (57 rows)
#
# 650/695 datasets
#
# querying noaaSanctSound_SB03_09_northatlanticrightwhale_1d
# noaaSanctSound_SB03_09_northatlanticrightwhale_1d (67 rows): POINT (42.254995 -70.17908)
# Subsetted to (13 rows)
#
# 651/695 datasets
#
# querying noaaSanctSound_SB03_10_northatlanticrightwhale_1d
# noaaSanctSound_SB03_10_northatlanticrightwhale_1d (64 rows): POINT (42.254985 -70.179125)
# Subsetted to (2 rows)
#
# 652/695 datasets
#
# querying noaaSanctSound_SB03_11_northatlanticrightwhale_1d
# noaaSanctSound_SB03_11_northatlanticrightwhale_1d (35 rows): POINT (42.25512 -70.178928)
#
# 653/695 datasets
#
# querying noaaSanctSound_SB03_12_northatlanticrightwhale_1d
# noaaSanctSound_SB03_12_northatlanticrightwhale_1d (67 rows): POINT (42.25508 -70.179047)
#
# 654/695 datasets
#
# querying noaaSanctSound_GR01_01_finwhale_1d
# noaaSanctSound_GR01_01_finwhale_1d (140 rows): POINT (31.396417 -80.8904)
#
# 655/695 datasets
#
# querying noaaSanctSound_GR01_02_finwhale_1d
# noaaSanctSound_GR01_02_finwhale_1d (143 rows): POINT (31.396417 -80.8904)
#
# 656/695 datasets
#
# querying noaaSanctSound_GR02_02_finwhale_1d
# noaaSanctSound_GR02_02_finwhale_1d (134 rows): POINT (31.376133 -80.839133)
#
# 657/695 datasets
#
# querying noaaSanctSound_GR03_02_finwhale_1d
# noaaSanctSound_GR03_02_finwhale_1d (131 rows): POINT (31.36749 -80.895)
#
# 658/695 datasets
#
# querying noaaSanctSound_FK01_01_finwhale_1d
# noaaSanctSound_FK01_01_finwhale_1d (123 rows): POINT (24.43313 -81.93068)
#
# 659/695 datasets
#
# querying noaaSanctSound_FK02_01_finwhale_1d
# noaaSanctSound_FK02_01_finwhale_1d (125 rows): POINT (24.4888 -81.666316)
#
# 660/695 datasets
#
# querying noaaSanctSound_FK03_01_finwhale_1d
# noaaSanctSound_FK03_01_finwhale_1d (128 rows): POINT (24.45895 -81.774133)
#
# 661/695 datasets
#
# querying noaaSanctSound_SB01_01_finwhale_1d
# noaaSanctSound_SB01_01_finwhale_1d (78 rows): POINT (42.436838 -70.546958)
# Subsetted to (33 rows)
#
# 662/695 datasets
#
# querying noaaSanctSound_SB01_02_finwhale_1d
# noaaSanctSound_SB01_02_finwhale_1d (65 rows): POINT (42.43668 -70.546655)
# Subsetted to (14 rows)
#
# 663/695 datasets
#
# querying noaaSanctSound_SB01_03_finwhale_1d
# noaaSanctSound_SB01_03_finwhale_1d (61 rows): POINT (42.4371 -70.5467833)
# Subsetted to (4 rows)
#
# 664/695 datasets
#
# querying noaaSanctSound_SB01_05_finwhale_1d
# noaaSanctSound_SB01_05_finwhale_1d (65 rows): POINT (42.436785 -70.546435)
# Subsetted to (24 rows)
#
# 665/695 datasets
#
# querying noaaSanctSound_SB01_06_finwhale_1d
# noaaSanctSound_SB01_06_finwhale_1d (63 rows): POINT (42.4369067 -70.5460133)
# Subsetted to (27 rows)
#
# 666/695 datasets
#
# querying noaaSanctSound_SB01_07_finwhale_1d
# noaaSanctSound_SB01_07_finwhale_1d (57 rows): POINT (42.4369383 -70.54587)
# Subsetted to (33 rows)
#
# 667/695 datasets
#
# querying noaaSanctSound_SB01_08_finwhale_1d
# noaaSanctSound_SB01_08_finwhale_1d (68 rows): POINT (42.4369267 -70.5458567)
# Subsetted to (30 rows)
#
# 668/695 datasets
#
# querying noaaSanctSound_SB01_09_finwhale_1d
# noaaSanctSound_SB01_09_finwhale_1d (67 rows): POINT (42.437243 -70.54595)
# Subsetted to (20 rows)
#
# 669/695 datasets
#
# querying noaaSanctSound_SB01_10_finwhale_1d
# noaaSanctSound_SB01_10_finwhale_1d (64 rows): POINT (42.437455 -70.545987)
#
# 670/695 datasets
#
# querying noaaSanctSound_SB01_11_finwhale_1d
# noaaSanctSound_SB01_11_finwhale_1d (35 rows): POINT (42.437835 -70.54602)
# Subsetted to (6 rows)
#
# 671/695 datasets
#
# querying noaaSanctSound_SB01_12_finwhale_1d
# noaaSanctSound_SB01_12_finwhale_1d (67 rows): POINT (42.437805 -70.546112)
# Subsetted to (41 rows)
#
# 672/695 datasets
#
# querying noaaSanctSound_SB02_01_finwhale_1d
# noaaSanctSound_SB02_01_finwhale_1d (78 rows): POINT (42.470793 -70.24294)
# Subsetted to (78 rows)
#
# 673/695 datasets
#
# querying noaaSanctSound_SB02_02_finwhale_1d
# noaaSanctSound_SB02_02_finwhale_1d (65 rows): POINT (42.4708417 -70.24281)
# Subsetted to (64 rows)
#
# 674/695 datasets
#
# querying noaaSanctSound_SB02_03_finwhale_1d
# noaaSanctSound_SB02_03_finwhale_1d (61 rows): POINT (42.4713583 -70.2427633)
# Subsetted to (18 rows)
#
# 675/695 datasets
#
# querying noaaSanctSound_SB02_04_finwhale_1d
# noaaSanctSound_SB02_04_finwhale_1d (63 rows): POINT (42.4708617 -70.2424117)
# Subsetted to (6 rows)
#
# 676/695 datasets
#
# querying noaaSanctSound_SB02_05_finwhale_1d
# noaaSanctSound_SB02_05_finwhale_1d (65 rows): POINT (42.4708733 -70.2423833)
# Subsetted to (56 rows)
#
# 677/695 datasets
#
# querying noaaSanctSound_SB02_06_finwhale_1d
# noaaSanctSound_SB02_06_finwhale_1d (63 rows): POINT (42.47096 -70.242305)
# Subsetted to (62 rows)
#
# 678/695 datasets
#
# querying noaaSanctSound_SB02_07_finwhale_1d
# noaaSanctSound_SB02_07_finwhale_1d (57 rows): POINT (42.4709883 -70.2423467)
# Subsetted to (57 rows)
#
# 679/695 datasets
#
# querying noaaSanctSound_SB02_08_finwhale_1d
# noaaSanctSound_SB02_08_finwhale_1d (68 rows): POINT (42.470965 -70.2426433)
# Subsetted to (68 rows)
#
# 680/695 datasets
#
# querying noaaSanctSound_SB02_09_finwhale_1d
# noaaSanctSound_SB02_09_finwhale_1d (67 rows): POINT (42.470708 -70.242457)
# Subsetted to (40 rows)
#
# 681/695 datasets
#
# querying noaaSanctSound_SB02_10_finwhale_1d
# noaaSanctSound_SB02_10_finwhale_1d (64 rows): POINT (42.470772 -70.242258)
# Subsetted to (22 rows)
#
# 682/695 datasets
#
# querying noaaSanctSound_SB02_11_finwhale_1d
# noaaSanctSound_SB02_11_finwhale_1d (35 rows): POINT (42.47099 -70.24229)
# Subsetted to (34 rows)
#
# 683/695 datasets
#
# querying noaaSanctSound_SB02_12_finwhale_1d
# noaaSanctSound_SB02_12_finwhale_1d (67 rows): POINT (42.47083 -70.242287)
# Subsetted to (67 rows)
#
# 684/695 datasets
#
# querying noaaSanctSound_SB03_01_finwhale_1d
# noaaSanctSound_SB03_01_finwhale_1d (78 rows): POINT (42.25541 -70.178607)
# Subsetted to (68 rows)
#
# 685/695 datasets
#
# querying noaaSanctSound_SB03_02_finwhale_1d
# noaaSanctSound_SB03_02_finwhale_1d (65 rows): POINT (42.25539 -70.178843)
# Subsetted to (58 rows)
#
# 686/695 datasets
#
# querying noaaSanctSound_SB03_03_finwhale_1d
# noaaSanctSound_SB03_03_finwhale_1d (61 rows): POINT (42.2554067 -70.17901)
# Subsetted to (20 rows)
#
# 687/695 datasets
#
# querying noaaSanctSound_SB03_04_finwhale_1d
# noaaSanctSound_SB03_04_finwhale_1d (63 rows): POINT (42.2554283 -70.179015)
# Subsetted to (4 rows)
#
# 688/695 datasets
#
# querying noaaSanctSound_SB03_05_finwhale_1d
# noaaSanctSound_SB03_05_finwhale_1d (65 rows): POINT (42.2555167 -70.179065)
# Subsetted to (56 rows)
#
# 689/695 datasets
#
# querying noaaSanctSound_SB03_06_finwhale_1d
# noaaSanctSound_SB03_06_finwhale_1d (63 rows): POINT (42.25553 -70.1789733)
# Subsetted to (60 rows)
#
# 690/695 datasets
#
# querying noaaSanctSound_SB03_07_finwhale_1d
# noaaSanctSound_SB03_07_finwhale_1d (29 rows): POINT (42.2553933 -70.1794483)
# Subsetted to (29 rows)
#
# 691/695 datasets
#
# querying noaaSanctSound_SB03_08_finwhale_1d
# noaaSanctSound_SB03_08_finwhale_1d (68 rows): POINT (42.255235 -70.1796283)
# Subsetted to (67 rows)
#
# 692/695 datasets
#
# querying noaaSanctSound_SB03_09_finwhale_1d
# noaaSanctSound_SB03_09_finwhale_1d (67 rows): POINT (42.254995 -70.17908)
# Subsetted to (38 rows)
#
# 693/695 datasets
#
# querying noaaSanctSound_SB03_10_finwhale_1d
# noaaSanctSound_SB03_10_finwhale_1d (64 rows): POINT (42.254985 -70.179125)
# Subsetted to (18 rows)
#
# 694/695 datasets
#
# querying noaaSanctSound_SB03_11_finwhale_1d
# noaaSanctSound_SB03_11_finwhale_1d (35 rows): POINT (42.25512 -70.178928)
# Subsetted to (34 rows)
#
# 695/695 datasets
#
# querying noaaSanctSound_SB03_12_finwhale_1d
# noaaSanctSound_SB03_12_finwhale_1d (67 rows): POINT (42.25508 -70.179047)
# Subsetted to (67 rows)
# There were 186 datasets that either didn't have a presence variable or didn't contain presence data
# CPU times: total: 28.9 s
# Wall time: 4min 39s

# %%
df_final.sample(n=5)
# Out:
#                          start_time  dolphin_presence  \
# 19562                           NaT               NaN
# 28438                           NaT               NaN
# 13354 2020-04-24 10:33:53.125999872               NaN
# 46079                           NaT               NaN
# 6426                            NaT               NaN
#
#                              dataset_id                          WKT  \
# 19562  noaaSanctSound_MB01_03_bluewhale      POINT (36.798 -121.976)
# 28438  noaaSanctSound_CI02_07_bluewhale    POINT (34.0855 -120.5224)
# 13354   noaaSanctSound_CI03_03_bocaccio  POINT (33.48687 -119.01609)
# 46079  noaaSanctSound_CI02_05_bluewhale    POINT (34.0853 -120.5223)
# 6426   noaaSanctSound_CI04_08_bluewhale    POINT (33.8485 -120.1159)
#
#       decimalLatitude decimalLongitude vernacularName                    time  \
# 19562          36.798         -121.976     blue whale 2019-10-30 21:50:59.648
# 28438         34.0855        -120.5224     blue whale 2021-08-31 23:05:59.872
# 13354        33.48687       -119.01609       bocaccio                     NaT
# 46079         34.0853        -120.5223     blue whale 2020-10-18 03:15:56.104
# 6426          33.8485        -120.1159     blue whale 2021-08-22 23:56:29.424
#
#        bluewhale_presence  bluewhale_manual_presence  ...  pinniped_presence  \
# 19562                 1.0                        NaN  ...                NaN
# 28438                 1.0                        NaN  ...                NaN
# 13354                 NaN                        NaN  ...                NaN
# 46079                 1.0                        NaN  ...                NaN
# 6426                  1.0                        NaN  ...                NaN
#
#        redgrouper_detection_count  seiwhale_presence  atlanticcod_presence  \
# 19562                         NaN                NaN                   NaN
# 28438                         NaN                NaN                   NaN
# 13354                         NaN                NaN                   NaN
# 46079                         NaN                NaN                   NaN
# 6426                          NaN                NaN                   NaN
#
#        blackgrouper_detection_count  humpbackwhale_presence  \
# 19562                           NaN                     NaN
# 28438                           NaN                     NaN
# 13354                           NaN                     NaN
# 46079                           NaN                     NaN
# 6426                            NaN                     NaN
#
#        killerwhale_presence  minkewhale_presence  plainfinmidshipman_presence  \
# 19562                   NaN                  NaN                          NaN
# 28438                   NaN                  NaN                          NaN
# 13354                   NaN                  NaN                          NaN
# 46079                   NaN                  NaN                          NaN
# 6426                    NaN                  NaN                          NaN
#
#        northatlanticrightwhale_presence
# 19562                               NaN
# 28438                               NaN
# 13354                               NaN
# 46079                               NaN
# 6426                                NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## WoRMS Mapping
# WoRMS lookup. Abby Benson created a mapping table which we will use below to insert the appropriate WoRMS idenfitiers.

# %%
df_mapping = pd.read_csv('SanctSound_SpeciesLookupTable.csv')

df_mapping
# Out:
#                 vernacularName              scientificName  \
# 0                      dolphin                     Cetacea
# 1                   blue whale       Balaenoptera musculus
# 2                     bocaccio        Sebastes paucispinis
# 3                    fin whale       Balaenoptera physalus
# 4                     pinniped                  Pinnipedia
# 5                  red grouper           Epinephelus morio
# 6                    sei whale       Balaenoptera borealis
# 7                black grouper         Mycteroperca bonaci
# 8               humpback whale      Megaptera novaeangliae
# 9                 killer whale                Orcinus orca
# 10                 minke whale  Balaenoptera acutorostrata
# 11         plainfin midshipman          Porichthys notatus
# 12  north atlantic right whale         Eubalaena glacialis
# 13                atlantic cod                Gadus morhua
#
#                              scientificNameID   taxonRank   kingdom  \
# 0     urn:lsid:marinespecies.org:taxname:2688  Infraorder  Animalia
# 1   urn:lsid:marinespecies.org:taxname:137090     Species  Animalia
# 2   urn:lsid:marinespecies.org:taxname:274833     Species  Animalia
# 3   urn:lsid:marinespecies.org:taxname:137091     Species  Animalia
# 4   urn:lsid:marinespecies.org:taxname:148736  Infraorder  Animalia
# 5   urn:lsid:marinespecies.org:taxname:159354     Species  Animalia
# 6   urn:lsid:marinespecies.org:taxname:137088     Species  Animalia
# 7   urn:lsid:marinespecies.org:taxname:159231     Species  Animalia
# 8   urn:lsid:marinespecies.org:taxname:137092     Species  Animalia
# 9   urn:lsid:marinespecies.org:taxname:137102     Species  Animalia
# 10  urn:lsid:marinespecies.org:taxname:137087     Species  Animalia
# 11  urn:lsid:marinespecies.org:taxname:275658     Species  Animalia
# 12  urn:lsid:marinespecies.org:taxname:159023     Species  Animalia
# 13  urn:lsid:marinespecies.org:taxname:126436     Species  Animalia
#
#     propagationFrequency
# 0                   5000
# 1                     63
# 2                    300
# 3                     20
# 4                   1000
# 5                    125
# 6                     63
# 7                    125
# 8                    300
# 9                   1000
# 10                    20
# 11                   300
# 12                    63
# 13                    63

# %% [markdown]
# Now lets add in the WoRMS mapping for species information.

# %%
# merge in the WoRMS species information
df_presence = df_final.merge(df_mapping, how='left', on='vernacularName')  

df_presence.sample(5)
# Out:
#        start_time  dolphin_presence                        dataset_id  \
# 181509        NaT               NaN  noaaSanctSound_CI04_03_bluewhale
# 381921        NaT               NaN  noaaSanctSound_MB01_03_bluewhale
# 247910        NaT               NaN  noaaSanctSound_CI04_05_bluewhale
# 128655        NaT               NaN  noaaSanctSound_CI04_02_bluewhale
# 270676        NaT               NaN  noaaSanctSound_CI04_06_bluewhale
#
#                               WKT decimalLatitude decimalLongitude  \
# 181509  POINT (33.84888 -120.117)        33.84888         -120.117
# 381921    POINT (36.798 -121.976)          36.798         -121.976
# 247910  POINT (33.8489 -120.1171)         33.8489        -120.1171
# 128655  POINT (33.8489 -120.1175)         33.8489        -120.1175
# 270676  POINT (33.8489 -120.1174)         33.8489        -120.1174
#
#        vernacularName                          time  bluewhale_presence  \
# 181509     blue whale 2019-11-03 03:10:25.984000000                 1.0
# 381921     blue whale 2019-11-10 01:22:41.208000000                 1.0
# 247910     blue whale 2020-10-12 23:36:04.064000256                 1.0
# 128655     blue whale 2019-07-23 17:47:28.248000256                 1.0
# 270676     blue whale 2020-11-28 22:21:12.792000000                 1.0
#
#         bluewhale_manual_presence  ...  humpbackwhale_presence  \
# 181509                        NaN  ...                     NaN
# 381921                        NaN  ...                     NaN
# 247910                        NaN  ...                     NaN
# 128655                        NaN  ...                     NaN
# 270676                        NaN  ...                     NaN
#
#         killerwhale_presence  minkewhale_presence  \
# 181509                   NaN                  NaN
# 381921                   NaN                  NaN
# 247910                   NaN                  NaN
# 128655                   NaN                  NaN
# 270676                   NaN                  NaN
#
#         plainfinmidshipman_presence  northatlanticrightwhale_presence  \
# 181509                          NaN                               NaN
# 381921                          NaN                               NaN
# 247910                          NaN                               NaN
# 128655                          NaN                               NaN
# 270676                          NaN                               NaN
#
#                scientificName                           scientificNameID  \
# 181509  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 381921  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 247910  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 128655  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
# 270676  Balaenoptera musculus  urn:lsid:marinespecies.org:taxname:137090
#
#         taxonRank   kingdom  propagationFrequency
# 181509    Species  Animalia                    63
# 381921    Species  Animalia                    63
# 247910    Species  Animalia                    63
# 128655    Species  Animalia                    63
# 270676    Species  Animalia                    63
#
# [5 rows x 27 columns]

# %%
df_presence.columns
# Out:
# Index(['start_time', 'dolphin_presence', 'dataset_id', 'WKT',
#        'decimalLatitude', 'decimalLongitude', 'vernacularName', 'time',
#        'bluewhale_presence', 'bluewhale_manual_presence', 'bocaccio_presence',
#        'finwhale_presence', 'pinniped_presence', 'redgrouper_detection_count',
#        'seiwhale_presence', 'atlanticcod_presence',
#        'blackgrouper_detection_count', 'humpbackwhale_presence',
#        'killerwhale_presence', 'minkewhale_presence',
#        'plainfinmidshipman_presence', 'northatlanticrightwhale_presence',
#        'scientificName', 'scientificNameID', 'taxonRank', 'kingdom',
#        'propagationFrequency'],
#       dtype='object')

# %% [markdown]
# ## Determining `time`
#
# Okay, we have two time variables:
# `start_time`, and `time`
#
# We need to make one `eventDate`!
#
# Let's first check to see if we can mash things together.
#
# First, lets print out all the times when `time` has an entry:

# %%
df_presence.loc[df_presence['time'].notna(),['start_time','time']].sample(20)
# Out:
#        start_time                          time
# 13763         NaT 2020-08-05 06:15:05.240000000
# 591552        NaT 2020-12-01 23:45:29.952000256
# 338704        NaT 2020-12-10 07:26:42.672000000
# 507469        NaT 2018-12-20 22:49:31.608000000
# 95345         NaT 2021-09-06 14:13:55.112000000
# 54322         NaT 2020-10-18 23:21:49.528000000
# 53154         NaT 2020-10-17 06:36:43.120000000
# 567323        NaT 2020-09-06 08:19:35.520000000
# 231718        NaT 2020-09-20 18:45:20.512000000
# 292438        NaT 2021-07-28 05:49:55.104000000
# 408764        NaT 2020-08-12 06:25:11.632000000
# 358139        NaT 2019-09-12 10:56:52.280000000
# 61277         NaT 2020-11-06 08:40:56.048000000
# 324384        NaT 2021-10-07 23:29:38.080000000
# 575792        NaT 2020-09-28 21:37:51.200000000
# 389559        NaT 2019-11-20 21:35:06.672000000
# 397281        NaT 2019-12-08 10:13:41.960000000
# 423607        NaT 2020-10-09 04:13:56.992000000
# 104976        NaT 2021-10-28 13:49:50.832000000
# 370875        NaT 2019-10-25 11:29:39.976000000

# %% [markdown]
# Okay, so let's see if `start_time` is only NaN for all those rows:

# %%
df_presence.loc[df_presence['time'].notna(),'start_time'].unique()
# Out:
# array(['NaT'], dtype='datetime64[ns]')

# %% [markdown]
# Looking good! We have only NaN's returned so we don't have conflicting dates between `start_time` and `time`.

# %% [markdown]
# Fantastic! So, this means we can make a new column for `eventDate` which merges `time` into `start_time`.

# %%
#df_presence_copy = df_presence.copy()

# start eventDate column with values where `time` exists.
df_presence['eventDate'] = df_presence.loc[df_presence['time'].notna(),['time']]

# fillna with values from start_time
df_presence['eventDate'].fillna(df_presence['start_time'], inplace=True)

df_presence[['eventDate','time','start_time']].sample(n=5)
# Out:
#                      eventDate                    time start_time
# 116785 2019-06-27 13:06:12.336 2019-06-27 13:06:12.336        NaT
# 551719 2019-11-17 01:13:48.928 2019-11-17 01:13:48.928        NaT
# 470289 2021-01-31 03:24:13.920 2021-01-31 03:24:13.920        NaT
# 592650 2020-12-09 00:54:28.576 2020-12-09 00:54:28.576        NaT
# 428263 2020-10-19 14:05:28.296 2020-10-19 14:05:28.296        NaT

# %%
df_presence.loc[df_presence['eventDate'].isna()]
# Out:
# Empty DataFrame
# Columns: [start_time, dolphin_presence, dataset_id, WKT, decimalLatitude, decimalLongitude, vernacularName, time, bluewhale_presence, bluewhale_manual_presence, bocaccio_presence, finwhale_presence, pinniped_presence, redgrouper_detection_count, seiwhale_presence, atlanticcod_presence, blackgrouper_detection_count, humpbackwhale_presence, killerwhale_presence, minkewhale_presence, plainfinmidshipman_presence, northatlanticrightwhale_presence, scientificName, scientificNameID, taxonRank, kingdom, propagationFrequency, eventDate]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ## Double check we moved the right values
#
# Show me where `time` is NaN and we used `start_time`.

# %%
df_presence.loc[df_presence['time'].isna(),['start_time','eventDate','time']].sample(5)
# Out:
#                           start_time                     eventDate time
# 672147 2020-01-09 19:00:00.000000000 2020-01-09 19:00:00.000000000  NaT
# 625625 2020-04-13 04:24:32.341000192 2020-04-13 04:24:32.341000192  NaT
# 676220 2019-06-23 09:00:00.000000000 2019-06-23 09:00:00.000000000  NaT
# 657342 2019-09-24 05:44:58.614000128 2019-09-24 05:44:58.614000128  NaT
# 608600 2019-10-22 03:08:01.860000256 2019-10-22 03:08:01.860000256  NaT

# %% [markdown]
# Show me where `start_time` is NaN and we used `time`.

# %%
df_presence.loc[df_presence['start_time'].isna(),['start_time','eventDate','time']].sample(5)
# Out:
#        start_time                     eventDate                          time
# 409503        NaT 2020-08-17 08:24:09.200000000 2020-08-17 08:24:09.200000000
# 317524        NaT 2021-09-24 13:03:51.176000000 2021-09-24 13:03:51.176000000
# 216989        NaT 2020-08-25 05:17:54.328000000 2020-08-25 05:17:54.328000000
# 529394        NaT 2020-08-09 02:50:25.232000000 2020-08-09 02:50:25.232000000
# 124050        NaT 2019-07-13 19:48:09.192000256 2019-07-13 19:48:09.192000256

# %% [markdown]
# Now, lets make `eventDate` the index for our DataFrame so we can make a nice plot and output the dates in a format we like.

# %%
df_presence['eventDate'] = pd.to_datetime(df_presence['eventDate'], format='%Y-%m-%d %H:%M:%S.%f')

df_presence
# Out:
#                 start_time  dolphin_presence  \
# 0      2018-12-15 04:00:00               1.0
# 1      2018-12-15 05:00:00               1.0
# 2      2018-12-15 06:00:00               1.0
# 3      2018-12-15 07:00:00               1.0
# 4      2018-12-15 18:00:00               1.0
# ...                    ...               ...
# 713671 2020-11-18 00:00:00               NaN
# 713672 2020-11-19 00:00:00               NaN
# 713673 2020-11-20 00:00:00               NaN
# 713674 2020-11-21 00:00:00               NaN
# 713675 2020-11-22 00:00:00               NaN
#
#                                 dataset_id                          WKT  \
# 0       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 1       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 2       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 3       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# 4       noaaSanctSound_GR01_01_dolphins_1h   POINT (31.396417 -80.8904)
# ...                                    ...                          ...
# 713671  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713672  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713673  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713674  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
# 713675  noaaSanctSound_SB03_12_finwhale_1d  POINT (42.25508 -70.179047)
#
#        decimalLatitude decimalLongitude vernacularName time  \
# 0            31.396417         -80.8904        dolphin  NaT
# 1            31.396417         -80.8904        dolphin  NaT
# 2            31.396417         -80.8904        dolphin  NaT
# 3            31.396417         -80.8904        dolphin  NaT
# 4            31.396417         -80.8904        dolphin  NaT
# ...                ...              ...            ...  ...
# 713671        42.25508       -70.179047      fin whale  NaT
# 713672        42.25508       -70.179047      fin whale  NaT
# 713673        42.25508       -70.179047      fin whale  NaT
# 713674        42.25508       -70.179047      fin whale  NaT
# 713675        42.25508       -70.179047      fin whale  NaT
#
#         bluewhale_presence  bluewhale_manual_presence  ...  \
# 0                      NaN                        NaN  ...
# 1                      NaN                        NaN  ...
# 2                      NaN                        NaN  ...
# 3                      NaN                        NaN  ...
# 4                      NaN                        NaN  ...
# ...                    ...                        ...  ...
# 713671                 NaN                        NaN  ...
# 713672                 NaN                        NaN  ...
# 713673                 NaN                        NaN  ...
# 713674                 NaN                        NaN  ...
# 713675                 NaN                        NaN  ...
#
#         killerwhale_presence  minkewhale_presence  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
# ...                      ...                  ...
# 713671                   NaN                  NaN
# 713672                   NaN                  NaN
# 713673                   NaN                  NaN
# 713674                   NaN                  NaN
# 713675                   NaN                  NaN
#
#         plainfinmidshipman_presence  northatlanticrightwhale_presence  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 713671                          NaN                               NaN
# 713672                          NaN                               NaN
# 713673                          NaN                               NaN
# 713674                          NaN                               NaN
# 713675                          NaN                               NaN
#
#                scientificName                           scientificNameID  \
# 0                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 1                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 2                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 3                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# 4                     Cetacea    urn:lsid:marinespecies.org:taxname:2688
# ...                       ...                                        ...
# 713671  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713672  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713673  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713674  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
# 713675  Balaenoptera physalus  urn:lsid:marinespecies.org:taxname:137091
#
#          taxonRank   kingdom  propagationFrequency           eventDate
# 0       Infraorder  Animalia                  5000 2018-12-15 04:00:00
# 1       Infraorder  Animalia                  5000 2018-12-15 05:00:00
# 2       Infraorder  Animalia                  5000 2018-12-15 06:00:00
# 3       Infraorder  Animalia                  5000 2018-12-15 07:00:00
# 4       Infraorder  Animalia                  5000 2018-12-15 18:00:00
# ...            ...       ...                   ...                 ...
# 713671     Species  Animalia                    20 2020-11-18 00:00:00
# 713672     Species  Animalia                    20 2020-11-19 00:00:00
# 713673     Species  Animalia                    20 2020-11-20 00:00:00
# 713674     Species  Animalia                    20 2020-11-21 00:00:00
# 713675     Species  Animalia                    20 2020-11-22 00:00:00
#
# [713676 rows x 28 columns]

# %% [markdown]
# ## Write presence file

# %%
# overwrite to csv file
fname = 'data/sanctsound_presence.zip'
df_presence.to_csv(fname, index=False, compression='zip')

df_presence.sample(10)
# Out:
#                     start_time  dolphin_presence  \
# 234983                     NaT               NaN
# 510351                     NaT               NaN
# 517690                     NaT               NaN
# 72830                      NaT               NaN
# 528180                     NaT               NaN
# 520102                     NaT               NaN
# 472381 2021-08-13 08:19:10.856               NaN
# 246192                     NaT               NaN
# 228775                     NaT               NaN
# 552081                     NaT               NaN
#
#                               dataset_id                           WKT  \
# 234983  noaaSanctSound_CI04_05_bluewhale     POINT (33.8489 -120.1171)
# 510351  noaaSanctSound_MB02_03_bluewhale     POINT (36.6495 -121.9084)
# 517690  noaaSanctSound_MB02_03_bluewhale     POINT (36.6495 -121.9084)
# 72830   noaaSanctSound_CI02_07_bluewhale     POINT (34.0855 -120.5224)
# 528180  noaaSanctSound_MB02_05_bluewhale     POINT (36.6484 -121.9075)
# 520102  noaaSanctSound_MB02_03_bluewhale     POINT (36.6495 -121.9084)
# 472381  noaaSanctSound_MB01_09_bluewhale      POINT (36.798 -122.9758)
# 246192  noaaSanctSound_CI04_05_bluewhale     POINT (33.8489 -120.1171)
# 228775  noaaSanctSound_CI04_05_bluewhale     POINT (33.8489 -120.1171)
# 552081  noaaSanctSound_MB03_02_bluewhale  POINT (36.37021 -122.314903)
#
#        decimalLatitude decimalLongitude vernacularName  \
# 234983         33.8489        -120.1171     blue whale
# 510351         36.6495        -121.9084     blue whale
# 517690         36.6495        -121.9084     blue whale
# 72830          34.0855        -120.5224     blue whale
# 528180         36.6484        -121.9075     blue whale
# 520102         36.6495        -121.9084     blue whale
# 472381          36.798        -122.9758     blue whale
# 246192         33.8489        -120.1171     blue whale
# 228775         33.8489        -120.1171     blue whale
# 552081        36.37021      -122.314903     blue whale
#
#                                 time  bluewhale_presence  \
# 234983 2020-09-23 23:51:51.280000000                 1.0
# 510351 2019-10-14 16:59:19.216000000                 1.0
# 517690 2019-11-15 11:09:46.360000256                 1.0
# 72830  2021-07-13 10:04:36.968000000                 1.0
# 528180 2020-07-14 17:41:54.488000000                 1.0
# 520102 2019-12-01 16:28:58.192000256                 1.0
# 472381                           NaT                 1.0
# 246192 2020-10-10 04:17:40.000000000                 1.0
# 228775 2020-09-12 07:26:43.552000000                 1.0
# 552081 2019-11-21 03:49:34.480000000                 1.0
#
#         bluewhale_manual_presence  ...  killerwhale_presence  \
# 234983                        NaN  ...                   NaN
# 510351                        NaN  ...                   NaN
# 517690                        NaN  ...                   NaN
# 72830                         NaN  ...                   NaN
# 528180                        NaN  ...                   NaN
# 520102                        NaN  ...                   NaN
# 472381                        NaN  ...                   NaN
# 246192                        NaN  ...                   NaN
# 228775                        NaN  ...                   NaN
# 552081                        NaN  ...                   NaN
#
#         minkewhale_presence  plainfinmidshipman_presence  \
# 234983                  NaN                          NaN
# 510351                  NaN                          NaN
# 517690                  NaN                          NaN
# 72830                   NaN                          NaN
# 528180                  NaN                          NaN
# 520102                  NaN                          NaN
# 472381                  NaN                          NaN
# 246192                  NaN                          NaN
# 228775                  NaN                          NaN
# 552081                  NaN                          NaN
#
#         northatlanticrightwhale_presence         scientificName  \
# 234983                               NaN  Balaenoptera musculus
# 510351                               NaN  Balaenoptera musculus
# 517690                               NaN  Balaenoptera musculus
# 72830                                NaN  Balaenoptera musculus
# 528180                               NaN  Balaenoptera musculus
# 520102                               NaN  Balaenoptera musculus
# 472381                               NaN  Balaenoptera musculus
# 246192                               NaN  Balaenoptera musculus
# 228775                               NaN  Balaenoptera musculus
# 552081                               NaN  Balaenoptera musculus
#
#                                  scientificNameID  taxonRank   kingdom  \
# 234983  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 510351  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 517690  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 72830   urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 528180  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 520102  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 472381  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 246192  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 228775  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
# 552081  urn:lsid:marinespecies.org:taxname:137090    Species  Animalia
#
#         propagationFrequency                     eventDate
# 234983                    63 2020-09-23 23:51:51.280000000
# 510351                    63 2019-10-14 16:59:19.216000000
# 517690                    63 2019-11-15 11:09:46.360000256
# 72830                     63 2021-07-13 10:04:36.968000000
# 528180                    63 2020-07-14 17:41:54.488000000
# 520102                    63 2019-12-01 16:28:58.192000256
# 472381                    63 2021-08-13 08:19:10.856000000
# 246192                    63 2020-10-10 04:17:40.000000000
# 228775                    63 2020-09-12 07:26:43.552000000
# 552081                    63 2019-11-21 03:49:34.480000000
#
# [10 rows x 28 columns]
