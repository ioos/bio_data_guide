# %% [markdown]
# # Processing zooplankton data to DWC compliant files

# %%
#get coding environment ready
#bring in pandas for manipulating columns, put no limit on the amount of columns in display
import pandas as pd
pd.options.display.max_columns = None

#bring in numpy to manipulate numbers
import numpy as np

#I need random numbers
import random

#I need to manipulate dates
import datetime

# %% [markdown]
# # Let start with data: read in existing csv

# %% [markdown]
# ## take a look at the file

# %%
#Make a dataframe, parse dates
raw = pd.read_csv('https://raw.githubusercontent.com/ioos/bio_data_guide/main/datasets/AMBON_zooplankton/data/raw/AMBON2017150.csv', parse_dates=['Date_Time'])

raw.head()
# Out:
#       Cruise Station                       Type           Date_Time  \
# 0  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 1  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 2  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 3  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 4  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
#
#    Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 0                         -163.5095                            69.3443
# 1                         -163.5095                            69.3443
# 2                         -163.5095                            69.3443
# 3                         -163.5095                            69.3443
# 4                         -163.5095                            69.3443
#
#    Bottom_Depth_[m]  Cast_Number  Depth_[m] Accepted_Organism_Identification  \
# 0                15          NaN         12                           Pisces
# 1                15          NaN         12                          Isopoda
# 2                15          NaN         12                 Evadne nordmanni
# 3                15          NaN         12            Pseudocalanus newmani
# 4                15          NaN         12            Pseudocalanus acuspes
#
#   Life_Stage  APHIA_ID  Abundance_[#/m3]  Biomass_[mg dw/m3]
# 0     larvae   11676.0             1.172                 NaN
# 1               1131.0             1.172                 NaN
# 2             106273.0             1.172              0.0086
# 3             157679.0             4.686              0.0121
# 4             104514.0             4.686              0.0335

# %%
raw.tail()
# Out:
#          Cruise Station                       Type           Date_Time  \
# 2931  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2932  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2933  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2934  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-07 01:39:00
# 2935  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-07 01:39:00
#
#       Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 2931                         -168.2368                             67.897
# 2932                         -168.2368                             67.897
# 2933                         -168.2368                             67.897
# 2934                         -168.2368                             67.897
# 2935                         -168.2368                             67.897
#
#       Bottom_Depth_[m]  Cast_Number  Depth_[m]  \
# 2931                59          NaN         56
# 2932                59          NaN         56
# 2933                59          NaN         56
# 2934                59          NaN         56
# 2935                59          NaN         56
#
#      Accepted_Organism_Identification Life_Stage  APHIA_ID  Abundance_[#/m3]  \
# 2931              Parasagitta elegans             105440.0             0.998
# 2932     Calanus glacialis/marshallae             196770.0            10.112
# 2933             Neocalanus plumchrus             196772.0             7.983
# 2934                         Decapoda   megalopa    1130.0             2.195
# 2935             Neocalanus cristatus             104470.0             1.064
#
#       Biomass_[mg dw/m3]
# 2931              2.0528
# 2932              2.8979
# 2933              5.0574
# 2934              5.0972
# 2935              5.0994

# %%
raw.describe()
#so it's count of 2936
# Out:
#        Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# count                       2936.000000                        2936.000000
# mean                        -164.283995                          70.388515
# std                            2.515989                           1.177150
# min                         -168.954100                          67.666400
# 25%                         -166.472300                          69.821400
# 50%                         -163.960900                          70.648000
# 75%                         -162.250800                          71.232000
# max                         -159.397200                          72.496400
#
#        Bottom_Depth_[m]  Cast_Number    Depth_[m]      APHIA_ID  \
# count       2936.000000          0.0  2936.000000  2.934000e+03
# mean          42.691757          NaN    39.691757  9.396167e+04
# std            8.678432          NaN     8.678432  7.801204e+04
# min           15.000000          NaN    12.000000  1.010000e+02
# 25%           41.000000          NaN    38.000000  1.268000e+03
# 50%           45.000000          NaN    42.000000  1.045140e+05
# 75%           48.000000          NaN    45.000000  1.178490e+05
# max           59.000000          NaN    56.000000  1.434803e+06
#
#        Abundance_[#/m3]  Biomass_[mg dw/m3]
# count       2936.000000         2909.000000
# mean         223.325846            0.745213
# std         1478.179158            4.116812
# min            0.025000            0.000010
# 25%            0.420750            0.006800
# 50%            3.985000            0.046200
# 75%           31.895250            0.276300
# max        37568.289000           99.113600

# %%
#let's check for non identified observations, just in case
raw["APHIA_ID"].isnull().sum()
# Out:
# 2

# %%
raw.dropna(subset=['APHIA_ID'], inplace=True)

# %%
raw.tail()
# Out:
#          Cruise Station                       Type           Date_Time  \
# 2931  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2932  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2933  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-22 03:47:00
# 2934  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-07 01:39:00
# 2935  AMBON2017  DBO3.6  TWINRING_150UM_MICROSCOPY 2017-08-07 01:39:00
#
#       Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 2931                         -168.2368                             67.897
# 2932                         -168.2368                             67.897
# 2933                         -168.2368                             67.897
# 2934                         -168.2368                             67.897
# 2935                         -168.2368                             67.897
#
#       Bottom_Depth_[m]  Cast_Number  Depth_[m]  \
# 2931                59          NaN         56
# 2932                59          NaN         56
# 2933                59          NaN         56
# 2934                59          NaN         56
# 2935                59          NaN         56
#
#      Accepted_Organism_Identification Life_Stage  APHIA_ID  Abundance_[#/m3]  \
# 2931              Parasagitta elegans             105440.0             0.998
# 2932     Calanus glacialis/marshallae             196770.0            10.112
# 2933             Neocalanus plumchrus             196772.0             7.983
# 2934                         Decapoda   megalopa    1130.0             2.195
# 2935             Neocalanus cristatus             104470.0             1.064
#
#       Biomass_[mg dw/m3]
# 2931              2.0528
# 2932              2.8979
# 2933              5.0574
# 2934              5.0972
# 2935              5.0994

# %%
# checked NaNs removed
raw["APHIA_ID"].isnull().sum()
# Out:
# 0

# %%
#Ok, doublechecking that it was an ok thing
raw.describe()
#count of 2934, as expected
#raw.head()
# Out:
#        Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# count                       2934.000000                        2934.000000
# mean                        -164.281753                          70.389463
# std                            2.515320                           1.176640
# min                         -168.954100                          67.666400
# 25%                         -166.472300                          69.821400
# 50%                         -163.960900                          70.648000
# 75%                         -162.250800                          71.232000
# max                         -159.397200                          72.496400
#
#        Bottom_Depth_[m]  Cast_Number    Depth_[m]      APHIA_ID  \
# count       2934.000000          0.0  2934.000000  2.934000e+03
# mean          42.684390          NaN    39.684390  9.396167e+04
# std            8.675609          NaN     8.675609  7.801204e+04
# min           15.000000          NaN    12.000000  1.010000e+02
# 25%           41.000000          NaN    38.000000  1.268000e+03
# 50%           45.000000          NaN    42.000000  1.045140e+05
# 75%           48.000000          NaN    45.000000  1.178490e+05
# max           59.000000          NaN    56.000000  1.434803e+06
#
#        Abundance_[#/m3]  Biomass_[mg dw/m3]
# count       2934.000000         2907.000000
# mean         223.476458            0.711606
# std         1478.671789            3.691712
# min            0.025000            0.000010
# 25%            0.420250            0.006800
# 50%            3.985000            0.046200
# 75%           32.003750            0.276100
# max        37568.289000           82.354000

# %% [markdown]
# ## list existing column headers, match to DWC terms

# %%
# what are the existing column headers?
raw.columns
# Out:
# Index(['Cruise', 'Station', 'Type', 'Date_Time',
#        'Longitude_[decimal_degrees_east]', 'Latitude_[decimal _degrees_north]',
#        'Bottom_Depth_[m]', 'Cast_Number', 'Depth_[m]',
#        'Accepted_Organism_Identification', 'Life_Stage', 'APHIA_ID',
#        'Abundance_[#/m3]', 'Biomass_[mg dw/m3]'],
#       dtype='object')

# %%
# dataframe processing
# make a copy
df = raw.copy()
df.head()
# Out:
#       Cruise Station                       Type           Date_Time  \
# 0  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 1  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 2  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 3  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 4  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
#
#    Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 0                         -163.5095                            69.3443
# 1                         -163.5095                            69.3443
# 2                         -163.5095                            69.3443
# 3                         -163.5095                            69.3443
# 4                         -163.5095                            69.3443
#
#    Bottom_Depth_[m]  Cast_Number  Depth_[m] Accepted_Organism_Identification  \
# 0                15          NaN         12                           Pisces
# 1                15          NaN         12                          Isopoda
# 2                15          NaN         12                 Evadne nordmanni
# 3                15          NaN         12            Pseudocalanus newmani
# 4                15          NaN         12            Pseudocalanus acuspes
#
#   Life_Stage  APHIA_ID  Abundance_[#/m3]  Biomass_[mg dw/m3]
# 0     larvae   11676.0             1.172                 NaN
# 1               1131.0             1.172                 NaN
# 2             106273.0             1.172              0.0086
# 3             157679.0             4.686              0.0121
# 4             104514.0             4.686              0.0335

# %%
#what I need is class(df[Station]) and levels. In Pandas that's...
#df['Station'].astype('category')
#hmm there are 78, that's, not going to work
df['APHIA_ID'].astype('category')
#hmmm 78

#OK, also, unique()
#df.describe(include='all', datetime_is_numeric=True)
# Out:
# C:\Users\Mathew.Biddle\programs\Anaconda3\envs\sandbox\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# 0        11676.0
# 1         1131.0
# 2       106273.0
# 3       157679.0
# 4       104514.0
#           ...
# 2931    105440.0
# 2932    196770.0
# 2933    196772.0
# 2934      1130.0
# 2935    104470.0
# Name: APHIA_ID, Length: 2934, dtype: category
# Categories (99, float64): [101.0, 105.0, 883.0, 1082.0, ..., 346398.0, 353708.0, 355067.0, 1434803.0]

# %% [markdown]
# ## Enough looking, let's get the two files as one
#
# Zooplankton has two file system going on.
# because of net size.
# Let's rowbind the 150 and the 505 datasets together. luckily, their columns already look alike.

# %%
#Rename df to it's netsize

df150 = df

df150.head()

#read in the 505 data

#%ls ../Zooplankton_505

raw2 = pd.read_csv('https://raw.githubusercontent.com/ioos/bio_data_guide/main/datasets/AMBON_zooplankton/data/raw/AMBON2017505.csv', parse_dates=['Date_Time'])

raw2.tail()
# Out:
#          Cruise Station                    Type           Date_Time  \
# 1788  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 1789  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 1790  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 1791  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 1792  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
#
#       Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 1788                         -168.9554                            67.6645
# 1789                         -168.9554                            67.6645
# 1790                         -168.9554                            67.6645
# 1791                         -168.9554                            67.6645
# 1792                         -168.9554                            67.6645
#
#       Bottom_Depth_[m]  Cast_Number  Depth_[m]  \
# 1788                48            1         45
# 1789                48            1         45
# 1790                48            1         45
# 1791                48            1         45
# 1792                48            1         45
#
#      Accepted_Organism_Identification Life_Stage  APHIA_ID  Abundance_[#/m3]  \
# 1788                            Beroe               106331             0.047
# 1789              Parasagitta elegans               105440             5.985
# 1790                     Euphausiacea   juvenile      1128            10.259
# 1791          Bolinopsis infundibulum               106939             0.404
# 1792                           Pisces     larvae     11676             0.024
#
#       Biomass_[mg dw/m3]
# 1788              1.0295
# 1789              2.8788
# 1790              5.4358
# 1791              5.4557
# 1792                 NaN

# %%
#check for NaN
raw2["APHIA_ID"].isnull().sum()
#hooray, 0
#raw2[1200:1206]
# Out:
# 0

# %%
raw2.describe()
#1793 observations
# Out:
#        Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# count                       1793.000000                        1793.000000
# mean                        -159.825056                          70.587651
# std                           37.278220                           1.212839
# min                         -168.955400                          67.664500
# 25%                         -166.065800                          70.006600
# 50%                         -163.797900                          70.934400
# 75%                         -162.151600                          71.449000
# max                          159.410600                          72.496900
#
#        Bottom_Depth_[m]  Cast_Number    Depth_[m]       APHIA_ID  \
# count       1793.000000  1793.000000  1793.000000    1793.000000
# mean          44.101506    40.776352    41.101506  104628.774679
# std            7.305878    24.323931     7.305878   70729.662967
# min           23.000000     1.000000    20.000000     883.000000
# 25%           41.000000    21.000000    38.000000  103256.000000
# 50%           45.000000    38.000000    42.000000  106673.000000
# 75%           48.000000    62.000000    45.000000  117755.000000
# max           59.000000    85.000000    56.000000  355067.000000
#
#        Abundance_[#/m3]  Biomass_[mg dw/m3]
# count       1793.000000         1748.000000
# mean           3.799430            1.341224
# std           30.159061            7.115910
# min            0.005000            0.000000
# 25%            0.028000            0.010100
# 50%            0.102000            0.060800
# 75%            0.523000            0.386325
# max          804.396000          210.000000

# %%
#rowbind these two csvs together
#first make the csvs raw copies
df505 = raw2.copy()

df505.head()
# Out:
#       Cruise Station                    Type           Date_Time  \
# 0  AMBON2017   ML1.2  BONGO_505UM_MICROSCOPY 2017-08-17 18:22:00
# 1  AMBON2017   ML1.2  BONGO_505UM_MICROSCOPY 2017-08-17 18:22:00
# 2  AMBON2017   ML1.2  BONGO_505UM_MICROSCOPY 2017-08-17 18:22:00
# 3  AMBON2017   ML1.2  BONGO_505UM_MICROSCOPY 2017-08-17 18:22:00
# 4  AMBON2017   ML1.2  BONGO_505UM_MICROSCOPY 2017-08-17 18:22:00
#
#    Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 0                         -163.0342                            70.1434
# 1                         -163.0342                            70.1434
# 2                         -163.0342                            70.1434
# 3                         -163.0342                            70.1434
# 4                         -163.0342                            70.1434
#
#    Bottom_Depth_[m]  Cast_Number  Depth_[m] Accepted_Organism_Identification  \
# 0                23           56         20               Acartia longiremis
# 1                23           56         20              Eurytemora pacifica
# 2                23           56         20                          Hyperia
# 3                23           56         20                Limacina helicina
# 4                23           56         20            Pseudocalanus acuspes
#
#   Life_Stage  APHIA_ID  Abundance_[#/m3]  Biomass_[mg dw/m3]
# 0               104257             0.057              0.0002
# 1               232028             0.057              0.0007
# 2               101796             0.014              0.0012
# 3               140223             0.014              0.0013
# 4               104514             0.114              0.0015

# %%
df505.describe()
# Out:
#        Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# count                       1793.000000                        1793.000000
# mean                        -159.825056                          70.587651
# std                           37.278220                           1.212839
# min                         -168.955400                          67.664500
# 25%                         -166.065800                          70.006600
# 50%                         -163.797900                          70.934400
# 75%                         -162.151600                          71.449000
# max                          159.410600                          72.496900
#
#        Bottom_Depth_[m]  Cast_Number    Depth_[m]       APHIA_ID  \
# count       1793.000000  1793.000000  1793.000000    1793.000000
# mean          44.101506    40.776352    41.101506  104628.774679
# std            7.305878    24.323931     7.305878   70729.662967
# min           23.000000     1.000000    20.000000     883.000000
# 25%           41.000000    21.000000    38.000000  103256.000000
# 50%           45.000000    38.000000    42.000000  106673.000000
# 75%           48.000000    62.000000    45.000000  117755.000000
# max           59.000000    85.000000    56.000000  355067.000000
#
#        Abundance_[#/m3]  Biomass_[mg dw/m3]
# count       1793.000000         1748.000000
# mean           3.799430            1.341224
# std           30.159061            7.115910
# min            0.005000            0.000000
# 25%            0.028000            0.010100
# 50%            0.102000            0.060800
# 75%            0.523000            0.386325
# max          804.396000          210.000000

# %%
#so now with have df150 and df505, let's concat

df = pd.concat([df150, df505])
df.describe()
#4727 count total
#df[2930:2940]
df['Life_Stage'].unique()
# Out:
# array(['larvae', ' ', 'male', 'nauplii', 'cyprid', 'bipinnaria',
#        'cyphonautes', 'calytopsis', 'zoea', 'furcilia', 'juvenile',
#        'megalopa', 'eudoxid', '0'], dtype=object)

# %%
# Yay for one big dataframe

df.reset_index(drop=True, inplace=True)
df.tail()
# Out:
#          Cruise Station                    Type           Date_Time  \
# 4722  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 4723  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 4724  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 4725  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
# 4726  AMBON2017  DBO3.8  BONGO_505UM_MICROSCOPY 2017-08-06 19:33:00
#
#       Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 4722                         -168.9554                            67.6645
# 4723                         -168.9554                            67.6645
# 4724                         -168.9554                            67.6645
# 4725                         -168.9554                            67.6645
# 4726                         -168.9554                            67.6645
#
#       Bottom_Depth_[m]  Cast_Number  Depth_[m]  \
# 4722                48          1.0         45
# 4723                48          1.0         45
# 4724                48          1.0         45
# 4725                48          1.0         45
# 4726                48          1.0         45
#
#      Accepted_Organism_Identification Life_Stage  APHIA_ID  Abundance_[#/m3]  \
# 4722                            Beroe             106331.0             0.047
# 4723              Parasagitta elegans             105440.0             5.985
# 4724                     Euphausiacea   juvenile    1128.0            10.259
# 4725          Bolinopsis infundibulum             106939.0             0.404
# 4726                           Pisces     larvae   11676.0             0.024
#
#       Biomass_[mg dw/m3]
# 4722              1.0295
# 4723              2.8788
# 4724              5.4358
# 4725              5.4557
# 4726                 NaN

# %% [markdown]
# ## EventDate as ISO format

# %%
#let's get the eventDate looking ISO_perfect
#df.head()

list = df['Date_Time']
list
# Out:
# 0      2017-08-20 22:48:00
# 1      2017-08-20 22:48:00
# 2      2017-08-20 22:48:00
# 3      2017-08-20 22:48:00
# 4      2017-08-20 22:48:00
#                ...
# 4722   2017-08-06 19:33:00
# 4723   2017-08-06 19:33:00
# 4724   2017-08-06 19:33:00
# 4725   2017-08-06 19:33:00
# 4726   2017-08-06 19:33:00
# Name: Date_Time, Length: 4727, dtype: datetime64[ns]

# %%
#iso format the thing? from datetime package
test = list[1]
test
#est.isoformat()
test = test.isoformat()
#est
print(test)
test
# Out:
# 2017-08-20T22:48:00
# '2017-08-20T22:48:00'

# %%
#Make a list, build it with iso format, add 'Z' for utc timezone

storage = []
for x in list:
    x=x.isoformat()
    x=x+'Z'
    storage.append(x)

    #I have no idea why I can't write over in place in the list, but dumping the output into another list works for me

# %%
storage[1:6]
# Out:
# ['2017-08-20T22:48:00Z',
#  '2017-08-20T22:48:00Z',
#  '2017-08-20T22:48:00Z',
#  '2017-08-20T22:48:00Z',
#  '2017-08-20T22:48:00Z']

# %%
#done
#storage
df['eventDate']=storage
df.head()
# Out:
#       Cruise Station                       Type           Date_Time  \
# 0  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 1  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 2  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 3  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 4  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
#
#    Longitude_[decimal_degrees_east]  Latitude_[decimal _degrees_north]  \
# 0                         -163.5095                            69.3443
# 1                         -163.5095                            69.3443
# 2                         -163.5095                            69.3443
# 3                         -163.5095                            69.3443
# 4                         -163.5095                            69.3443
#
#    Bottom_Depth_[m]  Cast_Number  Depth_[m] Accepted_Organism_Identification  \
# 0                15          NaN         12                           Pisces
# 1                15          NaN         12                          Isopoda
# 2                15          NaN         12                 Evadne nordmanni
# 3                15          NaN         12            Pseudocalanus newmani
# 4                15          NaN         12            Pseudocalanus acuspes
#
#   Life_Stage  APHIA_ID  Abundance_[#/m3]  Biomass_[mg dw/m3]  \
# 0     larvae   11676.0             1.172                 NaN
# 1               1131.0             1.172                 NaN
# 2             106273.0             1.172              0.0086
# 3             157679.0             4.686              0.0121
# 4             104514.0             4.686              0.0335
#
#               eventDate
# 0  2017-08-20T22:48:00Z
# 1  2017-08-20T22:48:00Z
# 2  2017-08-20T22:48:00Z
# 3  2017-08-20T22:48:00Z
# 4  2017-08-20T22:48:00Z

# %% [markdown]
# ---
# # eventID and datasetID and OccurenceID for all the tables
#
# So my understanding is.....
# One occurenceID for each row as is here, in the untidy, because 2 measurements were taken off a given species from the 'station stop' on the cruise. And then reference that occurenceID in the long tidy measurementorFact table

# %%
# added by mmb 2021-10-04
# cast number should be a string not a number, so let's replace NaN with empty and convert number to string as integer.
df['Cast_Number_conv'] = df['Cast_Number'].astype('Int64').astype(str).replace('<NA>','?')


# find where lifeStage is either 'male' or 'female' and return that to another column called 'sex'
df['sex'] = df.loc[ (df['Life_Stage'] == 'male') | (df['Life_Stage'] == 'female'), ['Life_Stage'] ]
df['sex'].replace(np.nan, '?', inplace=True)
#df.loc[ (df['Life_Stage'] == 'male'), ['Life_Stage']] = ''
#df.loc[ (df['Life_Stage'] == 'female'), ['Life_Stage']] = ''
        
# Adjust life stage to not have null values but empty cells
df['Life_Stage_conv'] = df['Life_Stage'].replace(' ','?')

# adjust Accepted_Organism_Identification to separate by underscores, replace / with _ as well
df['Accepted_Organism_Identification_conv'] = df['Accepted_Organism_Identification'].str.replace(' ','_').str.replace('/','_')


df[['Life_Stage_conv','Cast_Number_conv','Accepted_Organism_Identification_conv','sex']]
# Out:
#      Life_Stage_conv Cast_Number_conv Accepted_Organism_Identification_conv  \
# 0             larvae                ?                                Pisces
# 1                  ?                ?                               Isopoda
# 2                  ?                ?                      Evadne_nordmanni
# 3                  ?                ?                 Pseudocalanus_newmani
# 4                  ?                ?                 Pseudocalanus_acuspes
# ...              ...              ...                                   ...
# 4722               ?                1                                 Beroe
# 4723               ?                1                   Parasagitta_elegans
# 4724        juvenile                1                          Euphausiacea
# 4725               ?                1               Bolinopsis_infundibulum
# 4726          larvae                1                                Pisces
#
#      sex
# 0      ?
# 1      ?
# 2      ?
# 3      ?
# 4      ?
# ...   ..
# 4722   ?
# 4723   ?
# 4724   ?
# 4725   ?
# 4726   ?
#
# [4727 rows x 4 columns]

# %%
df['sex'].unique()
# Out:
# array(['?', 'male'], dtype=object)

# %%
#let's do two eggs in one nest with the datasetID and occurenceID stuff
#first, datasetID
df['datasetID'] = 'AMBON_Zooplankton_2017'

#occurenceID -- I'll have to tackle that separately
#df['occurrenceID'] =df['datasetID']+'_'+df['Station']+'_'

# mmb 2021-10-04 
# join string columns together as id
# need to convert biomass to a string to join
df['depth_str'] = df['Depth_[m]'].astype(str)
df['date_str'] = df['Date_Time'].dt.strftime('%Y-%m-%dT%H:%M:%S%Z')
df['biomass_str'] = df['Biomass_[mg dw/m3]'].astype(str)

df['occurrenceID'] = df[['datasetID',
                         'Station',
                         'Cast_Number_conv',
                         'Accepted_Organism_Identification_conv',
                         'Life_Stage_conv',
                         'sex',
                         'Type',
                         #'biomass_str',
                         'depth_str',
                         'date_str',
                        ]].agg('_'.join, axis=1)

#then eventID
df['eventID'] = df['datasetID']+'_'+df['Station']+'_'+df['eventDate']

# %%
#How many rows are in this dataframe?
#df.describe()
df['occurrenceID'].tail().tolist() # edited mmb 2021-07-23
#4726
# Out:
# ['AMBON_Zooplankton_2017_DBO3.8_1_Beroe_?_?_BONGO_505UM_MICROSCOPY_45_2017-08-06T19:33:00',
#  'AMBON_Zooplankton_2017_DBO3.8_1_Parasagitta_elegans_?_?_BONGO_505UM_MICROSCOPY_45_2017-08-06T19:33:00',
#  'AMBON_Zooplankton_2017_DBO3.8_1_Euphausiacea_juvenile_?_BONGO_505UM_MICROSCOPY_45_2017-08-06T19:33:00',
#  'AMBON_Zooplankton_2017_DBO3.8_1_Bolinopsis_infundibulum_?_?_BONGO_505UM_MICROSCOPY_45_2017-08-06T19:33:00',
#  'AMBON_Zooplankton_2017_DBO3.8_1_Pisces_larvae_?_BONGO_505UM_MICROSCOPY_45_2017-08-06T19:33:00']

# %% [markdown]
# Return a sorted list of the duplicate occurrenceID's.

# %%
print('Number of duplicates found = %s\n' % df[df.duplicated(subset='occurrenceID', keep=False)].shape[0])

print('Duplicate occurrenceIDs:')
sorted(df[df.duplicated(subset='occurrenceID', keep=False)]['occurrenceID'].tolist()) # added by mmb 2021-10-04
# Out:
# Number of duplicates found = 410
#
# Duplicate occurrenceIDs:
# ['AMBON_Zooplankton_2017_BBL10_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_48_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL10_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_48_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL10_?_Parasagitta_elegans_?_?_TWINRING_150UM_MICROSCOPY_48_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL10_?_Parasagitta_elegans_?_?_TWINRING_150UM_MICROSCOPY_48_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Parasagitta_elegans_?_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Parasagitta_elegans_?_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Polychaeta_larvae_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL11_?_Polychaeta_larvae_?_TWINRING_150UM_MICROSCOPY_46_2017-08-22T03:47:00',
#  'AMBON_Zooplankton_2017_BBL2_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_20_2017-08-21T01:22:00',
#  'AMBON_Zooplankton_2017_BBL2_?_Calanus_glacialis_marshallae_?_?_TWINRING_150UM_MICROSCOPY_20_2017-08-21T01:22:00',
#  'AMBON_Zooplankton_2017_BBL3_?_Aglantha_digitale_?_?_TWINRING_150UM_MICROSCOPY
# Cruise                                                                         AMBON2017
# Station                                                                            BBL10
# Type                                                           TWINRING_150UM_MICROSCOPY
# Date_Time                                                            2017-08-22 03:47:00
# Longitude_[decimal_degrees_east]                                               -167.3646
# Latitude_[decimal _degrees_north]                                                70.1925
# Bottom_Depth_[m]                                                                      51
# Cast_Number                                                                          NaN
# Depth_[m]                                                                             48
# Accepted_Organism_Identification                            Calanus glacialis/marshallae
# Life_Stage
# APHIA_ID                                                                        196770.0
# Abundance_[#/m3]                                                                   1.068
# Biomass_[mg dw/m3]                                                                0.0174
# eventDate                                                           2017-08-22T03:47:00Z
# Cast_Number_conv                                                                       ?
# sex                                                                                    ?
# Life_Stage_conv                                                                        ?
# Accepted_Organism_Identification_conv                       Calanus_glacialis_marshallae
# datasetID                                                         AMBON_Zooplankton_2017
# depth_str                                                                             48
# date_str                                                             2017-08-22T03:47:00
# biomass_str                                                                       0.0174
# occurrenceID                           AMBON_Zooplankton_2017_BBL10_?_Calanus_glacial...
# eventID                                AMBON_Zooplankton_2017_BBL10_2017-08-22T03:47:00Z
#
#                                                                                     2700
# Cruise                                                                         AMBON2017
# Station                                                                            BBL10
# Type                                                           TWINRING_150UM_MICROSCOPY
# Date_Time                                                            2017-08-22 03:47:00
# Longitude_[decimal_degrees_east]                                               -167.3646
# Latitude_[decimal _degrees_north]                                                70.1925
# Bottom_Depth_[m]                                                                      51
# Cast_Number                                                                          NaN
# Depth_[m]                                                                             48
# Accepted_Organism_Identification                            Calanus glacialis/marshallae
# Life_Stage
# APHIA_ID                                                                        196770.0
# Abundance_[#/m3]                                                                     0.2
# Biomass_[mg dw/m3]                                                                0.0663
# eventDate                                                           2017-08-22T03:47:00Z
# Cast_Number_conv                                                                       ?
# sex                                                                                    ?
# Life_Stage_conv                                                                        ?
# Accepted_Organism_Identification_conv                       Calanus_glacialis_marshallae
# datasetID                                                         AMBON_Zooplankton_2017
# depth_str                                                                             48
# date_str                                                             2017-08-22T03:47:00
# biomass_str                                                                       0.0663
# occurrenceID                           AMBON_Zooplankton_2017_BBL10_?_Calanus_glacial...
# eventID                                AMBON_Zooplankton_2017_BBL10_2017-08-22T03:47:00Z

# %% [markdown]
# To resolve the duplicate record, add the biomass (or abundance) value to make `occurrenceID` unique.

# %%
df['occurrenceID'] = df[['datasetID',
                         'Station',
                         'Cast_Number_conv',
                         'Accepted_Organism_Identification_conv',
                         'Life_Stage_conv',
                         'sex',
                         'Type',
                         'biomass_str',
                         'depth_str',
                         'date_str',
                        ]].agg('_'.join, axis=1)

# %% [markdown]
# Check for duplicate IDs.

# %%
print('Number of duplicates found = %s\n' % df[df.duplicated(subset='occurrenceID', keep=False)].shape[0])

print('Duplicate occurrenceIDs:')
sorted(df[df.duplicated(subset='occurrenceID', keep=False)]['occurrenceID'].tolist()) # added by mmb 2021-10-04
# Out:
# Number of duplicates found = 0
#
# Duplicate occurrenceIDs:
# []

# %% [markdown]
# # END of ID generation
# ---

# %%
#OK, rename and then add new columns
#rename columns as necessary

df.rename(columns={'Depth_[m]': 'minimumDepthInMeters',
                   'Life_Stage': 'lifeStage',
                   'Type': 'samplingProtocol',
                   'Longitude_[decimal_degrees_east]': 'decimalLongitude',
                   'Latitude_[decimal _degrees_north]': 'decimalLatitude',
                   'Accepted_Organism_Identification': 'scientificName',
                   'APHIA_ID': 'taxonID' }, inplace=True)

# add new parameters

df['scientificNameID'] = 'urn:lsid:marinespecies.org:taxname:'+df['taxonID'].astype(str)
df['identificationReferences'] = 'WoRMS'
df['basisOfRecord'] = 'HumanObservation' #nospace!
df['occurenceStatus'] = 'present'

df.head()
# Out:
#       Cruise Station           samplingProtocol           Date_Time  \
# 0  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 1  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 2  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 3  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
# 4  AMBON2017    BBL1  TWINRING_150UM_MICROSCOPY 2017-08-20 22:48:00
#
#    decimalLongitude  decimalLatitude  Bottom_Depth_[m]  Cast_Number  \
# 0         -163.5095          69.3443                15          NaN
# 1         -163.5095          69.3443                15          NaN
# 2         -163.5095          69.3443                15          NaN
# 3         -163.5095          69.3443                15          NaN
# 4         -163.5095          69.3443                15          NaN
#
#    minimumDepthInMeters         scientificName lifeStage   taxonID  \
# 0                    12                 Pisces    larvae   11676.0
# 1                    12                Isopoda              1131.0
# 2                    12       Evadne nordmanni            106273.0
# 3                    12  Pseudocalanus newmani            157679.0
# 4                    12  Pseudocalanus acuspes            104514.0
#
#    Abundance_[#/m3]  Biomass_[mg dw/m3]             eventDate  \
# 0             1.172                 NaN  2017-08-20T22:48:00Z
# 1             1.172                 NaN  2017-08-20T22:48:00Z
# 2             1.172              0.0086  2017-08-20T22:48:00Z
# 3             4.686              0.0121  2017-08-20T22:48:00Z
# 4             4.686              0.0335  2017-08-20T22:48:00Z
#
#   Cast_Number_conv sex Life_Stage_conv Accepted_Organism_Identification_conv  \
# 0                ?   ?          larvae                                Pisces
# 1                ?   ?               ?                               Isopoda
# 2                ?   ?               ?                      Evadne_nordmanni
# 3                ?   ?               ?                 Pseudocalanus_newmani
# 4                ?   ?               ?                 Pseudocalanus_acuspes
#
#                 datasetID depth_str             date_str biomass_str  \
# 0  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 1  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 2  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0086
# 3  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0121
# 4  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0335
#
#                                         occurrenceID  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
#
#                               scientificNameID identificationReferences  \
# 0   urn:lsid:marinespecies.org:taxname:11676.0                    WoRMS
# 1    urn:lsid:marinespecies.org:taxname:1131.0                    WoRMS
# 2  urn:lsid:marinespecies.org:taxname:106273.0                    WoRMS
# 3  urn:lsid:marinespecies.org:taxname:157679.0                    WoRMS
# 4  urn:lsid:marinespecies.org:taxname:104514.0                    WoRMS
#
#       basisOfRecord occurenceStatus
# 0  HumanObservation         present
# 1  HumanObservation         present
# 2  HumanObservation         present
# 3  HumanObservation         present
# 4  HumanObservation         present

# %%
df['maximumDepthInMeters'] = df['minimumDepthInMeters'].copy()

# %%
# Remove unnecessary columns

df = df.drop(columns=['Cruise', 'Station', 'Bottom_Depth_[m]', 'Date_Time','Cast_Number'])

#but not the measurements!
df.head()
# Out:
#             samplingProtocol  decimalLongitude  decimalLatitude  \
# 0  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 1  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 2  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 3  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 4  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
#
#    minimumDepthInMeters         scientificName lifeStage   taxonID  \
# 0                    12                 Pisces    larvae   11676.0
# 1                    12                Isopoda              1131.0
# 2                    12       Evadne nordmanni            106273.0
# 3                    12  Pseudocalanus newmani            157679.0
# 4                    12  Pseudocalanus acuspes            104514.0
#
#    Abundance_[#/m3]  Biomass_[mg dw/m3]             eventDate  \
# 0             1.172                 NaN  2017-08-20T22:48:00Z
# 1             1.172                 NaN  2017-08-20T22:48:00Z
# 2             1.172              0.0086  2017-08-20T22:48:00Z
# 3             4.686              0.0121  2017-08-20T22:48:00Z
# 4             4.686              0.0335  2017-08-20T22:48:00Z
#
#   Cast_Number_conv sex Life_Stage_conv Accepted_Organism_Identification_conv  \
# 0                ?   ?          larvae                                Pisces
# 1                ?   ?               ?                               Isopoda
# 2                ?   ?               ?                      Evadne_nordmanni
# 3                ?   ?               ?                 Pseudocalanus_newmani
# 4                ?   ?               ?                 Pseudocalanus_acuspes
#
#                 datasetID depth_str             date_str biomass_str  \
# 0  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 1  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 2  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0086
# 3  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0121
# 4  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0335
#
#                                         occurrenceID  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
#
#                               scientificNameID identificationReferences  \
# 0   urn:lsid:marinespecies.org:taxname:11676.0                    WoRMS
# 1    urn:lsid:marinespecies.org:taxname:1131.0                    WoRMS
# 2  urn:lsid:marinespecies.org:taxname:106273.0                    WoRMS
# 3  urn:lsid:marinespecies.org:taxname:157679.0                    WoRMS
# 4  urn:lsid:marinespecies.org:taxname:104514.0                    WoRMS
#
#       basisOfRecord occurenceStatus  maximumDepthInMeters
# 0  HumanObservation         present                    12
# 1  HumanObservation         present                    12
# 2  HumanObservation         present                    12
# 3  HumanObservation         present                    12
# 4  HumanObservation         present                    12

# %%
#taxonid needs to not have trailing .0
taxons = df[['taxonID']].astype('string', errors='ignore')
t=taxons['taxonID'].convert_dtypes()
t=t.str.strip('.0')
t
df['taxonID']=t
df.head()
# Out:
#             samplingProtocol  decimalLongitude  decimalLatitude  \
# 0  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 1  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 2  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 3  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 4  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
#
#    minimumDepthInMeters         scientificName lifeStage taxonID  \
# 0                    12                 Pisces    larvae   11676
# 1                    12                Isopoda              1131
# 2                    12       Evadne nordmanni            106273
# 3                    12  Pseudocalanus newmani            157679
# 4                    12  Pseudocalanus acuspes            104514
#
#    Abundance_[#/m3]  Biomass_[mg dw/m3]             eventDate  \
# 0             1.172                 NaN  2017-08-20T22:48:00Z
# 1             1.172                 NaN  2017-08-20T22:48:00Z
# 2             1.172              0.0086  2017-08-20T22:48:00Z
# 3             4.686              0.0121  2017-08-20T22:48:00Z
# 4             4.686              0.0335  2017-08-20T22:48:00Z
#
#   Cast_Number_conv sex Life_Stage_conv Accepted_Organism_Identification_conv  \
# 0                ?   ?          larvae                                Pisces
# 1                ?   ?               ?                               Isopoda
# 2                ?   ?               ?                      Evadne_nordmanni
# 3                ?   ?               ?                 Pseudocalanus_newmani
# 4                ?   ?               ?                 Pseudocalanus_acuspes
#
#                 datasetID depth_str             date_str biomass_str  \
# 0  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 1  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 2  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0086
# 3  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0121
# 4  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0335
#
#                                         occurrenceID  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
#
#                               scientificNameID identificationReferences  \
# 0   urn:lsid:marinespecies.org:taxname:11676.0                    WoRMS
# 1    urn:lsid:marinespecies.org:taxname:1131.0                    WoRMS
# 2  urn:lsid:marinespecies.org:taxname:106273.0                    WoRMS
# 3  urn:lsid:marinespecies.org:taxname:157679.0                    WoRMS
# 4  urn:lsid:marinespecies.org:taxname:104514.0                    WoRMS
#
#       basisOfRecord occurenceStatus  maximumDepthInMeters
# 0  HumanObservation         present                    12
# 1  HumanObservation         present                    12
# 2  HumanObservation         present                    12
# 3  HumanObservation         present                    12
# 4  HumanObservation         present                    12

# %%
df['kingdom']='Animalia'

# %%
#finally!
#nope it's scientificNameID that needs this
sciids = df[['scientificNameID']].astype('string', errors='ignore')
s = sciids['scientificNameID'].convert_dtypes()
s=s.str.strip('.0')
df['scientificNameID']=s
df.head()
# Out:
#             samplingProtocol  decimalLongitude  decimalLatitude  \
# 0  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 1  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 2  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 3  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 4  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
#
#    minimumDepthInMeters         scientificName lifeStage taxonID  \
# 0                    12                 Pisces    larvae   11676
# 1                    12                Isopoda              1131
# 2                    12       Evadne nordmanni            106273
# 3                    12  Pseudocalanus newmani            157679
# 4                    12  Pseudocalanus acuspes            104514
#
#    Abundance_[#/m3]  Biomass_[mg dw/m3]             eventDate  \
# 0             1.172                 NaN  2017-08-20T22:48:00Z
# 1             1.172                 NaN  2017-08-20T22:48:00Z
# 2             1.172              0.0086  2017-08-20T22:48:00Z
# 3             4.686              0.0121  2017-08-20T22:48:00Z
# 4             4.686              0.0335  2017-08-20T22:48:00Z
#
#   Cast_Number_conv sex Life_Stage_conv Accepted_Organism_Identification_conv  \
# 0                ?   ?          larvae                                Pisces
# 1                ?   ?               ?                               Isopoda
# 2                ?   ?               ?                      Evadne_nordmanni
# 3                ?   ?               ?                 Pseudocalanus_newmani
# 4                ?   ?               ?                 Pseudocalanus_acuspes
#
#                 datasetID depth_str             date_str biomass_str  \
# 0  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 1  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00         nan
# 2  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0086
# 3  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0121
# 4  AMBON_Zooplankton_2017        12  2017-08-20T22:48:00      0.0335
#
#                                         occurrenceID  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
#
#                             scientificNameID identificationReferences  \
# 0   urn:lsid:marinespecies.org:taxname:11676                    WoRMS
# 1    urn:lsid:marinespecies.org:taxname:1131                    WoRMS
# 2  urn:lsid:marinespecies.org:taxname:106273                    WoRMS
# 3  urn:lsid:marinespecies.org:taxname:157679                    WoRMS
# 4  urn:lsid:marinespecies.org:taxname:104514                    WoRMS
#
#       basisOfRecord occurenceStatus  maximumDepthInMeters   kingdom
# 0  HumanObservation         present                    12  Animalia
# 1  HumanObservation         present                    12  Animalia
# 2  HumanObservation         present                    12  Animalia
# 3  HumanObservation         present                    12  Animalia
# 4  HumanObservation         present                    12  Animalia

# %%
#double checking
df.columns
# Out:
# Index(['samplingProtocol', 'decimalLongitude', 'decimalLatitude',
#        'minimumDepthInMeters', 'scientificName', 'lifeStage', 'taxonID',
#        'Abundance_[#/m3]', 'Biomass_[mg dw/m3]', 'eventDate',
#        'Cast_Number_conv', 'sex', 'Life_Stage_conv',
#        'Accepted_Organism_Identification_conv', 'datasetID', 'depth_str',
#        'date_str', 'biomass_str', 'occurrenceID', 'eventID',
#        'scientificNameID', 'identificationReferences', 'basisOfRecord',
#        'occurenceStatus', 'maximumDepthInMeters', 'kingdom'],
#       dtype='object')

# %%
df['lifeStage'].unique()
# Out:
# array(['larvae', ' ', 'male', 'nauplii', 'cyprid', 'bipinnaria',
#        'cyphonautes', 'calytopsis', 'zoea', 'furcilia', 'juvenile',
#        'megalopa', 'eudoxid', '0'], dtype=object)

# %%
df['lifeStage'].replace(to_replace='male', value=None, inplace= True, method='pad')
df['lifeStage'].replace(to_replace='female', value=None, inplace= True, method='pad')

df['lifeStage'].unique()
# Out:
# array(['larvae', ' ', 'nauplii', 'cyprid', 'bipinnaria', 'cyphonautes',
#        'calytopsis', 'zoea', 'furcilia', 'juvenile', 'megalopa',
#        'eudoxid', '0'], dtype=object)

# %% [markdown]
# # Now for table 1 - event table
#
# ## Event table needs:
#
# Event Table
#
# eventID == 'eventID'
# EventDate== 'eventDate'
# Depth == 'minimumDepthInMeters' , 'maximumDepthInMeters'
# decimal Lat== 'decimalLatitude'
# decimal Long == 'decimalLongitude'
# ~~basisofRecord== 'basisOfRecord'  ~~
# geodeticDatum == 'WGS84'
# countryCode == 'US'
# coordinateUncertaintyInMeters ==~~'NA'~~ Nope, if it's blank do not include.
#
#
# Without repeating or duplicate events. So, filtered by unique. IN PANDAS that's...

# %%
eventdf = df[['eventID', 'eventDate', 'maximumDepthInMeters','minimumDepthInMeters' , 'decimalLatitude', 'decimalLongitude']]
eventdf.head()
eventdf['eventID'].describe()

#and, that's that? Check!
# Out:
# count                                                  4727
# unique                                                  154
# top       AMBON_Zooplankton_2017_DBO3.8_2017-08-06T18:14...
# freq                                                     54
# Name: eventID, dtype: object

# %%
#add columns of data needed
eventdf['geodeticDatum'] = 'WGS84'
eventdf['countryCode'] = 'US'
#eventdf['coordinateUncertaintyInMeters'] ='NA'

eventdf.head()
# Out:
# C:\Users\MATHEW~1.BID\AppData\Local\Temp\19/ipykernel_15412/1165450252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventdf['geodeticDatum'] = 'WGS84'
# C:\Users\MATHEW~1.BID\AppData\Local\Temp\19/ipykernel_15412/1165450252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventdf['countryCode'] = 'US'
#                                             eventID             eventDate  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
#
#    maximumDepthInMeters  minimumDepthInMeters  decimalLatitude  \
# 0                    12                    12          69.3443
# 1                    12                    12          69.3443
# 2                    12                    12          69.3443
# 3                    12                    12          69.3443
# 4                    12                    12          69.3443
#
#    decimalLongitude geodeticDatum countryCode
# 0         -163.5095         WGS84          US
# 1         -163.5095         WGS84          US
# 2         -163.5095         WGS84          US
# 3         -163.5095         WGS84          US
# 4         -163.5095         WGS84          US

# %%
#The event table needs to only hold those 135 unique events, so....
#eventdf.head()
eventdf = eventdf.drop_duplicates(subset=['eventID'])

eventdf['eventID'].describe()

#win
# Out:
# count                                                  154
# unique                                                 154
# top       AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# freq                                                     1
# Name: eventID, dtype: object

# %% [markdown]
# # Now for table 2 - Occurence
#
# Occurence table needs
# - Occurence/organism quantity table with the following fields, minimum
#     - ~~eventDate
#     - ~~eventID
#     - ~~dec lat
#     - ~~dec long~~
#     - kingdom
#     - scientificName
#     - basisofRecord (according to controlled vocab, probably HumanObservation)
#     - occurenceID
#     - datasetid (a shortname for the OPT occurence table ( more at  https://tools.gbif.org/dwca-validator/extension.do?id=dwc:event )
#     - organismQuantity (as applicable)
#     - organismQuantityType (as applicable)
#     - lifeStage (if present)
#     - occurrenceRemarks (if present)
#     - occurrenceStatus = present
#     - identificationReference
#
# The tricky part here is the occurrence ID. Each occurence ID should be unique to each observation in the occurence table. It's recommended out of eventID and TAXON id. Or just make a UUID type deal.
# It's also, a unique occurence observation but NOT a unique measurement. SO, for abundance and biomass, they're off the same occurence.
#
# So I'm not tidy-ing the dataset yet, in case I need to brute-force something by row.

# %%
#build the dataframe

occdf = df[['datasetID','eventID','occurrenceID', 'kingdom', 'scientificName', 'scientificNameID', 'taxonID','identificationReferences', 
            'lifeStage','basisOfRecord', 'samplingProtocol']]

occdf.describe().T
# Out:
#                          count unique  \
# datasetID                 4727      1
# eventID                   4727    154
# occurrenceID              4727   4727
# kingdom                   4727      1
# scientificName            4727    108
# scientificNameID          4727    111
# taxonID                   4727    111
# identificationReferences  4727      1
# lifeStage                 4727     13
# basisOfRecord             4727      1
# samplingProtocol          4727      2
#
#                                                                         top  \
# datasetID                                            AMBON_Zooplankton_2017
# eventID                   AMBON_Zooplankton_2017_DBO3.8_2017-08-06T18:14...
# occurrenceID              AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# kingdom                                                            Animalia
# scientificName                                 Calanus glacialis/marshallae
# scientificNameID                    urn:lsid:marinespecies.org:taxname:1082
# taxonID                                                                1082
# identificationReferences                                              WoRMS
# lifeStage
# basisOfRecord                                              HumanObservation
# samplingProtocol                                  TWINRING_150UM_MICROSCOPY
#
#                           freq
# datasetID                 4727
# eventID                     54
# occurrenceID                 1
# kingdom                   4727
# scientificName             227
# scientificNameID           216
# taxonID                    216
# identificationReferences  4727
# lifeStage                 3444
# basisOfRecord             4727
# samplingProtocol          2934

# %%
occdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4727 entries, 0 to 4726
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   datasetID                 4727 non-null   object
#  1   eventID                   4727 non-null   object
#  2   occurrenceID              4727 non-null   object
#  3   kingdom                   4727 non-null   object
#  4   scientificName            4727 non-null   object
#  5   scientificNameID          4727 non-null   string
#  6   taxonID                   4727 non-null   string
#  7   identificationReferences  4727 non-null   object
#  8   lifeStage                 4727 non-null   object
#  9   basisOfRecord             4727 non-null   object
#  10  samplingProtocol          4727 non-null   object
# dtypes: object(9), string(2)
# memory usage: 406.4+ KB

# %%
#where are the messy values in scinameid and taxon id?
n = occdf['scientificNameID'] == 'urn:lsid:marinespecies.org:taxname:nan'
occdf[n]
# Out:
# Empty DataFrame
# Columns: [datasetID, eventID, occurrenceID, kingdom, scientificName, scientificNameID, taxonID, identificationReferences, lifeStage, basisOfRecord, samplingProtocol]
# Index: []

# %%
#add columns still needed
#occdf.insert(0,'ocurrenceStatus', 'present')
occdf['ocurrenceStatus'] = 'present'
# Out:
# C:\Users\MATHEW~1.BID\AppData\Local\Temp\19/ipykernel_15412/3716975350.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   occdf['ocurrenceStatus'] = 'present'

# %%
occdf.head()
# Out:
#                 datasetID                                           eventID  \
# 0  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z
#
#                                         occurrenceID   kingdom  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...  Animalia
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...  Animalia
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...  Animalia
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...  Animalia
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...  Animalia
#
#           scientificName                           scientificNameID taxonID  \
# 0                 Pisces   urn:lsid:marinespecies.org:taxname:11676   11676
# 1                Isopoda    urn:lsid:marinespecies.org:taxname:1131    1131
# 2       Evadne nordmanni  urn:lsid:marinespecies.org:taxname:106273  106273
# 3  Pseudocalanus newmani  urn:lsid:marinespecies.org:taxname:157679  157679
# 4  Pseudocalanus acuspes  urn:lsid:marinespecies.org:taxname:104514  104514
#
#   identificationReferences lifeStage     basisOfRecord  \
# 0                    WoRMS    larvae  HumanObservation
# 1                    WoRMS            HumanObservation
# 2                    WoRMS            HumanObservation
# 3                    WoRMS            HumanObservation
# 4                    WoRMS            HumanObservation
#
#             samplingProtocol ocurrenceStatus
# 0  TWINRING_150UM_MICROSCOPY         present
# 1  TWINRING_150UM_MICROSCOPY         present
# 2  TWINRING_150UM_MICROSCOPY         present
# 3  TWINRING_150UM_MICROSCOPY         present
# 4  TWINRING_150UM_MICROSCOPY         present

# %% [markdown]
# ## Make the measurementorfact table long and tidy
#
# So the occurence table is now, bereft of actual specimen information? it references out to this table.
# (it could hold one measurement of the information, but in this particular case study, it made more sense not to)
#
# What I need is melt, so in pandas that's....
# melt. ^_^
#
# So, Abundance, and biomass, stacked on top of eachother, as 'organismQuantity' and 'organismQuantitytype' containing 'biomass' or abundance dry weight.
#
# MoFTable needs:
# - MeasurementOrFact table for additional attributes/variables, But ONLY those in the [OBIS mof guide](https://tools.gbif.org/dwca-validator/extension.do?id=dwc:MeasurementOrFact)
#     - eventID
#     - occurenceID
#     - measurementType
#     - measurementTypeID
#     - measurementValue
#     - measurementUnit
#     - measurementUnitID

# %%
#OK, let's make this a tidy dataset of as much of the information as possible, THEN manipulate it into a MOF dataframe. So I have a tidy dataset if I need it.
#DataFrame.melt(id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)


tidydf = df.melt(id_vars=['datasetID','occurrenceID','eventID','eventDate','samplingProtocol','decimalLongitude','decimalLatitude','maximumDepthInMeters', 'minimumDepthInMeters','scientificName','lifeStage','taxonID','scientificNameID','identificationReferences','basisOfRecord'],
        value_vars=['Abundance_[#/m3]', 'Biomass_[mg dw/m3]'])

tidydf.head()
# Out:
#                 datasetID                                       occurrenceID  \
# 0  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID             eventDate  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
#
#             samplingProtocol  decimalLongitude  decimalLatitude  \
# 0  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 1  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 2  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 3  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 4  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
#
#    maximumDepthInMeters  minimumDepthInMeters         scientificName  \
# 0                    12                    12                 Pisces
# 1                    12                    12                Isopoda
# 2                    12                    12       Evadne nordmanni
# 3                    12                    12  Pseudocalanus newmani
# 4                    12                    12  Pseudocalanus acuspes
#
#   lifeStage taxonID                           scientificNameID  \
# 0    larvae   11676   urn:lsid:marinespecies.org:taxname:11676
# 1              1131    urn:lsid:marinespecies.org:taxname:1131
# 2            106273  urn:lsid:marinespecies.org:taxname:106273
# 3            157679  urn:lsid:marinespecies.org:taxname:157679
# 4            104514  urn:lsid:marinespecies.org:taxname:104514
#
#   identificationReferences     basisOfRecord          variable  value
# 0                    WoRMS  HumanObservation  Abundance_[#/m3]  1.172
# 1                    WoRMS  HumanObservation  Abundance_[#/m3]  1.172
# 2                    WoRMS  HumanObservation  Abundance_[#/m3]  1.172
# 3                    WoRMS  HumanObservation  Abundance_[#/m3]  4.686
# 4                    WoRMS  HumanObservation  Abundance_[#/m3]  4.686

# %%
tidydf.describe()
# Out:
#        decimalLongitude  decimalLatitude  maximumDepthInMeters  \
# count       9454.000000      9454.000000           9454.000000
# mean        -162.591282        70.464638             40.221917
# std           23.140421         1.194188              8.210705
# min         -168.955400        67.664500             12.000000
# 25%         -166.423700        69.911400             38.000000
# 50%         -163.928800        70.771800             42.000000
# 75%         -162.202400        71.322200             45.000000
# max          159.410600        72.496900             56.000000
#
#        minimumDepthInMeters         value
# count           9454.000000   9382.000000
# mean              40.221917     71.083501
# std                8.210705    833.285075
# min               12.000000      0.000000
# 25%               38.000000      0.027000
# 50%               42.000000      0.180000
# 75%               45.000000      1.908825
# max               56.000000  37568.289000

# %%
tidydf['occurrenceID'].describe()
# Out:
# count                                                  9454
# unique                                                 4727
# top       AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# freq                                                      2
# Name: occurrenceID, dtype: object

# %%
# I will take that, let's rename 'variable ' and 'value'
tidydf.rename(columns={'variable': 'measurementType',
                   'value': 'measurementValue'}, inplace= True)
tidydf.head()

#tidydf.columns
# Out:
#                 datasetID                                       occurrenceID  \
# 0  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID             eventDate  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  2017-08-20T22:48:00Z
#
#             samplingProtocol  decimalLongitude  decimalLatitude  \
# 0  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 1  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 2  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 3  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
# 4  TWINRING_150UM_MICROSCOPY         -163.5095          69.3443
#
#    maximumDepthInMeters  minimumDepthInMeters         scientificName  \
# 0                    12                    12                 Pisces
# 1                    12                    12                Isopoda
# 2                    12                    12       Evadne nordmanni
# 3                    12                    12  Pseudocalanus newmani
# 4                    12                    12  Pseudocalanus acuspes
#
#   lifeStage taxonID                           scientificNameID  \
# 0    larvae   11676   urn:lsid:marinespecies.org:taxname:11676
# 1              1131    urn:lsid:marinespecies.org:taxname:1131
# 2            106273  urn:lsid:marinespecies.org:taxname:106273
# 3            157679  urn:lsid:marinespecies.org:taxname:157679
# 4            104514  urn:lsid:marinespecies.org:taxname:104514
#
#   identificationReferences     basisOfRecord   measurementType  \
# 0                    WoRMS  HumanObservation  Abundance_[#/m3]
# 1                    WoRMS  HumanObservation  Abundance_[#/m3]
# 2                    WoRMS  HumanObservation  Abundance_[#/m3]
# 3                    WoRMS  HumanObservation  Abundance_[#/m3]
# 4                    WoRMS  HumanObservation  Abundance_[#/m3]
#
#    measurementValue
# 0             1.172
# 1             1.172
# 2             1.172
# 3             4.686
# 4             4.686

# %%
tidydf.describe()
tidydf['occurrenceID'].describe()
# Out:
# count                                                  9454
# unique                                                 4727
# top       AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# freq                                                      2
# Name: occurrenceID, dtype: object

# %%
tidydf.columns
# Out:
# Index(['datasetID', 'occurrenceID', 'eventID', 'eventDate', 'samplingProtocol',
#        'decimalLongitude', 'decimalLatitude', 'maximumDepthInMeters',
#        'minimumDepthInMeters', 'scientificName', 'lifeStage', 'taxonID',
#        'scientificNameID', 'identificationReferences', 'basisOfRecord',
#        'measurementType', 'measurementValue'],
#       dtype='object')

# %%
#MOF table needs columns dropped, added, renamed etc
mofdf = tidydf.drop(columns=['datasetID','eventDate','samplingProtocol','decimalLongitude','decimalLatitude','maximumDepthInMeters', 'minimumDepthInMeters','scientificName','lifeStage','taxonID','scientificNameID','identificationReferences','basisOfRecord',])

#add static values from DWC vocabs etc
mofdf['measurementUnit'] = 'Number per m3'
mofdf['measurementUnitID'] = 'http://vocab.nerc.ac.uk/collection/P06/current/UPMM/'
#mofdf['measurementTypeID'] = '' #Do not include things that are blank values
mofdf.head()
# Out:
#                                         occurrenceID  \
# 0  AMBON_Zooplankton_2017_BBL1_?_Pisces_larvae_?_...
# 1  AMBON_Zooplankton_2017_BBL1_?_Isopoda_?_?_TWIN...
# 2  AMBON_Zooplankton_2017_BBL1_?_Evadne_nordmanni...
# 3  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ne...
# 4  AMBON_Zooplankton_2017_BBL1_?_Pseudocalanus_ac...
#
#                                             eventID   measurementType  \
# 0  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  Abundance_[#/m3]
# 1  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  Abundance_[#/m3]
# 2  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  Abundance_[#/m3]
# 3  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  Abundance_[#/m3]
# 4  AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z  Abundance_[#/m3]
#
#    measurementValue measurementUnit  \
# 0             1.172   Number per m3
# 1             1.172   Number per m3
# 2             1.172   Number per m3
# 3             4.686   Number per m3
# 4             4.686   Number per m3
#
#                                    measurementUnitID
# 0  http://vocab.nerc.ac.uk/collection/P06/current...
# 1  http://vocab.nerc.ac.uk/collection/P06/current...
# 2  http://vocab.nerc.ac.uk/collection/P06/current...
# 3  http://vocab.nerc.ac.uk/collection/P06/current...
# 4  http://vocab.nerc.ac.uk/collection/P06/current...

# %%
mofdf['measurementTypeID'] = ''

# %%
#for abundance mofdf['measurementTypeID'] = 'http://vocab.nerc.ac.uk/collection/S06/current/S0600002/'
#for biomass mofdf['measurementTypeID'] = 'http://vocab.nerc.ac.uk/collection/S06/current/S0600086/'

mofdf.loc[mofdf['measurementType'] == 'Abundance_[#/m3]', 'measurementTypeID']= 'http://vocab.nerc.ac.uk/collection/S06/current/S0600002/'
mofdf.loc[mofdf['measurementType'] == 'Biomass_[mg dw/m3]', 'measurementTypeID']= 'http://vocab.nerc.ac.uk/collection/S06/current/S0600086/'

# %%
mofdf[2100:2110]
# Out:
#                                            occurrenceID  \
# 2100  AMBON_Zooplankton_2017_ML1.12_?_Brachyura_zoea...
# 2101  AMBON_Zooplankton_2017_ML1.12_?_Pseudocalanus_...
# 2102  AMBON_Zooplankton_2017_ML1.12_?_Euphausiacea_f...
# 2103  AMBON_Zooplankton_2017_ML1.12_?_Fritillaria_bo...
# 2104  AMBON_Zooplankton_2017_ML1.12_?_Cirripedia_cyp...
# 2105  AMBON_Zooplankton_2017_ML1.12_?_Paguridae_zoea...
# 2106  AMBON_Zooplankton_2017_ML1.12_?_Polychaeta_lar...
# 2107  AMBON_Zooplankton_2017_ML1.12_?_Euphausiacea_j...
# 2108  AMBON_Zooplankton_2017_ML1.12_?_Calanus_glacia...
# 2109  AMBON_Zooplankton_2017_ML1.12_?_Oithona_simili...
#
#                                                 eventID   measurementType  \
# 2100  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2101  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2102  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2103  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2104  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2105  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2106  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2107  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2108  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
# 2109  AMBON_Zooplankton_2017_ML1.12_2017-08-19T01:25...  Abundance_[#/m3]
#
#       measurementValue measurementUnit  \
# 2100             0.590   Number per m3
# 2101            18.872   Number per m3
# 2102             0.843   Number per m3
# 2103           949.011   Number per m3
# 2104             9.436   Number per m3
# 2105             0.337   Number per m3
# 2106           121.322   Number per m3
# 2107             0.758   Number per m3
# 2108             0.927   Number per m3
# 2109           399.016   Number per m3
#
#                                       measurementUnitID  \
# 2100  http://vocab.nerc.ac.uk/collection/P06/current...
# 2101  http://vocab.nerc.ac.uk/collection/P06/current...
# 2102  http://vocab.nerc.ac.uk/collection/P06/current...
# 2103  http://vocab.nerc.ac.uk/collection/P06/current...
# 2104  http://vocab.nerc.ac.uk/collection/P06/current...
# 2105  http://vocab.nerc.ac.uk/collection/P06/current...
# 2106  http://vocab.nerc.ac.uk/collection/P06/current...
# 2107  http://vocab.nerc.ac.uk/collection/P06/current...
# 2108  http://vocab.nerc.ac.uk/collection/P06/current...
# 2109  http://vocab.nerc.ac.uk/collection/P06/current...
#
#                                       measurementTypeID
# 2100  http://vocab.nerc.ac.uk/collection/S06/current...
# 2101  http://vocab.nerc.ac.uk/collection/S06/current...
# 2102  http://vocab.nerc.ac.uk/collection/S06/current...
# 2103  http://vocab.nerc.ac.uk/collection/S06/current...
# 2104  http://vocab.nerc.ac.uk/collection/S06/current...
# 2105  http://vocab.nerc.ac.uk/collection/S06/current...
# 2106  http://vocab.nerc.ac.uk/collection/S06/current...
# 2107  http://vocab.nerc.ac.uk/collection/S06/current...
# 2108  http://vocab.nerc.ac.uk/collection/S06/current...
# 2109  http://vocab.nerc.ac.uk/collection/S06/current...

# %% [markdown]
# ## write out dataframe to new csv file

# %%
#Event Table
eventdf.to_csv('data/processed/AMBON2017_zooplankton_Event_DWC_mb.csv', index=False)
#occurence table
occdf.to_csv('data/processed/AMBON2017_zooplankton_Occurrence_DWC_mb.csv', index=False)
#MoF table
mofdf.to_csv('data/processed/AMBON2017_zooplankton_MoF_DWC_mb.csv', index=False)

# %%
# !ls data/processed
# Out:
# AMBON2017_zooplankton_Event_DWC_mb.csv
# AMBON2017_zooplankton_MoF_DWC_mb.csv
# AMBON2017_zooplankton_Occurrence_DWC_mb.csv

# %% [markdown]
# # *Fin*
